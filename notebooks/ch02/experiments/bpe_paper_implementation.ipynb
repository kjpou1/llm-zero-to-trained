# %%
# 🔄 Auto-reload modules when their source code changes
# %load_ext autoreload
# %autoreload 2

# 📦 Set up src/ and utils/ paths (project root is detected via pyproject.toml)
# %run ../../bootstrap.py

# %%
import sys
import os
from os import path

from llmscratch.config.config import Config
from llmscratch.components.io.text_loader import TextLoader
from llmscratch.services.text_preprocessing_service import TextPreprocessingService
from llmscratch.components.trainers.bpe_trainer import BPETrainer

# %%
config = Config()

config.print_config_info()
# Out:
# ==================================================
# 📂 Configured Dataset Directories
# --------------------------------------------------
# Datasets/raw dir:         /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/datasets/raw
# Datasets/processed dir:   /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/datasets/processed
# Artifacts/raw dir:        /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/artifacts/data/raw
# Artifacts/processed dir:  /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/artifacts/data/processed
# Vocab dir:                /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/artifacts/data/vocabulary
# ==================================================

# %%
file_path = path.join(config.DATASETS_RAW_DIR, "the-verdict.txt")  # Replace with your file path

text_loader = TextLoader()

for line in text_loader.load_text(file_path, mode="line"):
    print(line)
# Out:
# [ 2025-07-19 09:48:13 ] INFO [../../../src/llmscratch/components/io/text_loader.py:28] - 📂 Loading file: /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/datasets/raw/the-verdict.txt (mode: line)
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no great surprise to me to hear that, in the height of his glory, he had dropped his painting, married a rich widow, and established himself in a villa on the Riviera. (Though I rather thought it would have been Rome or Florence.)
#
# "The height of his glory"--that was what the women called it. I can hear Mrs. Gideon Thwing--his last Chicago sitter--deploring his unaccountable abdication. "Of course it's going to send the value of my picture 'way up; but I don't think of that, Mr. Rickham--the loss to Arrt is all I think of." The word, on Mrs. Thwing's lips, multiplied its _rs_ as though they were reflected in an endless vista of mirrors. And it was not only the Mrs. Thwings who mourned. Had not the exquisite Hermia Croft, at the last Grafton Gallery show, stopped me before Gisburn's "Moon-dancers" to say, with tears in her eyes: "We shall not look upon its like again"?
#
# Well!--even through the prism of Hermia's tears I felt able to face the fact with equanimity. Poor Jack Gisburn! The women had made him--it was fitting that they should mourn him. Among his own sex fewer regrets were heard, and in his own trade hardly a murmur. Professional jealousy? Perhaps. If it were, the honour of the craft was vindicated by little Claude Nutley, who, in all good faith, brought out in the Burlington a very handsome "obituary" on Jack--one of those showy articles stocked with random technicalities that I have heard (I won't say by whom) compared to Gisburn's painting. And so--his resolve being apparently irrevocable--the discussion gradually died out, and, as Mrs. Thwing had predicted, the price of "Gisburns" went up.
#
# It was not till three years later that, in the course of a few weeks' idling on the Riviera, it suddenly occurred to me to wonder why Gisburn had given up his painting. On reflection, it really was a tempting problem. To accuse his wife would have been too easy--his fair sitters had been denied the solace of saying that Mrs. Gisburn had "dragged him down." For Mrs. Gisburn--as such--had not existed till nearly a year after Jack's resolve had been taken. It might be that he had married her--since he liked his ease--because he didn't want to go on painting; but it would have been hard to prove that he had given up his painting because he had married her.
#
# Of course, if she had not dragged him down, she had equally, as Miss Croft contended, failed to "lift him up"--she had not led him back to the easel. To put the brush into his hand again--what a vocation for a wife! But Mrs. Gisburn appeared to have disdained it--and I felt it might be interesting to find out why.
#
# The desultory life of the Riviera lends itself to such purely academic speculations; and having, on my way to Monte Carlo, caught a glimpse of Jack's balustraded terraces between the pines, I had myself borne thither the next day.
#
# I found the couple at tea beneath their palm-trees; and Mrs. Gisburn's welcome was so genial that, in the ensuing weeks, I claimed it frequently. It was not that my hostess was "interesting": on that point I could have given Miss Croft the fullest reassurance. It was just because she was _not_ interesting--if I may be pardoned the bull--that I found her so. For Jack, all his life, had been surrounded by interesting women: they had fostered his art, it had been reared in the hot-house of their adulation. And it was therefore instructive to note what effect the "deadening atmosphere of mediocrity" (I quote Miss Croft) was having on him.
#
# I have mentioned that Mrs. Gisburn was rich; and it was immediately perceptible that her husband was extracting from this circumstance a delicate but substantial satisfaction. It is, as a rule, the people who scorn money who get most out of it; and Jack's elegant disdain of his wife's big balance enabled him, with an appearance of perfect good-breeding, to transmute it into objects of art and luxury. To the latter, I must add, he remained relatively indifferent; but he was buying Renaissance bronzes and eighteenth-century pictures with a discrimination that bespoke the amplest resources.
#
# "Money's only excuse is to put beauty into circulation," was one of the axioms he laid down across the Sevres and silver of an exquisitely appointed luncheon-table, when, on a later day, I had again run over from Monte Carlo; and Mrs. Gisburn, beaming on him, added for my enlightenment: "Jack is so morbidly sensitive to every form of beauty."
#
# Poor Jack! It had always been his fate to have women say such things of him: the fact should be set down in extenuation. What struck me now was that, for the first time, he resented the tone. I had seen him, so often, basking under similar tributes--was it the conjugal note that robbed them of their savour? No--for, oddly enough, it became apparent that he was fond of Mrs. Gisburn--fond enough not to see her absurdity. It was his own absurdity he seemed to be wincing under--his own attitude as an object for garlands and incense.
#
# "My dear, since I've chucked painting people don't say that stuff about me--they say it about Victor Grindle," was his only protest, as he rose from the table and strolled out onto the sunlit terrace.
#
# I glanced after him, struck by his last word. Victor Grindle was, in fact, becoming the man of the moment--as Jack himself, one might put it, had been the man of the hour. The younger artist was said to have formed himself at my friend's feet, and I wondered if a tinge of jealousy underlay the latter's mysterious abdication. But no--for it was not till after that event that the _rose Dubarry_ drawing-rooms had begun to display their "Grindles."
#
# I turned to Mrs. Gisburn, who had lingered to give a lump of sugar to her spaniel in the dining-room.
#
# "Why _has_ he chucked painting?" I asked abruptly.
#
# She raised her eyebrows with a hint of good-humoured surprise.
#
# "Oh, he doesn't _have_ to now, you know; and I want him to enjoy himself," she said quite simply.
#
# I looked about the spacious white-panelled room, with its _famille-verte_ vases repeating the tones of the pale damask curtains, and its eighteenth-century pastels in delicate faded frames.
#
# "Has he chucked his pictures too? I haven't seen a single one in the house."
#
# A slight shade of constraint crossed Mrs. Gisburn's open countenance. "It's his ridiculous modesty, you know. He says they're not fit to have about; he's sent them all away except one--my portrait--and that I have to keep upstairs."
#
# His ridiculous modesty--Jack's modesty about his pictures? My curiosity was growing like the bean-stalk. I said persuasively to my hostess: "I must really see your portrait, you know."
#
# She glanced out almost timorously at the terrace where her husband, lounging in a hooded chair, had lit a cigar and drawn the Russian deerhound's head between his knees.
#
# "Well, come while he's not looking," she said, with a laugh that tried to hide her nervousness; and I followed her between the marble Emperors of the hall, and up the wide stairs with terra-cotta nymphs poised among flowers at each landing.
#
# In the dimmest corner of her boudoir, amid a profusion of delicate and distinguished objects, hung one of the familiar oval canvases, in the inevitable garlanded frame. The mere outline of the frame called up all Gisburn's past!
#
# Mrs. Gisburn drew back the window-curtains, moved aside a _jardiniere_ full of pink azaleas, pushed an arm-chair away, and said: "If you stand here you can just manage to see it. I had it over the mantel-piece, but he wouldn't let it stay."
#
# Yes--I could just manage to see it--the first portrait of Jack's I had ever had to strain my eyes over! Usually they had the place of honour--say the central panel in a pale yellow or _rose Dubarry_ drawing-room, or a monumental easel placed so that it took the light through curtains of old Venetian point. The more modest place became the picture better; yet, as my eyes grew accustomed to the half-light, all the characteristic qualities came out--all the hesitations disguised as audacities, the tricks of prestidigitation by which, with such consummate skill, he managed to divert attention from the real business of the picture to some pretty irrelevance of detail. Mrs. Gisburn, presenting a neutral surface to work on--forming, as it were, so inevitably the background of her own picture--had lent herself in an unusual degree to the display of this false virtuosity. The picture was one of Jack's "strongest," as his admirers would have put it--it represented, on his part, a swelling of muscles, a congesting of veins, a balancing, straddling and straining, that reminded one of the circus-clown's ironic efforts to lift a feather. It met, in short, at every point the demand of lovely woman to be painted "strongly" because she was tired of being painted "sweetly"--and yet not to lose an atom of the sweetness.
#
# "It's the last he painted, you know," Mrs. Gisburn said with pardonable pride. "The last but one," she corrected herself--"but the other doesn't count, because he destroyed it."
#
# "Destroyed it?" I was about to follow up this clue when I heard a footstep and saw Jack himself on the threshold.
#
# As he stood there, his hands in the pockets of his velveteen coat, the thin brown waves of hair pushed back from his white forehead, his lean sunburnt cheeks furrowed by a smile that lifted the tips of a self-confident moustache, I felt to what a degree he had the same quality as his pictures--the quality of looking cleverer than he was.
#
# His wife glanced at him deprecatingly, but his eyes travelled past her to the portrait.
#
# "Mr. Rickham wanted to see it," she began, as if excusing herself. He shrugged his shoulders, still smiling.
#
# "Oh, Rickham found me out long ago," he said lightly; then, passing his arm through mine: "Come and see the rest of the house."
#
# He showed it to me with a kind of naive suburban pride: the bath-rooms, the speaking-tubes, the dress-closets, the trouser-presses--all the complex simplifications of the millionaire's domestic economy. And whenever my wonder paid the expected tribute he said, throwing out his chest a little: "Yes, I really don't see how people manage to live without that."
#
# Well--it was just the end one might have foreseen for him. Only he was, through it all and in spite of it all--as he had been through, and in spite of, his pictures--so handsome, so charming, so disarming, that one longed to cry out: "Be dissatisfied with your leisure!" as once one had longed to say: "Be dissatisfied with your work!"
#
# But, with the cry on my lips, my diagnosis suffered an unexpected check.
#
# "This is my own lair," he said, leading me into a dark plain room at the end of the florid vista. It was square and brown and leathery: no "effects"; no bric-a-brac, none of the air of posing for reproduction in a picture weekly--above all, no least sign of ever having been used as a studio.
#
# The fact brought home to me the absolute finality of Jack's break with his old life.
#
# "Don't you ever dabble with paint any more?" I asked, still looking about for a trace of such activity.
#
# "Never," he said briefly.
#
# "Or water-colour--or etching?"
#
# His confident eyes grew dim, and his cheeks paled a little under their handsome sunburn.
#
# "Never think of it, my dear fellow--any more than if I'd never touched a brush."
#
# And his tone told me in a flash that he never thought of anything else.
#
# I moved away, instinctively embarrassed by my unexpected discovery; and as I turned, my eye fell on a small picture above the mantel-piece--the only object breaking the plain oak panelling of the room.
#
# "Oh, by Jove!" I said.
#
# It was a sketch of a donkey--an old tired donkey, standing in the rain under a wall.
#
# "By Jove--a Stroud!" I cried.
#
# He was silent; but I felt him close behind me, breathing a little quickly.
#
# "What a wonder! Made with a dozen lines--but on everlasting foundations. You lucky chap, where did you get it?"
#
# He answered slowly: "Mrs. Stroud gave it to me."
#
# "Ah--I didn't know you even knew the Strouds. He was such an inflexible hermit."
#
# "I didn't--till after. . . . She sent for me to paint him when he was dead."
#
# "When he was dead? You?"
#
# I must have let a little too much amazement escape through my surprise, for he answered with a deprecating laugh: "Yes--she's an awful simpleton, you know, Mrs. Stroud. Her only idea was to have him done by a fashionable painter--ah, poor Stroud! She thought it the surest way of proclaiming his greatness--of forcing it on a purblind public. And at the moment I was _the_ fashionable painter."
#
# "Ah, poor Stroud--as you say. Was _that_ his history?"
#
# "That was his history. She believed in him, gloried in him--or thought she did. But she couldn't bear not to have all the drawing-rooms with her. She couldn't bear the fact that, on varnishing days, one could always get near enough to see his pictures. Poor woman! She's just a fragment groping for other fragments. Stroud is the only whole I ever knew."
#
# "You ever knew? But you just said--"
#
# Gisburn had a curious smile in his eyes.
#
# "Oh, I knew him, and he knew me--only it happened after he was dead."
#
# I dropped my voice instinctively. "When she sent for you?"
#
# "Yes--quite insensible to the irony. She wanted him vindicated--and by me!"
#
# He laughed again, and threw back his head to look up at the sketch of the donkey. "There were days when I couldn't look at that thing--couldn't face it. But I forced myself to put it here; and now it's cured me--cured me. That's the reason why I don't dabble any more, my dear Rickham; or rather Stroud himself is the reason."
#
# For the first time my idle curiosity about my companion turned into a serious desire to understand him better.
#
# "I wish you'd tell me how it happened," I said.
#
# He stood looking up at the sketch, and twirling between his fingers a cigarette he had forgotten to light. Suddenly he turned toward me.
#
# "I'd rather like to tell you--because I've always suspected you of loathing my work."
#
# I made a deprecating gesture, which he negatived with a good-humoured shrug.
#
# "Oh, I didn't care a straw when I believed in myself--and now it's an added tie between us!"
#
# He laughed slightly, without bitterness, and pushed one of the deep arm-chairs forward. "There: make yourself comfortable--and here are the cigars you like."
#
# He placed them at my elbow and continued to wander up and down the room, stopping now and then beneath the picture.
#
# "How it happened? I can tell you in five minutes--and it didn't take much longer to happen. . . . I can remember now how surprised and pleased I was when I got Mrs. Stroud's note. Of course, deep down, I had always _felt_ there was no one like him--only I had gone with the stream, echoed the usual platitudes about him, till I half got to think he was a failure, one of the kind that are left behind. By Jove, and he _was_ left behind--because he had come to stay! The rest of us had to let ourselves be swept along or go under, but he was high above the current--on everlasting foundations, as you say.
#
# "Well, I went off to the house in my most egregious mood--rather moved, Lord forgive me, at the pathos of poor Stroud's career of failure being crowned by the glory of my painting him! Of course I meant to do the picture for nothing--I told Mrs. Stroud so when she began to stammer something about her poverty. I remember getting off a prodigious phrase about the honour being _mine_--oh, I was princely, my dear Rickham! I was posing to myself like one of my own sitters.
#
# "Then I was taken up and left alone with him. I had sent all my traps in advance, and I had only to set up the easel and get to work. He had been dead only twenty-four hours, and he died suddenly, of heart disease, so that there had been no preliminary work of destruction--his face was clear and untouched. I had met him once or twice, years before, and thought him insignificant and dingy. Now I saw that he was superb.
#
# "I was glad at first, with a merely aesthetic satisfaction: glad to have my hand on such a 'subject.' Then his strange life-likeness began to affect me queerly--as I blocked the head in I felt as if he were watching me do it. The sensation was followed by the thought: if he _were_ watching me, what would he say to my way of working? My strokes began to go a little wild--I felt nervous and uncertain.
#
# "Once, when I looked up, I seemed to see a smile behind his close grayish beard--as if he had the secret, and were amusing himself by holding it back from me. That exasperated me still more. The secret? Why, I had a secret worth twenty of his! I dashed at the canvas furiously, and tried some of my bravura tricks. But they failed me, they crumbled. I saw that he wasn't watching the showy bits--I couldn't distract his attention; he just kept his eyes on the hard passages between. Those were the ones I had always shirked, or covered up with some lying paint. And how he saw through my lies!
#
# "I looked up again, and caught sight of that sketch of the donkey hanging on the wall near his bed. His wife told me afterward it was the last thing he had done--just a note taken with a shaking hand, when he was down in Devonshire recovering from a previous heart attack. Just a note! But it tells his whole history. There are years of patient scornful persistence in every line. A man who had swum with the current could never have learned that mighty up-stream stroke. . . .
#
# "I turned back to my work, and went on groping and muddling; then I looked at the donkey again. I saw that, when Stroud laid in the first stroke, he knew just what the end would be. He had possessed his subject, absorbed it, recreated it. When had I done that with any of my things? They hadn't been born of me--I had just adopted them. . . .
#
# "Hang it, Rickham, with that face watching me I couldn't do another stroke. The plain truth was, I didn't know where to put it--_I had never known_. Only, with my sitters and my public, a showy splash of colour covered up the fact--I just threw paint into their faces. . . . Well, paint was the one medium those dead eyes could see through--see straight to the tottering foundations underneath. Don't you know how, in talking a foreign language, even fluently, one says half the time not what one wants to but what one can? Well--that was the way I painted; and as he lay there and watched me, the thing they called my 'technique' collapsed like a house of cards. He didn't sneer, you understand, poor Stroud--he just lay there quietly watching, and on his lips, through the gray beard, I seemed to hear the question: 'Are you sure you know where you're coming out?'
#
# "If I could have painted that face, with that question on it, I should have done a great thing. The next greatest thing was to see that I couldn't--and that grace was given me. But, oh, at that minute, Rickham, was there anything on earth I wouldn't have given to have Stroud alive before me, and to hear him say: 'It's not too late--I'll show you how'?
#
# "It _was_ too late--it would have been, even if he'd been alive. I packed up my traps, and went down and told Mrs. Stroud. Of course I didn't tell her _that_--it would have been Greek to her. I simply said I couldn't paint him, that I was too moved. She rather liked the idea--she's so romantic! It was that that made her give me the donkey. But she was terribly upset at not getting the portrait--she did so want him 'done' by some one showy! At first I was afraid she wouldn't let me off--and at my wits' end I suggested Grindle. Yes, it was I who started Grindle: I told Mrs. Stroud he was the 'coming' man, and she told somebody else, and so it got to be true. . . . And he painted Stroud without wincing; and she hung the picture among her husband's things. . . ."
#
# He flung himself down in the arm-chair near mine, laid back his head, and clasping his arms beneath it, looked up at the picture above the chimney-piece.
#
# "I like to fancy that Stroud himself would have given it to me, if he'd been able to say what he thought that day."
#
# And, in answer to a question I put half-mechanically--"Begin again?" he flashed out. "When the one thing that brings me anywhere near him is that I knew enough to leave off?"
#
# He stood up and laid his hand on my shoulder with a laugh. "Only the irony of it is that I _am_ still painting--since Grindle's doing it for me! The Strouds stand alone, and happen once--but there's no exterminating our kind of art."

# %%
#!python -m spacy download en_core_web_sm

# %%
service = TextPreprocessingService(config.DATASETS_RAW_DIR)
# Out:
# [ 2025-07-19 09:48:13 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:26] - ⚙️ Initializing spaCy language model...
# [ 2025-07-19 09:48:13 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:28] - ✅ spaCy model loaded.

# %%
for line in text_loader.load_text(file_path, mode="chunk"):
    words = service.split_line_into_words(line)
    print(words)
# Out:
# [ 2025-07-19 09:48:13 ] INFO [../../../src/llmscratch/components/io/text_loader.py:28] - 📂 Loading file: /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/datasets/raw/the-verdict.txt (mode: chunk)
# [ 2025-07-19 09:48:13 ] WARNING [../../../src/llmscratch/components/io/text_loader.py:33] - ⚠️ Chunk mode may split words across chunk boundaries. Not recommended for BPE or word-level NLP preprocessing.
# ['I', 'HAD', 'always', 'thought', 'Jack', 'Gisburn', 'rather', 'a', 'cheap', 'genius', 'though', 'a', 'good', 'fellow', 'enough', 'so', 'it', 'was', 'no', 'great', 'surprise', 'to', 'me', 'to', 'hear', 'that', 'in', 'the', 'height', 'of', 'his', 'glory', 'he', 'had', 'dropped', 'his', 'painting', 'married', 'a', 'rich', 'widow', 'and', 'established', 'himself', 'in', 'a', 'villa', 'on', 'the', 'Riviera', 'Though', 'I', 'rather', 'thought', 'it', 'would', 'have', 'been', 'Rome', 'or', 'Florence', 'The', 'height', 'of', 'his', 'was', 'what', 'the', 'women', 'called', 'it', 'I', 'can', 'hear', 'Gideon', 'Thwing', 'his', 'last', 'Chicago', 'sitter', 'deploring', 'his', 'unaccountable', 'abdication', 'Of', 'course', 'it', 'going', 'to', 'send', 'the', 'value', 'of', 'my', 'picture', 'way', 'up', 'but', 'I', 'do', 'think', 'of', 'that', 'Rickham', 'the', 'loss', 'to', 'Arrt', 'is', 'all', 'I', 'think', 'of', 'The', 'word', 'on', 'Thwing', 'lips', 'multiplied', 'its', 'rs', 'as', 'though', 'they', 'were', 'reflected', 'in', 'an', 'endless', 'vista', 'of', 'mirrors', 'And', 'it', 'was', 'not', 'only', 'the', 'Thwings', 'who', 'mourned', 'Had', 'not', 'the', 'exquisite', 'Hermia', 'Croft', 'at', 'the', 'last', 'Grafton', 'Gallery', 'show', 'stopped', 'me', 'before', 'Gisburn', 'Moon', 'dancers', 'to', 'say', 'with', 'tears', 'in', 'her', 'eyes', 'We', 'shall', 'not', 'look', 'upon', 'its', 'like', 'again', 'through', 'the', 'prism', 'of', 'Hermia', 'tears', 'I', 'felt', 'able', 'to', 'face', 'the', 'fact', 'with', 'equanimity', 'Poor', 'Jack', 'Gisburn', 'The', 'women', 'had', 'made', 'him', 'it', 'was', 'fitting', 'that', 'they', 'should', 'mourn', 'him', 'Among', 'his', 'own', 'sex', 'fewer', 'regrets', 'were', 'heard', 'and', 'in', 'his', 'own', 'trade', 'hardly', 'a', 'murmur', 'Professional', 'jealousy', 'Perhaps', 'If', 'it', 'were', 'the', 'honour', 'of', 'the', 'craft', 'was', 'vindicated', 'by', 'little', 'Claude', 'Nutley', 'who', 'in', 'all', 'good', 'faith', 'brought', 'out', 'in', 'the', 'Burlington', 'a', 'very', 'handsome', 'obituary', 'on', 'Jack', 'one', 'of', 'those', 'showy', 'articles', 'stocked', 'with', 'random', 'technicalities', 'that', 'I', 'have', 'heard', 'I', 'wo', 'say', 'by', 'whom', 'compared', 'to', 'Gisburn', 'painting', 'And', 'so', 'his', 'resolve', 'being', 'apparently', 'irrevocable', 'the', 'discussion', 'gradually', 'died', 'out', 'and', 'as', 'Thwing', 'had', 'predicted', 'the', 'price', 'of', 'Gisburns', 'went', 'up', 'It', 'was', 'not', 'till', 'three', 'years', 'later', 'that', 'in', 'the', 'course', 'of', 'a', 'few', 'weeks', 'idling', 'on', 'the', 'Riviera', 'it', 'suddenly', 'occurred', 'to', 'me', 'to', 'wonder', 'why', 'Gisburn', 'had', 'given', 'up', 'his', 'painting', 'On', 'reflection', 'it', 'really', 'was', 'a', 'tempting', 'problem', 'To', 'accuse', 'his', 'wife', 'would', 'have', 'been', 'too', 'easy', 'his', 'fair', 'sitters', 'had', 'been', 'denied', 'the', 'solace', 'of', 'saying', 'that', 'Gisburn', 'had', 'dragged', 'him', 'down', 'For', 'Gisburn', 'as', 'such', 'had', 'not', 'existed', 'till', 'nearly', 'a', 'year', 'after', 'Jack', 'resolve', 'had', 'been', 'taken', 'It', 'might', 'be', 'that', 'he', 'had', 'married', 'her', 'since', 'he', 'liked', 'his', 'ease', 'because', 'he', 'did', 'want', 'to', 'go', 'on', 'painting', 'but', 'it', 'would', 'have', 'been', 'hard', 'to', 'prove', 'that', 'he', 'had', 'given', 'up', 'his', 'painting', 'because', 'he', 'had', 'married', 'her', 'Of', 'course', 'if', 'she', 'had', 'not', 'dragged', 'him', 'down', 'she', 'had', 'equally', 'as', 'Miss', 'Croft', 'contended', 'failed', 'to', 'lift', 'him', 'had', 'not', 'led', 'him', 'back', 'to', 'the', 'easel', 'To', 'put', 'the', 'brush', 'into', 'his', 'hand', 'again', 'what', 'a', 'vocation', 'for', 'a', 'wife', 'But', 'Gisburn', 'appeared', 'to', 'have', 'disdained', 'it', 'and', 'I', 'felt', 'it', 'might', 'be', 'interesting', 'to', 'find', 'out', 'why', 'The', 'desultory', 'life', 'of', ...
# ['tention', 'from', 'the', 'real', 'business', 'of', 'the', 'picture', 'to', 'some', 'pretty', 'irrelevance', 'of', 'detail', 'Gisburn', 'presenting', 'a', 'neutral', 'surface', 'to', 'work', 'on', 'forming', 'as', 'it', 'were', 'so', 'inevitably', 'the', 'background', 'of', 'her', 'own', 'picture', 'had', 'lent', 'herself', 'in', 'an', 'unusual', 'degree', 'to', 'the', 'display', 'of', 'this', 'false', 'virtuosity', 'The', 'picture', 'was', 'one', 'of', 'Jack', 'strongest', 'as', 'his', 'admirers', 'would', 'have', 'put', 'it', 'it', 'represented', 'on', 'his', 'part', 'a', 'swelling', 'of', 'muscles', 'a', 'congesting', 'of', 'veins', 'a', 'balancing', 'straddling', 'and', 'straining', 'that', 'reminded', 'one', 'of', 'the', 'circus', 'clown', 'ironic', 'efforts', 'to', 'lift', 'a', 'feather', 'It', 'met', 'in', 'short', 'at', 'every', 'point', 'the', 'demand', 'of', 'lovely', 'woman', 'to', 'be', 'painted', 'strongly', 'because', 'she', 'was', 'tired', 'of', 'being', 'painted', 'yet', 'not', 'to', 'lose', 'an', 'atom', 'of', 'the', 'sweetness', 'It', 'the', 'last', 'he', 'painted', 'you', 'know', 'Gisburn', 'said', 'with', 'pardonable', 'pride', 'The', 'last', 'but', 'one', 'she', 'corrected', 'the', 'other', 'does', 'count', 'because', 'he', 'destroyed', 'it', 'Destroyed', 'it', 'I', 'was', 'about', 'to', 'follow', 'up', 'this', 'clue', 'when', 'I', 'heard', 'a', 'footstep', 'and', 'saw', 'Jack', 'himself', 'on', 'the', 'threshold', 'As', 'he', 'stood', 'there', 'his', 'hands', 'in', 'the', 'pockets', 'of', 'his', 'velveteen', 'coat', 'the', 'thin', 'brown', 'waves', 'of', 'hair', 'pushed', 'back', 'from', 'his', 'white', 'forehead', 'his', 'lean', 'sunburnt', 'cheeks', 'furrowed', 'by', 'a', 'smile', 'that', 'lifted', 'the', 'tips', 'of', 'a', 'self', 'confident', 'moustache', 'I', 'felt', 'to', 'what', 'a', 'degree', 'he', 'had', 'the', 'same', 'quality', 'as', 'his', 'pictures', 'the', 'quality', 'of', 'looking', 'cleverer', 'than', 'he', 'was', 'His', 'wife', 'glanced', 'at', 'him', 'deprecatingly', 'but', 'his', 'eyes', 'travelled', 'past', 'her', 'to', 'the', 'portrait', 'Rickham', 'wanted', 'to', 'see', 'it', 'she', 'began', 'as', 'if', 'excusing', 'herself', 'He', 'shrugged', 'his', 'shoulders', 'still', 'smiling', 'Oh', 'Rickham', 'found', 'me', 'out', 'long', 'ago', 'he', 'said', 'lightly', 'then', 'passing', 'his', 'arm', 'through', 'mine', 'Come', 'and', 'see', 'the', 'rest', 'of', 'the', 'house', 'He', 'showed', 'it', 'to', 'me', 'with', 'a', 'kind', 'of', 'naive', 'suburban', 'pride', 'the', 'bath', 'rooms', 'the', 'speaking', 'tubes', 'the', 'dress', 'closets', 'the', 'trouser', 'presses', 'all', 'the', 'complex', 'simplifications', 'of', 'the', 'millionaire', 'domestic', 'economy', 'And', 'whenever', 'my', 'wonder', 'paid', 'the', 'expected', 'tribute', 'he', 'said', 'throwing', 'out', 'his', 'chest', 'a', 'little', 'Yes', 'I', 'really', 'do', 'see', 'how', 'people', 'manage', 'to', 'live', 'without', 'that', 'Well', 'it', 'was', 'just', 'the', 'end', 'one', 'might', 'have', 'foreseen', 'for', 'him', 'Only', 'he', 'was', 'through', 'it', 'all', 'and', 'in', 'spite', 'of', 'it', 'all', 'as', 'he', 'had', 'been', 'through', 'and', 'in', 'spite', 'of', 'his', 'pictures', 'so', 'handsome', 'so', 'charming', 'so', 'disarming', 'that', 'one', 'longed', 'to', 'cry', 'out', 'Be', 'dissatisfied', 'with', 'your', 'leisure', 'as', 'once', 'one', 'had', 'longed', 'to', 'say', 'Be', 'dissatisfied', 'with', 'your', 'work', 'But', 'with', 'the', 'cry', 'on', 'my', 'lips', 'my', 'diagnosis', 'suffered', 'an', 'unexpected', 'check', 'This', 'is', 'my', 'own', 'lair', 'he', 'said', 'leading', 'me', 'into', 'a', 'dark', 'plain', 'room', 'at', 'the', 'end', 'of', 'the', 'florid', 'vista', 'It', 'was', 'square', 'and', 'brown', 'and', 'leathery', 'no', 'effects', 'no', 'bric', 'a', 'brac', 'none', 'of', 'the', 'air', 'of', 'posing', 'for', 'reproduction', 'in', 'a', 'picture', 'weekly', 'above', 'all', 'no', 'least', 'sign', 'o ...
# ['Once', 'when', 'I', 'looked', 'up', 'I', 'seemed', 'to', 'see', 'a', 'smile', 'behind', 'his', 'close', 'grayish', 'beard', 'as', 'if', 'he', 'had', 'the', 'secret', 'and', 'were', 'amusing', 'himself', 'by', 'holding', 'it', 'back', 'from', 'me', 'That', 'exasperated', 'me', 'still', 'more', 'The', 'secret', 'Why', 'I', 'had', 'a', 'secret', 'worth', 'twenty', 'of', 'his', 'I', 'dashed', 'at', 'the', 'canvas', 'furiously', 'and', 'tried', 'some', 'of', 'my', 'bravura', 'tricks', 'But', 'they', 'failed', 'me', 'they', 'crumbled', 'I', 'saw', 'that', 'he', 'was', 'watching', 'the', 'showy', 'bits', 'I', 'could', 'distract', 'his', 'attention', 'he', 'just', 'kept', 'his', 'eyes', 'on', 'the', 'hard', 'passages', 'between', 'Those', 'were', 'the', 'ones', 'I', 'had', 'always', 'shirked', 'or', 'covered', 'up', 'with', 'some', 'lying', 'paint', 'And', 'how', 'he', 'saw', 'through', 'my', 'lies', 'I', 'looked', 'up', 'again', 'and', 'caught', 'sight', 'of', 'that', 'sketch', 'of', 'the', 'donkey', 'hanging', 'on', 'the', 'wall', 'near', 'his', 'bed', 'His', 'wife', 'told', 'me', 'afterward', 'it', 'was', 'the', 'last', 'thing', 'he', 'had', 'done', 'just', 'a', 'note', 'taken', 'with', 'a', 'shaking', 'hand', 'when', 'he', 'was', 'down', 'in', 'Devonshire', 'recovering', 'from', 'a', 'previous', 'heart', 'attack', 'Just', 'a', 'note', 'But', 'it', 'tells', 'his', 'whole', 'history', 'There', 'are', 'years', 'of', 'patient', 'scornful', 'persistence', 'in', 'every', 'line', 'A', 'man', 'who', 'had', 'swum', 'with', 'the', 'current', 'could', 'never', 'have', 'learned', 'that', 'mighty', 'up', 'stream', 'stroke', 'I', 'turned', 'back', 'to', 'my', 'work', 'and', 'went', 'on', 'groping', 'and', 'muddling', 'then', 'I', 'looked', 'at', 'the', 'donkey', 'again', 'I', 'saw', 'that', 'when', 'Stroud', 'laid', 'in', 'the', 'first', 'stroke', 'he', 'knew', 'just', 'what', 'the', 'end', 'would', 'be', 'He', 'had', 'possessed', 'his', 'subject', 'absorbed', 'it', 'recreated', 'it', 'When', 'had', 'I', 'done', 'that', 'with', 'any', 'of', 'my', 'things', 'They', 'had', 'been', 'born', 'of', 'me', 'I', 'had', 'just', 'adopted', 'them', 'Hang', 'it', 'Rickham', 'with', 'that', 'face', 'watching', 'me', 'I', 'could', 'do', 'another', 'stroke', 'The', 'plain', 'truth', 'was', 'I', 'did', 'know', 'where', 'to', 'put', 'had', 'never', 'known', 'Only', 'with', 'my', 'sitters', 'and', 'my', 'public', 'a', 'showy', 'splash', 'of', 'colour', 'covered', 'up', 'the', 'fact', 'I', 'just', 'threw', 'paint', 'into', 'their', 'faces', 'Well', 'paint', 'was', 'the', 'one', 'medium', 'those', 'dead', 'eyes', 'could', 'see', 'through', 'see', 'straight', 'to', 'the', 'tottering', 'foundations', 'underneath', 'Do', 'you', 'know', 'how', 'in', 'talking', 'a', 'foreign', 'language', 'even', 'fluently', 'one', 'says', 'half', 'the', 'time', 'not', 'what', 'one', 'wants', 'to', 'but', 'what', 'one', 'can', 'Well', 'that', 'was', 'the', 'way', 'I', 'painted', 'and', 'as', 'he', 'lay', 'there', 'and', 'watched', 'me', 'the', 'thing', 'they', 'called', 'my', 'technique', 'collapsed', 'like', 'a', 'house', 'of', 'cards', 'He', 'did', 'sneer', 'you', 'understand', 'poor', 'Stroud', 'he', 'just', 'lay', 'there', 'quietly', 'watching', 'and', 'on', 'his', 'lips', 'through', 'the', 'gray', 'beard', 'I', 'seemed', 'to', 'hear', 'the', 'question', 'Are', 'you', 'sure', 'you', 'know', 'where', 'you', 'coming', 'out', 'If', 'I', 'could', 'have', 'painted', 'that', 'face', 'with', 'that', 'question', 'on', 'it', 'I', 'should', 'have', 'done', 'a', 'great', 'thing', 'The', 'next', 'greatest', 'thing', 'was', 'to', 'see', 'that', 'I', 'and', 'that', 'grace', 'was', 'given', 'me', 'But', 'oh', 'at', 'that', 'minute', 'Rickham', 'was', 'there', 'anything', 'on', 'earth', 'I', 'would', 'have', 'given', 'to', 'have', 'Stroud', 'alive', 'before', 'me', 'and', 'to', 'hear', 'him', 'say', 'It', 'not', 'too', 'late', 'show', 'you', 'how', 'It', 'was', 'too', 'late', 'it', 'would', 'have ...
# /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/.venv/lib/python3.12/site-packages/spacy/pipeline/lemmatizer.py:188: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)

# %%
vocab = service.build_word_freq(mode="line", lowercase=False)
vocab_chunk = service.build_word_freq(mode="chunk", lowercase=False)
# Out:
# [ 2025-07-19 09:48:13 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:61] - 📁 Scanning directory: /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/datasets/raw
# [ 2025-07-19 09:48:13 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:65] - 📄 Processing file: the-verdict.txt
# [ 2025-07-19 09:48:13 ] INFO [../../../src/llmscratch/components/io/text_loader.py:28] - 📂 Loading file: /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/datasets/raw/the-verdict.txt (mode: line)
# [ 2025-07-19 09:48:14 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:70] - ✅ Word frequency dictionary built with 1109 unique words.
# [ 2025-07-19 09:48:14 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:61] - 📁 Scanning directory: /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/datasets/raw
# [ 2025-07-19 09:48:14 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:65] - 📄 Processing file: the-verdict.txt
# [ 2025-07-19 09:48:14 ] INFO [../../../src/llmscratch/components/io/text_loader.py:28] - 📂 Loading file: /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/datasets/raw/the-verdict.txt (mode: chunk)
# [ 2025-07-19 09:48:14 ] WARNING [../../../src/llmscratch/components/io/text_loader.py:33] - ⚠️ Chunk mode may split words across chunk boundaries. Not recommended for BPE or word-level NLP preprocessing.
# [ 2025-07-19 09:48:14 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:70] - ✅ Word frequency dictionary built with 1110 unique words.

# %%
vocab
# Out:
# {'I': 120,
#  'HAD': 1,
#  'always': 6,
#  'thought': 8,
#  'Jack': 15,
#  'Gisburn': 19,
#  'rather': 6,
#  'a': 82,
#  'cheap': 1,
#  'genius': 1,
#  'though': 2,
#  'good': 5,
#  'fellow': 2,
#  'enough': 5,
#  'so': 16,
#  'it': 66,
#  'was': 72,
#  'no': 8,
#  'great': 2,
#  'surprise': 3,
#  'to': 97,
#  'me': 37,
#  'hear': 4,
#  'that': 55,
#  'in': 40,
#  'the': 168,
#  'height': 2,
#  'of': 98,
#  'his': 61,
#  'glory': 2,
#  'he': 64,
#  'had': 54,
#  'dropped': 2,
#  'painting': 9,
#  'married': 3,
#  'rich': 2,
#  'widow': 1,
#  'and': 74,
#  'established': 1,
#  'himself': 9,
#  'villa': 1,
#  'on': 27,
#  'Riviera': 3,
#  'Though': 1,
#  'would': 12,
#  'have': 27,
#  'been': 18,
#  'Rome': 1,
#  'or': 9,
#  'Florence': 1,
#  'The': 16,
#  'what': 9,
#  'women': 4,
#  'called': 3,
#  'can': 5,
#  'Gideon': 1,
#  'Thwing': 3,
#  'last': 6,
#  'Chicago': 1,
#  'sitter': 1,
#  'deploring': 1,
#  'unaccountable': 1,
#  'abdication': 2,
#  'Of': 5,
#  'course': 6,
#  'going': 1,
#  'send': 1,
#  'value': 1,
#  'my': 40,
#  'picture': 11,
#  'way': 5,
#  'up': 20,
#  'but': 12,
#  'do': 7,
#  'think': 4,
#  'Rickham': 7,
#  'loss': 1,
#  'Arrt': 1,
#  'is': 9,
#  'all': 13,
#  'word': 2,
#  'lips': 3,
#  'multiplied': 1,
#  'its': 4,
#  'rs': 1,
#  'as': 24,
#  'they': 9,
#  'were': 9,
#  'reflected': 1,
#  'an': 12,
#  'endless': 1,
#  'vista': 2,
#  'mirrors': 1,
#  'And': 9,
#  'not': 18,
#  'only': 10,
#  'Thwings': 1,
#  'who': 7,
#  'mourned': 1,
#  'Had': 1,
#  'exquisite': 1,
#  'Hermia': 2,
#  'Croft': 4,
#  'at': 21,
#  'Grafton': 1,
#  'Gallery': 1,
#  'show': 2,
#  'stopped': 1,
#  'before': 3,
#  'Moon': 1,
#  'dancers': 1,
#  'say': 12,
#  'with': 32,
#  'tears': 2,
#  'her': 20,
#  'eyes': 8,
#  'We': 1,
#  'shall': 1,
#  'look': 3,
#  'upon': 1,
#  'like': 8,
#  'again': 7,
#  'through': 9,
#  'prism': 1,
#  'felt': 7,
#  'able': 2,
#  'face': 5,
#  'fact': 6,
#  'equanimity': 1,
#  'Poor': 3,
#  'made': 3,
#  'him': 33,
#  'fitting': 1,
#  'should': 3,
#  'mourn': 1,
#  'Among': 1,
#  'own': 7,
#  'sex': 1,
#  'fewer': 1,
#  'regrets': 1,
#  'heard': 3,
#  'trade': 1,
#  'hardly': 1,
#  'murmur': 1,
#  'Professional': 1,
#  'jealousy': 2,
#  'Perhaps': 1,
#  'If': 3,
#  'honour': 3,
#  'craft': 1,
#  'vindicated': 2,
#  'by': 14,
#  'little': 6,
#  'Claude': 1,
#  'Nutley': 1,
#  'faith': 1,
#  'brought': 2,
#  'out': 12,
#  'Burlington': 1,
#  'very': 1,
#  'handsome': 3,
#  'obituary': 1,
#  'one': 23,
#  'those': 2,
#  'showy': 4,
#  'articles': 1,
#  'stocked': 1,
#  'random': 1,
#  'technicalities': 1,
#  'wo': 1,
#  'whom': 1,
#  'compared': 1,
#  'resolve': 2,
#  'being': 4,
#  'apparently': 1,
#  'irrevocable': 1,
#  'discussion': 1,
#  'gradually': 1,
#  'died': 2,
#  'predicted': 1,
#  'price': 1,
#  'Gisburns': 1,
#  'went': 4,
#  'It': 15,
#  'till': 5,
#  'three': 1,
#  'years': 3,
#  'later': 2,
#  'few': 1,
#  'weeks': 2,
#  'idling': 1,
#  'suddenly': 2,
#  'occurred': 1,
#  'wonder': 3,
#  'why': 3,
#  'given': 6,
#  'On': 1,
#  'reflection': 1,
#  'really': 3,
#  'tempting': 1,
#  'problem': 1,
#  'To': 3,
#  'accuse': 1,
#  'wife': 5,
#  'too': 6,
#  'easy': 1,
#  'fair': 1,
#  'sitters': 3,
#  'denied': 1,
#  'solace': 1,
#  'saying': 1,
#  'dragged': 2,
#  'down': 9,
#  'For': 3,
#  'such': 7,
#  'existed': 1,
#  'nearly': 1,
#  'year': 1,
#  'after': 5,
#  'taken': 3,
#  'might': 4,
#  'be': 9,
#  'since': 3,
#  'liked': 2,
#  'ease': 1,
#  'because': 7,
#  'did': 10,
#  'want': 3,
#  'go': 3,
#  'hard': 2,
#  'prove': 1,
#  'if': 10,
#  'she': 19,
#  'equally': 1,
#  'Miss': 3,
#  'contended': 1,
#  'failed': 2,
#  'lift': 2,
#  'led': 1,
#  'back': 7,
#  'easel': 3,
#  'put': 7,
#  'brush': 2,
#  'into': 6,
#  'hand': 4,
#  'vocation': 1,
#  'for': 15,
#  'But': 10,
#  'appeared': 1,
#  'disdained': 1,
#  'interesting': 4,
#  'find': 1,
#  'desultory': 1,
#  'life': 4,
#  'lends': 1,
#  'itself': 1,
#  'purely': 1,
#  'academic': 1,
#  'speculations': 1,
#  'having': 3,
#  'Monte': 2,
#  'Carlo': 2,
#  'caught': 2,
#  'glimpse': 1,
#  'balustraded': 1,
#  'terraces': 1,
#  'between': 6,
#  'pines': 1,
#  'myself': 4,
#  'borne': 1,
#  'thither': 1,
#  'next': 2,
#  'day': 3,
#  'found': 3,
#  'couple': 1,
#  'tea': 1,
#  'beneath': 3,
#  'their': 6,
#  'palm': 1,
#  'trees': 1,
#  'welcome': 1,
#  'genial': 1,
#  'ensuing': 1,
#  'claimed': 1,
#  'frequently': 1,
#  'hostess': 2,
#  'point': 3,
#  'could': 12,
#  'fullest': 1,
#  'reassurance': 1,
#  'just': 12,
#  'may': 1,
#  'pardoned': 1,
#  'bull': 1,
#  'surrounded': 1,
#  'fostered': 1,
#  'art': 3,
#  'reared': 1,
#  'hot': 1,
#  'house': 5,
#  'adulation': 1,
#  'therefore': 1,
#  'instructive': 1,
#  'note': 5,
#  'effect': 1,
#  'deadening': 1,
#  'atmosphere': 1,
#  'mediocrity': 1,
#  'quote': 1,
#  'mentioned': 1,
#  'immediately': 1,
#  'perceptible': 1,
#  'husband': 3,
#  'extracting': 1,
#  'from': 7,
#  'this': 3,
#  'circumstance': 1,
#  'delicate': 3,
#  'substantial': 1,
#  'satisfaction': 2,
#  'rule': 1,
#  'people': 3,
#  'scorn': 1,
#  'money': 1,
#  'get': 4,
#  'most': 2,
#  'elegant': 1,
#  'disdain': 1,
#  'big': 1,
#  'balance': 1,
#  'enabled': 1,
#  'appearance': 1,
#  'perfect': 1,
#  'breeding': 1,
#  'transmute': 1,
#  'objects': 2,
#  'luxury': 1,
#  'latter': 2,
#  'must': 3,
#  'add': 1,
#  'remained': 1,
#  'relatively': 1,
#  'indifferent': 1,
#  'buying': 1,
#  'Renaissance': 1,
#  'bronzes': 1,
#  'eighteenth': 2,
#  'century': 2,
#  'pictures': 6,
#  'discrimination': 1,
#  'bespoke': 1,
#  'amplest': 1,
#  'resources': 1,
#  'Money': 1,
#  'excuse': 1,
#  'beauty': 2,
#  'circulation': 1,
#  'axioms': 1,
#  'laid': 4,
#  'across': 1,
#  'Sevres': 1,
#  'silver': 1,
#  'exquisitely': 1,
#  'appointed': 1,
#  'luncheon': 1,
#  'table': 2,
#  'when': 10,
#  'run': 1,
#  'over': 3,
#  'beaming': 1,
#  'added': 2,
#  'enlightenment': 1,
#  'morbidly': 1,
#  'sensitive': 1,
#  'every': 3,
#  'form': 1,
#  'fate': 1,
#  'things': 3,
#  'set': 2,
#  'extenuation': 1,
#  'What': 2,
#  'struck': 2,
#  'now': 6,
#  'first': 6,
#  'time': 3,
#  'resented': 1,
#  'tone': 2,
#  'seen': 2,
#  'often': 1,
#  'basking': 1,
#  'under': 5,
#  'similar': 1,
#  'tributes': 1,
#  'conjugal': 1,
#  'robbed': 1,
#  'them': 4,
#  'savour': 1,
#  'No': 1,
#  'oddly': 1,
#  'became': 2,
#  'apparent': 1,
#  'fond': 2,
#  'see': 12,
#  'absurdity': 2,
#  'seemed': 3,
#  'wincing': 2,
#  'attitude': 1,
#  'object': 2,
#  'garlands': 1,
#  'incense': 1,
#  'My': 3,
#  'dear': 4,
#  'chucked': 3,
#  'stuff': 1,
#  'about': 11,
#  'Victor': 2,
#  'Grindle': 5,
#  'protest': 1,
#  'rose': 3,
#  'strolled': 1,
#  'onto': 1,
#  'sunlit': 1,
#  'terrace': 2,
#  'glanced': 3,
#  'becoming': 1,
#  'man': 4,
#  'moment': 2,
#  'hour': 1,
#  'younger': 1,
#  'artist': 1,
#  'said': 13,
#  'formed': 1,
#  'friend': 1,
#  'feet': 1,
#  'wondered': 1,
#  'tinge': 1,
#  'underlay': 1,
#  'mysterious': 1,
#  'event': 1,
#  'Dubarry': 2,
#  'drawing': 3,
#  'rooms': 3,
#  'begun': 1,
#  'display': 2,
#  'Grindles': 1,
#  'turned': 5,
#  'lingered': 1,
#  'give': 2,
#  'lump': 1,
#  'sugar': 1,
#  'spaniel': 1,
#  'dining': 1,
#  'room': 6,
#  'Why': 2,
#  'has': 1,
#  'asked': 2,
#  'abruptly': 1,
#  'She': 9,
#  'raised': 1,
#  'eyebrows': 1,
#  'hint': 1,
#  'humoured': 2,
#  'Oh': 5,
#  'does': 2,
#  'you': 25,
#  'know': 9,
#  'enjoy': 1,
#  'quite': 2,
#  'simply': 2,
#  'looked': 5,
#  'spacious': 1,
#  'white': 2,
#  'panelled': 1,
#  'famille': 1,
#  'verte': 1,
#  'vases': 1,
#  'repeating': 1,
#  'tones': 1,
#  'pale': 2,
#  'damask': 1,
#  'curtains': 3,
#  'pastels': 1,
#  'faded': 1,
#  'frames': 1,
#  'Has': 1,
#  'single': 1,
#  'A': 2,
#  'slight': 1,
#  'shade': 1,
#  'constraint': 1,
#  'crossed': 1,
#  'open': 1,
#  'countenance': 1,
#  'ridiculous': 2,
#  'modesty': 3,
#  'He': 15,
#  'says': 2,
#  'fit': 1,
#  'sent': 4,
#  'away': 3,
#  'except': 1,
#  'portrait': 5,
#  'keep': 1,
#  'upstairs': 1,
#  'His': 4,
#  'curiosity': 2,
#  'growing': 1,
#  'bean': 1,
#  'stalk': 1,
#  'persuasively': 1,
#  'your': 3,
#  'almost': 1,
#  'timorously': 1,
#  'where': 4,
#  'lounging': 1,
#  'hooded': 1,
#  'chair': 3,
#  'lit': 1,
#  'cigar': 1,
#  'drawn': 1,
#  'Russian': 1,
#  'deerhound': 1,
#  'head': 4,
#  'knees': 1,
#  'Well': 5,
#  'come': 2,
#  'while': 1,
#  'looking': 4,
#  'laugh': 3,
#  'tried': 2,
#  'hide': 1,
#  'nervousness': 1,
#  'followed': 2,
#  'marble': 1,
#  'Emperors': 1,
#  'hall': 1,
#  'wide': 1,
#  'stairs': 1,
#  'terra': 1,
#  'cotta': 1,
#  'nymphs': 1,
#  'poised': 1,
#  'among': 2,
#  'flowers': 1,
#  'each': 1,
#  'landing': 1,
#  'In': 1,
#  'dimmest': 1,
#  'corner': 1,
#  'boudoir': 1,
#  'amid': 1,
#  'profusion': 1,
#  'distinguished': 1,
#  'hung': 2,
#  'familiar': 1,
#  'oval': 1,
#  'canvases': 1,
#  'inevitable': 1,
#  'garlanded': 1,
#  'frame': 2,
#  'mere': 1,
#  'outline': 1,
#  'past': 2,
#  'drew': 1,
#  'window': 1,
#  'moved': 4,
#  'aside': 1,
#  'jardiniere': 1,
#  'full': 1,
#  'pink': 1,
#  'azaleas': 1,
#  'pushed': 3,
#  'arm': 4,
#  'stand': 2,
#  'here': 3,
#  'manage': 3,
#  'mantel': 2,
#  'piece': 3,
#  'let': 4,
#  'stay': 2,
#  'Yes': 5,
#  'ever': 5,
#  'strain': 1,
#  'Usually': 1,
#  'place': 2,
#  'central': 1,
#  'panel': 1,
#  'yellow': 1,
#  'monumental': 1,
#  'placed': 2,
#  'took': 1,
#  'light': 3,
#  'old': 3,
#  'Venetian': 1,
#  'more': 5,
#  'modest': 1,
#  'better': 2,
#  'yet': 2,
#  'grew': 2,
#  'accustomed': 1,
#  'half': 4,
#  'characteristic': 1,
#  'qualities': 1,
#  'came': 1,
#  'hesitations': 1,
#  'disguised': 1,
#  'audacities': 1,
#  'tricks': 2,
#  'prestidigitation': 1,
#  'which': 2,
#  'consummate': 1,
#  'skill': 1,
#  'managed': 1,
#  'divert': 1,
#  'attention': 2,
#  'real': 1,
#  'business': 1,
#  'some': 4,
#  'pretty': 1,
#  'irrelevance': 1,
#  'detail': 1,
#  'presenting': 1,
#  'neutral': 1,
#  'surface': 1,
#  'work': 6,
#  'forming': 1,
#  'inevitably': 1,
#  'background': 1,
#  'lent': 1,
#  'herself': 2,
#  'unusual': 1,
#  'degree': 2,
#  'false': 1,
#  'virtuosity': 1,
#  'strongest': 1,
#  'admirers': 1,
#  'represented': 1,
#  'part': 1,
#  'swelling': 1,
#  'muscles': 1,
#  'congesting': 1,
#  'veins': 1,
#  'balancing': 1,
#  'straddling': 1,
#  'straining': 1,
#  'reminded': 1,
#  'circus': 1,
#  'clown': 1,
#  'ironic': 1,
#  'efforts': 1,
#  'feather': 1,
#  'met': 2,
#  'short': 1,
#  'demand': 1,
#  'lovely': 1,
#  'woman': 2,
#  'painted': 6,
#  'strongly': 1,
#  'tired': 2,
#  'lose': 1,
#  'atom': 1,
#  'sweetness': 1,
#  'pardonable': 1,
#  'pride': 2,
#  'corrected': 1,
#  'other': 2,
#  'count': 1,
#  'destroyed': 1,
#  'Destroyed': 1,
#  'follow': 1,
#  'clue': 1,
#  'footstep': 1,
#  'saw': 5,
#  'threshold': 1,
#  'As': 1,
#  'stood': 3,
#  'there': 7,
#  'hands': 1,
#  'pockets': 1,
#  'velveteen': 1,
#  'coat': 1,
#  'thin': 1,
#  'brown': 2,
#  'waves': 1,
#  'hair': 1,
#  'forehead': 1,
#  'lean': 1,
#  'sunburnt': 1,
#  'cheeks': 2,
#  'furrowed': 1,
#  'smile': 3,
#  'lifted': 1,
#  'tips': 1,
#  'self': 1,
#  'confident': 2,
#  'moustache': 1,
#  'same': 1,
#  'quality': 2,
#  'cleverer': 1,
#  'than': 2,
#  'deprecatingly': 1,
#  'travelled': 1,
#  'wanted': 2,
#  'began': 4,
#  'excusing': 1,
#  'shrugged': 1,
#  'shoulders': 1,
#  'still': 4,
#  'smiling': 1,
#  'long': 1,
#  'ago': 1,
#  'lightly': 1,
#  'then': 3,
#  'passing': 1,
#  'mine': 2,
#  'Come': 1,
#  'rest': 2,
#  'showed': 1,
#  'kind': 3,
#  'naive': 1,
#  'suburban': 1,
#  'bath': 1,
#  'speaking': 1,
#  'tubes': 1,
#  'dress': 1,
#  'closets': 1,
#  'trouser': 1,
#  'presses': 1,
#  'complex': 1,
#  'simplifications': 1,
#  'millionaire': 1,
#  'domestic': 1,
#  'economy': 1,
#  'whenever': 1,
#  'paid': 1,
#  'expected': 1,
#  'tribute': 1,
#  'throwing': 1,
#  'chest': 1,
#  'how': 6,
#  'live': 1,
#  'without': 3,
#  'end': 4,
#  'foreseen': 1,
#  'Only': 3,
#  'spite': 2,
#  'charming': 1,
#  'disarming': 1,
#  'longed': 2,
#  'cry': 2,
#  'Be': 2,
#  'dissatisfied': 2,
#  'leisure': 1,
#  'once': 3,
#  'diagnosis': 1,
#  'suffered': 1,
#  'unexpected': 2,
#  'check': 1,
#  'This': 1,
#  'lair': 1,
#  'leading': 1,
#  'dark': 1,
#  'plain': 3,
#  'florid': 1,
#  'square': 1,
#  'leathery': 1,
#  'effects': 1,
#  'bric': 1,
#  'brac': 1,
#  'none': 1,
#  'air': 1,
#  'posing': 2,
#  'reproduction': 1,
#  'weekly': 1,
#  'above': 4,
#  'least': 1,
#  'sign': 1,
#  'used': 1,
#  'studio': 1,
#  'home': 1,
#  'absolute': 1,
#  'finality': 1,
#  'break': 1,
#  'Do': 2,
#  'dabble': 2,
#  'paint': 6,
#  'any': 4,
#  'trace': 1,
#  'activity': 1,
#  'Never': 2,
#  'briefly': 1,
#  'Or': 1,
#  'water': 1,
#  'colour': 2,
#  'etching': 1,
#  'dim': 1,
#  'paled': 1,
#  'sunburn': 1,
#  'never': 4,
#  'touched': 1,
#  'told': 6,
#  'flash': 1,
#  'anything': 2,
#  'else': 2,
#  'instinctively': 2,
#  'embarrassed': 1,
#  'discovery': 1,
#  'eye': 1,
#  'fell': 1,
#  'small': 1,
#  'breaking': 1,
#  'oak': 1,
#  'panelling': 1,
#  'Jove': 3,
#  'sketch': 4,
#  'donkey': 6,
#  'standing': 1,
#  'rain': 1,
#  'wall': 2,
#  'By': 2,
#  'Stroud': 17,
#  'cried': 1,
#  'silent': 1,
#  'close': 2,
#  'behind': 4,
#  'breathing': 1,
#  'quickly': 1,
#  'Made': 1,
#  'dozen': 1,
#  'lines': 1,
#  'everlasting': 2,
#  'foundations': 3,
#  'You': 3,
#  'lucky': 1,
#  'chap': 1,
#  'answered': 2,
#  'slowly': 1,
#  'gave': 1,
#  'Ah': 2,
#  'even': 3,
#  'knew': 7,
#  'Strouds': 2,
#  'inflexible': 1,
#  'hermit': 1,
#  'dead': 5,
#  'When': 4,
#  'much': 2,
#  'amazement': 1,
#  'escape': 1,
#  'deprecating': 2,
#  'awful': 1,
#  'simpleton': 1,
#  'Her': 1,
#  'idea': 2,
#  'done': 5,
#  'fashionable': 2,
#  'painter': 2,
#  'ah': 1,
#  'poor': 4,
#  'surest': 1,
#  'proclaiming': 1,
#  'greatness': 1,
#  'forcing': 1,
#  'purblind': 1,
#  'public': 2,
#  'Was': 1,
#  'history': 3,
#  'That': 3,
#  'believed': 2,
#  'gloried': 1,
#  'bear': 2,
#  'varnishing': 1,
#  'days': 2,
#  'near': 4,
#  'fragment': 1,
#  'groping': 2,
#  'fragments': 1,
#  'whole': 2,
#  'curious': 1,
#  'happened': 3,
#  'voice': 1,
#  'insensible': 1,
#  'irony': 2,
#  'laughed': 2,
#  'threw': 2,
#  'There': 3,
#  'thing': 6,
#  'forced': 1,
#  'cured': 2,
#  'reason': 2,
#  'idle': 1,
#  'companion': 1,
#  'serious': 1,
#  'desire': 1,
#  'understand': 2,
#  'wish': 1,
#  'tell': 4,
#  'twirling': 1,
#  'fingers': 1,
#  'cigarette': 1,
#  'forgotten': 1,
#  'Suddenly': 1,
#  'toward': 1,
#  'suspected': 1,
#  'loathing': 1,
#  'gesture': 1,
#  'negatived': 1,
#  'shrug': 1,
#  'care': 1,
#  'straw': 1,
#  'tie': 1,
#  'us': 2,
#  'slightly': 1,
#  'bitterness': 1,
#  'deep': 2,
#  'chairs': 1,
#  'forward': 1,
#  'make': 1,
#  'yourself': 1,
#  'comfortable': 1,
#  'are': 3,
#  'cigars': 1,
#  'elbow': 1,
#  'continued': 1,
#  'wander': 1,
#  'stopping': 1,
#  'How': 1,
#  'five': 1,
#  'minutes': 1,
#  'take': 1,
#  'longer': 1,
#  'happen': 2,
#  'remember': 2,
#  'surprised': 1,
#  'pleased': 1,
#  'got': 3,
#  'gone': 1,
#  'stream': 2,
#  'echoed': 1,
#  'usual': 1,
#  'platitudes': 1,
#  'failure': 2,
#  'left': 3,
#  'ourselves': 1,
#  'swept': 1,
#  'along': 1,
#  'high': 1,
#  'current': 2,
#  'off': 4,
#  'egregious': 1,
#  'mood': 1,
#  'Lord': 1,
#  'forgive': 1,
#  'pathos': 1,
#  'career': 1,
#  'crowned': 1,
#  'meant': 1,
#  'nothing': 1,
#  'stammer': 1,
#  'something': 1,
#  'poverty': 1,
#  'getting': 2,
#  'prodigious': 1,
#  'phrase': 1,
#  'princely': 1,
#  'Then': 2,
#  'alone': 2,
#  'traps': 2,
#  'advance': 1,
#  'twenty': 2,
#  'four': 1,
#  'hours': 1,
#  'heart': 2,
#  'disease': 1,
#  'preliminary': 1,
#  'destruction': 1,
#  'clear': 1,
#  'untouched': 1,
#  'twice': 1,
#  'insignificant': 1,
#  'dingy': 1,
#  'Now': 1,
#  'superb': 1,
#  'glad': 2,
#  'merely': 1,
#  'aesthetic': 1,
#  'subject': 2,
#  'strange': 1,
#  'likeness': 1,
#  'affect': 1,
#  'queerly': 1,
#  'blocked': 1,
#  'watching': 5,
#  'sensation': 1,
#  'working': 1,
#  'strokes': 1,
#  'wild': 1,
#  'nervous': 1,
#  'uncertain': 1,
#  'Once': 1,
#  ...}

# %%
def compare_word_freqs(freq_line: dict, freq_chunk: dict) -> None:
    keys_line = set(freq_line.keys())
    keys_chunk = set(freq_chunk.keys())

    only_in_line = keys_line - keys_chunk
    only_in_chunk = keys_chunk - keys_line
    common = keys_line & keys_chunk

    diff_counts = {
        word: (freq_line[word], freq_chunk[word])
        for word in common
        if freq_line[word] != freq_chunk[word]
    }

    print("🧾 Comparison of line vs chunk mode:")
    print(f"🔹 Words only in line mode: {len(only_in_line)}")
    if only_in_line:
        print(f"  → {sorted(list(only_in_line))[:10]} ...")

    print(f"🔹 Words only in chunk mode: {len(only_in_chunk)}")
    if only_in_chunk:
        print(f"  → {sorted(list(only_in_chunk))[:10]} ...")

    print(f"🔸 Words with different counts: {len(diff_counts)}")
    for word, (count_line, count_chunk) in list(diff_counts.items())[:10]:
        print(f"  {word}: line={count_line}, chunk={count_chunk}")

# %%
compare_word_freqs(vocab, vocab_chunk)
# Out:
# 🧾 Comparison of line vs chunk mode:
# 🔹 Words only in line mode: 0
# 🔹 Words only in chunk mode: 1
#   → ['tention'] ...
# 🔸 Words with different counts: 2
#   attention: line=2, chunk=1
#   at: line=21, chunk=22

# %%
trainer = BPETrainer(num_merges=10000)
# Out:
# [ 2025-07-19 09:48:14 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:27] - 📦 Initialized BPETrainer with num_merges=10000

# %%
init_vocab = trainer._init_vocab(vocab)
sorted_vocab = sorted(init_vocab.items(), key=lambda x: x[1], reverse=True)
sorted_vocab
# Out:
# [(('t', 'h', 'e', '</w>'), 168),
#  (('I', '</w>'), 120),
#  (('o', 'f', '</w>'), 98),
#  (('t', 'o', '</w>'), 97),
#  (('a', '</w>'), 82),
#  (('a', 'n', 'd', '</w>'), 74),
#  (('w', 'a', 's', '</w>'), 72),
#  (('i', 't', '</w>'), 66),
#  (('h', 'e', '</w>'), 64),
#  (('h', 'i', 's', '</w>'), 61),
#  (('t', 'h', 'a', 't', '</w>'), 55),
#  (('h', 'a', 'd', '</w>'), 54),
#  (('i', 'n', '</w>'), 40),
#  (('m', 'y', '</w>'), 40),
#  (('m', 'e', '</w>'), 37),
#  (('h', 'i', 'm', '</w>'), 33),
#  (('w', 'i', 't', 'h', '</w>'), 32),
#  (('o', 'n', '</w>'), 27),
#  (('h', 'a', 'v', 'e', '</w>'), 27),
#  (('y', 'o', 'u', '</w>'), 25),
#  (('a', 's', '</w>'), 24),
#  (('o', 'n', 'e', '</w>'), 23),
#  (('a', 't', '</w>'), 21),
#  (('u', 'p', '</w>'), 20),
#  (('h', 'e', 'r', '</w>'), 20),
#  (('G', 'i', 's', 'b', 'u', 'r', 'n', '</w>'), 19),
#  (('s', 'h', 'e', '</w>'), 19),
#  (('b', 'e', 'e', 'n', '</w>'), 18),
#  (('n', 'o', 't', '</w>'), 18),
#  (('S', 't', 'r', 'o', 'u', 'd', '</w>'), 17),
#  (('s', 'o', '</w>'), 16),
#  (('T', 'h', 'e', '</w>'), 16),
#  (('J', 'a', 'c', 'k', '</w>'), 15),
#  (('I', 't', '</w>'), 15),
#  (('f', 'o', 'r', '</w>'), 15),
#  (('H', 'e', '</w>'), 15),
#  (('b', 'y', '</w>'), 14),
#  (('a', 'l', 'l', '</w>'), 13),
#  (('s', 'a', 'i', 'd', '</w>'), 13),
#  (('w', 'o', 'u', 'l', 'd', '</w>'), 12),
#  (('b', 'u', 't', '</w>'), 12),
#  (('a', 'n', '</w>'), 12),
#  (('s', 'a', 'y', '</w>'), 12),
#  (('o', 'u', 't', '</w>'), 12),
#  (('c', 'o', 'u', 'l', 'd', '</w>'), 12),
#  (('j', 'u', 's', 't', '</w>'), 12),
#  (('s', 'e', 'e', '</w>'), 12),
#  (('p', 'i', 'c', 't', 'u', 'r', 'e', '</w>'), 11),
#  (('a', 'b', 'o', 'u', 't', '</w>'), 11),
#  (('o', 'n', 'l', 'y', '</w>'), 10),
#  (('d', 'i', 'd', '</w>'), 10),
#  (('i', 'f', '</w>'), 10),
#  (('B', 'u', 't', '</w>'), 10),
#  (('w', 'h', 'e', 'n', '</w>'), 10),
#  (('p', 'a', 'i', 'n', 't', 'i', 'n', 'g', '</w>'), 9),
#  (('h', 'i', 'm', 's', 'e', 'l', 'f', '</w>'), 9),
#  (('o', 'r', '</w>'), 9),
#  (('w', 'h', 'a', 't', '</w>'), 9),
#  (('i', 's', '</w>'), 9),
#  (('t', 'h', 'e', 'y', '</w>'), 9),
#  (('w', 'e', 'r', 'e', '</w>'), 9),
#  (('A', 'n', 'd', '</w>'), 9),
#  (('t', 'h', 'r', 'o', 'u', 'g', 'h', '</w>'), 9),
#  (('d', 'o', 'w', 'n', '</w>'), 9),
#  (('b', 'e', '</w>'), 9),
#  (('S', 'h', 'e', '</w>'), 9),
#  (('k', 'n', 'o', 'w', '</w>'), 9),
#  (('t', 'h', 'o', 'u', 'g', 'h', 't', '</w>'), 8),
#  (('n', 'o', '</w>'), 8),
#  (('e', 'y', 'e', 's', '</w>'), 8),
#  (('l', 'i', 'k', 'e', '</w>'), 8),
#  (('d', 'o', '</w>'), 7),
#  (('R', 'i', 'c', 'k', 'h', 'a', 'm', '</w>'), 7),
#  (('w', 'h', 'o', '</w>'), 7),
#  (('a', 'g', 'a', 'i', 'n', '</w>'), 7),
#  (('f', 'e', 'l', 't', '</w>'), 7),
#  (('o', 'w', 'n', '</w>'), 7),
#  (('s', 'u', 'c', 'h', '</w>'), 7),
#  (('b', 'e', 'c', 'a', 'u', 's', 'e', '</w>'), 7),
#  (('b', 'a', 'c', 'k', '</w>'), 7),
#  (('p', 'u', 't', '</w>'), 7),
#  (('f', 'r', 'o', 'm', '</w>'), 7),
#  (('t', 'h', 'e', 'r', 'e', '</w>'), 7),
#  (('k', 'n', 'e', 'w', '</w>'), 7),
#  (('a', 'l', 'w', 'a', 'y', 's', '</w>'), 6),
#  (('r', 'a', 't', 'h', 'e', 'r', '</w>'), 6),
#  (('l', 'a', 's', 't', '</w>'), 6),
#  (('c', 'o', 'u', 'r', 's', 'e', '</w>'), 6),
#  (('f', 'a', 'c', 't', '</w>'), 6),
#  (('l', 'i', 't', 't', 'l', 'e', '</w>'), 6),
#  (('g', 'i', 'v', 'e', 'n', '</w>'), 6),
#  (('t', 'o', 'o', '</w>'), 6),
#  (('i', 'n', 't', 'o', '</w>'), 6),
#  (('b', 'e', 't', 'w', 'e', 'e', 'n', '</w>'), 6),
#  (('t', 'h', 'e', 'i', 'r', '</w>'), 6),
#  (('p', 'i', 'c', 't', 'u', 'r', 'e', 's', '</w>'), 6),
#  (('n', 'o', 'w', '</w>'), 6),
#  (('f', 'i', 'r', 's', 't', '</w>'), 6),
#  (('r', 'o', 'o', 'm', '</w>'), 6),
#  (('w', 'o', 'r', 'k', '</w>'), 6),
#  (('p', 'a', 'i', 'n', 't', 'e', 'd', '</w>'), 6),
#  (('h', 'o', 'w', '</w>'), 6),
#  (('p', 'a', 'i', 'n', 't', '</w>'), 6),
#  (('t', 'o', 'l', 'd', '</w>'), 6),
#  (('d', 'o', 'n', 'k', 'e', 'y', '</w>'), 6),
#  (('t', 'h', 'i', 'n', 'g', '</w>'), 6),
#  (('g', 'o', 'o', 'd', '</w>'), 5),
#  (('e', 'n', 'o', 'u', 'g', 'h', '</w>'), 5),
#  (('c', 'a', 'n', '</w>'), 5),
#  (('O', 'f', '</w>'), 5),
#  (('w', 'a', 'y', '</w>'), 5),
#  (('f', 'a', 'c', 'e', '</w>'), 5),
#  (('t', 'i', 'l', 'l', '</w>'), 5),
#  (('w', 'i', 'f', 'e', '</w>'), 5),
#  (('a', 'f', 't', 'e', 'r', '</w>'), 5),
#  (('h', 'o', 'u', 's', 'e', '</w>'), 5),
#  (('n', 'o', 't', 'e', '</w>'), 5),
#  (('u', 'n', 'd', 'e', 'r', '</w>'), 5),
#  (('G', 'r', 'i', 'n', 'd', 'l', 'e', '</w>'), 5),
#  (('t', 'u', 'r', 'n', 'e', 'd', '</w>'), 5),
#  (('O', 'h', '</w>'), 5),
#  (('l', 'o', 'o', 'k', 'e', 'd', '</w>'), 5),
#  (('p', 'o', 'r', 't', 'r', 'a', 'i', 't', '</w>'), 5),
#  (('W', 'e', 'l', 'l', '</w>'), 5),
#  (('Y', 'e', 's', '</w>'), 5),
#  (('e', 'v', 'e', 'r', '</w>'), 5),
#  (('m', 'o', 'r', 'e', '</w>'), 5),
#  (('s', 'a', 'w', '</w>'), 5),
#  (('d', 'e', 'a', 'd', '</w>'), 5),
#  (('d', 'o', 'n', 'e', '</w>'), 5),
#  (('w', 'a', 't', 'c', 'h', 'i', 'n', 'g', '</w>'), 5),
#  (('h', 'e', 'a', 'r', '</w>'), 4),
#  (('w', 'o', 'm', 'e', 'n', '</w>'), 4),
#  (('t', 'h', 'i', 'n', 'k', '</w>'), 4),
#  (('i', 't', 's', '</w>'), 4),
#  (('C', 'r', 'o', 'f', 't', '</w>'), 4),
#  (('s', 'h', 'o', 'w', 'y', '</w>'), 4),
#  (('b', 'e', 'i', 'n', 'g', '</w>'), 4),
#  (('w', 'e', 'n', 't', '</w>'), 4),
#  (('m', 'i', 'g', 'h', 't', '</w>'), 4),
#  (('h', 'a', 'n', 'd', '</w>'), 4),
#  (('i', 'n', 't', 'e', 'r', 'e', 's', 't', 'i', 'n', 'g', '</w>'), 4),
#  (('l', 'i', 'f', 'e', '</w>'), 4),
#  (('m', 'y', 's', 'e', 'l', 'f', '</w>'), 4),
#  (('g', 'e', 't', '</w>'), 4),
#  (('l', 'a', 'i', 'd', '</w>'), 4),
#  (('t', 'h', 'e', 'm', '</w>'), 4),
#  (('d', 'e', 'a', 'r', '</w>'), 4),
#  (('m', 'a', 'n', '</w>'), 4),
#  (('s', 'e', 'n', 't', '</w>'), 4),
#  (('H', 'i', 's', '</w>'), 4),
#  (('w', 'h', 'e', 'r', 'e', '</w>'), 4),
#  (('h', 'e', 'a', 'd', '</w>'), 4),
#  (('l', 'o', 'o', 'k', 'i', 'n', 'g', '</w>'), 4),
#  (('m', 'o', 'v', 'e', 'd', '</w>'), 4),
#  (('a', 'r', 'm', '</w>'), 4),
#  (('l', 'e', 't', '</w>'), 4),
#  (('h', 'a', 'l', 'f', '</w>'), 4),
#  (('s', 'o', 'm', 'e', '</w>'), 4),
#  (('b', 'e', 'g', 'a', 'n', '</w>'), 4),
#  (('s', 't', 'i', 'l', 'l', '</w>'), 4),
#  (('e', 'n', 'd', '</w>'), 4),
#  (('a', 'b', 'o', 'v', 'e', '</w>'), 4),
#  (('a', 'n', 'y', '</w>'), 4),
#  (('n', 'e', 'v', 'e', 'r', '</w>'), 4),
#  (('s', 'k', 'e', 't', 'c', 'h', '</w>'), 4),
#  (('b', 'e', 'h', 'i', 'n', 'd', '</w>'), 4),
#  (('W', 'h', 'e', 'n', '</w>'), 4),
#  (('p', 'o', 'o', 'r', '</w>'), 4),
#  (('n', 'e', 'a', 'r', '</w>'), 4),
#  (('t', 'e', 'l', 'l', '</w>'), 4),
#  (('o', 'f', 'f', '</w>'), 4),
#  (('s', 'u', 'r', 'p', 'r', 'i', 's', 'e', '</w>'), 3),
#  (('m', 'a', 'r', 'r', 'i', 'e', 'd', '</w>'), 3),
#  (('R', 'i', 'v', 'i', 'e', 'r', 'a', '</w>'), 3),
#  (('c', 'a', 'l', 'l', 'e', 'd', '</w>'), 3),
#  (('T', 'h', 'w', 'i', 'n', 'g', '</w>'), 3),
#  (('l', 'i', 'p', 's', '</w>'), 3),
#  (('b', 'e', 'f', 'o', 'r', 'e', '</w>'), 3),
#  (('l', 'o', 'o', 'k', '</w>'), 3),
#  (('P', 'o', 'o', 'r', '</w>'), 3),
#  (('m', 'a', 'd', 'e', '</w>'), 3),
#  (('s', 'h', 'o', 'u', 'l', 'd', '</w>'), 3),
#  (('h', 'e', 'a', 'r', 'd', '</w>'), 3),
#  (('I', 'f', '</w>'), 3),
#  (('h', 'o', 'n', 'o', 'u', 'r', '</w>'), 3),
#  (('h', 'a', 'n', 'd', 's', 'o', 'm', 'e', '</w>'), 3),
#  (('y', 'e', 'a', 'r', 's', '</w>'), 3),
#  (('w', 'o', 'n', 'd', 'e', 'r', '</w>'), 3),
#  (('w', 'h', 'y', '</w>'), 3),
#  (('r', 'e', 'a', 'l', 'l', 'y', '</w>'), 3),
#  (('T', 'o', '</w>'), 3),
#  (('s', 'i', 't', 't', 'e', 'r', 's', '</w>'), 3),
#  (('F', 'o', 'r', '</w>'), 3),
#  (('t', 'a', 'k', 'e', 'n', '</w>'), 3),
#  (('s', 'i', 'n', 'c', 'e', '</w>'), 3),
#  (('w', 'a', 'n', 't', '</w>'), 3),
#  (('g', 'o', '</w>'), 3),
#  (('M', 'i', 's', 's', '</w>'), 3),
#  (('e', 'a', 's', 'e', 'l', '</w>'), 3),
#  (('h', 'a', 'v', 'i', 'n', 'g', '</w>'), 3),
#  (('d', 'a', 'y', '</w>'), 3),
#  (('f', 'o', 'u', 'n', 'd', '</w>'), 3),
#  (('b', 'e', 'n', 'e', 'a', 't', 'h', '</w>'), 3),
#  (('p', 'o', 'i', 'n', 't', '</w>'), 3),
#  (('a', 'r', 't', '</w>'), 3),
#  (('h', 'u', 's', 'b', 'a', 'n', 'd', '</w>'), 3),
#  (('t', 'h', 'i', 's', '</w>'), 3),
#  (('d', 'e', 'l', 'i', 'c', 'a', 't', 'e', '</w>'), 3),
#  (('p', 'e', 'o', 'p', 'l', 'e', '</w>'), 3),
#  (('m', 'u', 's', 't', '</w>'), 3),
#  (('o', 'v', 'e', 'r', '</w>'), 3),
#  (('e', 'v', 'e', 'r', 'y', '</w>'), 3),
#  (('t', 'h', 'i', 'n', 'g', 's', '</w>'), 3),
#  (('t', 'i', 'm', 'e', '</w>'), 3),
#  (('s', 'e', 'e', 'm', 'e', 'd', '</w>'), 3),
#  (('M', 'y', '</w>'), 3),
#  (('c', 'h', 'u', 'c', 'k', 'e', 'd', '</w>'), 3),
#  (('r', 'o', 's', 'e', '</w>'), 3),
#  (('g', 'l', 'a', 'n', 'c', 'e', 'd', '</w>'), 3),
#  (('d', 'r', 'a', 'w', 'i', 'n', 'g', '</w>'), 3),
#  (('r', 'o', 'o', 'm', 's', '</w>'), 3),
#  (('c', 'u', 'r', 't', 'a', 'i', 'n', 's', '</w>'), 3),
#  (('m', 'o', 'd', 'e', 's', 't', 'y', '</w>'), 3),
#  (('a', 'w', 'a', 'y', '</w>'), 3),
#  (('y', 'o', 'u', 'r', '</w>'), 3),
#  (('c', 'h', 'a', 'i', 'r', '</w>'), 3),
#  (('l', 'a', 'u', 'g', 'h', '</w>'), 3),
#  (('p', 'u', 's', 'h', 'e', 'd', '</w>'), 3),
#  (('h', 'e', 'r', 'e', '</w>'), 3),
#  (('m', 'a', 'n', 'a', 'g', 'e', '</w>'), 3),
#  (('p', 'i', 'e', 'c', 'e', '</w>'), 3),
#  (('l', 'i', 'g', 'h', 't', '</w>'), 3),
#  (('o', 'l', 'd', '</w>'), 3),
#  (('s', 't', 'o', 'o', 'd', '</w>'), 3),
#  (('s', 'm', 'i', 'l', 'e', '</w>'), 3),
#  (('t', 'h', 'e', 'n', '</w>'), 3),
#  (('k', 'i', 'n', 'd', '</w>'), 3),
#  (('w', 'i', 't', 'h', 'o', 'u', 't', '</w>'), 3),
#  (('O', 'n', 'l', 'y', '</w>'), 3),
#  (('o', 'n', 'c', 'e', '</w>'), 3),
#  (('p', 'l', 'a', 'i', 'n', '</w>'), 3),
#  (('J', 'o', 'v', 'e', '</w>'), 3),
#  (('f', 'o', 'u', 'n', 'd', 'a', 't', 'i', 'o', 'n', 's', '</w>'), 3),
#  (('Y', 'o', 'u', '</w>'), 3),
#  (('e', 'v', 'e', 'n', '</w>'), 3),
#  (('h', 'i', 's', 't', 'o', 'r', 'y', '</w>'), 3),
#  (('T', 'h', 'a', 't', '</w>'), 3),
#  (('h', 'a', 'p', 'p', 'e', 'n', 'e', 'd', '</w>'), 3),
#  (('T', 'h', 'e', 'r', 'e', '</w>'), 3),
#  (('a', 'r', 'e', '</w>'), 3),
#  (('g', 'o', 't', '</w>'), 3),
#  (('l', 'e', 'f', 't', '</w>'), 3),
#  (('s', 'e', 'c', 'r', 'e', 't', '</w>'), 3),
#  (('s', 't', 'r', 'o', 'k', 'e', '</w>'), 3),
#  (('q', 'u', 'e', 's', 't', 'i', 'o', 'n', '</w>'), 3),
#  (('t', 'h', 'o', 'u', 'g', 'h', '</w>'), 2),
#  (('f', 'e', 'l', 'l', 'o', 'w', '</w>'), 2),
#  (('g', 'r', 'e', 'a', 't', '</w>'), 2),
#  (('h', 'e', 'i', 'g', 'h', 't', '</w>'), 2),
#  (('g', 'l', 'o', 'r', 'y', '</w>'), 2),
#  (('d', 'r', 'o', 'p', 'p', 'e', 'd', '</w>'), 2),
#  (('r', 'i', 'c', 'h', '</w>'), 2),
#  (('a', 'b', 'd', 'i', 'c', 'a', 't', 'i', 'o', 'n', '</w>'), 2),
#  (('w', 'o', 'r', 'd', '</w>'), 2),
#  (('v', 'i', 's', 't', 'a', '</w>'), 2),
#  (('H', 'e', 'r', 'm', 'i', 'a', '</w>'), 2),
#  (('s', 'h', 'o', 'w', '</w>'), 2),
#  (('t', 'e', 'a', 'r', 's', '</w>'), 2),
#  (('a', 'b', 'l', 'e', '</w>'), 2),
#  (('j', 'e', 'a', 'l', 'o', 'u', 's', 'y', '</w>'), 2),
#  (('v', 'i', 'n', 'd', 'i', 'c', 'a', 't', 'e', 'd', '</w>'), 2),
#  (('b', 'r', 'o', 'u', 'g', 'h', 't', '</w>'), 2),
#  (('t', 'h', 'o', 's', 'e', '</w>'), 2),
#  (('r', 'e', 's', 'o', 'l', 'v', 'e', '</w>'), 2),
#  (('d', 'i', 'e', 'd', '</w>'), 2),
#  (('l', 'a', 't', 'e', 'r', '</w>'), 2),
#  (('w', 'e', 'e', 'k', 's', '</w>'), 2),
#  (('s', 'u', 'd', 'd', 'e', 'n', 'l', 'y', '</w>'), 2),
#  (('d', 'r', 'a', 'g', 'g', 'e', 'd', '</w>'), 2),
#  (('l', 'i', 'k', 'e', 'd', '</w>'), 2),
#  (('h', 'a', 'r', 'd', '</w>'), 2),
#  (('f', 'a', 'i', 'l', 'e', 'd', '</w>'), 2),
#  (('l', 'i', 'f', 't', '</w>'), 2),
#  (('b', 'r', 'u', 's', 'h', '</w>'), 2),
#  (('M', 'o', 'n', 't', 'e', '</w>'), 2),
#  (('C', 'a', 'r', 'l', 'o', '</w>'), 2),
#  (('c', 'a', 'u', 'g', 'h', 't', '</w>'), 2),
#  (('n', 'e', 'x', 't', '</w>'), 2),
#  (('h', 'o', 's', 't', 'e', 's', 's', '</w>'), 2),
#  (('s', 'a', 't', 'i', 's', 'f', 'a', 'c', 't', 'i', 'o', 'n', '</w>'), 2),
#  (('m', 'o', 's', 't', '</w>'), 2),
#  (('o', 'b', 'j', 'e', 'c', 't', 's', '</w>'), 2),
#  (('l', 'a', 't', 't', 'e', 'r', '</w>'), 2),
#  (('e', 'i', 'g', 'h', 't', 'e', 'e', 'n', 't', 'h', '</w>'), 2),
#  (('c', 'e', 'n', 't', 'u', 'r', 'y', '</w>'), 2),
#  (('b', 'e', 'a', 'u', 't', 'y', '</w>'), 2),
#  (('t', 'a', 'b', 'l', 'e', '</w>'), 2),
#  (('a', 'd', 'd', 'e', 'd', '</w>'), 2),
#  (('s', 'e', 't', '</w>'), 2),
#  (('W', 'h', 'a', 't', '</w>'), 2),
#  (('s', 't', 'r', 'u', 'c', 'k', '</w>'), 2),
#  (('t', 'o', 'n', 'e', '</w>'), 2),
#  (('s', 'e', 'e', 'n', '</w>'), 2),
#  (('b', 'e', 'c', 'a', 'm', 'e', '</w>'), 2),
#  (('f', 'o', 'n', 'd', '</w>'), 2),
#  (('a', 'b', 's', 'u', 'r', 'd', 'i', 't', 'y', '</w>'), 2),
#  (('w', 'i', 'n', 'c', 'i', 'n', 'g', '</w>'), 2),
#  (('o', 'b', 'j', 'e', 'c', 't', '</w>'), 2),
#  (('V', 'i', 'c', 't', 'o', 'r', '</w>'), 2),
#  (('t', 'e', 'r', 'r', 'a', 'c', 'e', '</w>'), 2),
#  (('m', 'o', 'm', 'e', 'n', 't', '</w>'), 2),
#  (('D', 'u', 'b', 'a', 'r', 'r', 'y', '</w>'), 2),
#  (('d', 'i', 's', 'p', 'l', 'a', 'y', '</w>'), 2),
#  (('g', 'i', 'v', 'e', '</w>'), 2),
#  (('W', 'h', 'y', '</w>'), 2),
#  (('a', 's', 'k', 'e', 'd', '</w>'), 2),
#  (('h', 'u', 'm', 'o', 'u', 'r', 'e', 'd', '</w>'), 2),
#  (('d', 'o', 'e', 's', '</w>'), 2),
#  (('q', 'u', 'i', 't', 'e', '</w>'), 2),
#  (('s', 'i', 'm', 'p', 'l', 'y', '</w>'), 2),
#  (('w', 'h', 'i', 't', 'e', '</w>'), 2),
#  (('p', 'a', 'l', 'e', '</w>'), 2),
#  (('A', '</w>'), 2),
#  (('r', 'i', 'd', 'i', 'c', 'u', 'l', 'o', 'u', 's', '</w>'), 2),
#  (('s', 'a', 'y', 's', '</w>'), 2),
#  (('c', 'u', 'r', 'i', 'o', 's', 'i', 't', 'y', '</w>'), 2),
#  (('c', 'o', 'm', 'e', '</w>'), 2),
#  (('t', 'r', 'i', 'e', 'd', '</w>'), 2),
#  (('f', 'o', 'l', 'l', 'o', 'w', 'e', 'd', '</w>'), 2),
#  (('a', 'm', 'o', 'n', 'g', '</w>'), 2),
#  (('h', 'u', 'n', 'g', '</w>'), 2),
#  (('f', 'r', 'a', 'm', 'e', '</w>'), 2),
#  (('p', 'a', 's', 't', '</w>'), 2),
#  (('s', 't', 'a', 'n', 'd', '</w>'), 2),
#  (('m', 'a', 'n', 't', 'e', 'l', '</w>'), 2),
#  (('s', 't', 'a', 'y', '</w>'), 2),
#  (('p', 'l', 'a', 'c', 'e', '</w>'), 2),
#  (('p', 'l', 'a', 'c', 'e', 'd', '</w>'), 2),
#  (('b', 'e', 't', 't', 'e', 'r', '</w>'), 2),
#  (('y', 'e', 't', '</w>'), 2),
#  (('g', 'r', 'e', 'w', '</w>'), 2),
#  (('t', 'r', 'i', 'c', 'k', 's', '</w>'), 2),
#  (('w', 'h', 'i', 'c', 'h', '</w>'), 2),
#  (('a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n', '</w>'), 2),
#  (('h', 'e', 'r', 's', 'e', 'l', 'f', '</w>'), 2),
#  (('d', 'e', 'g', 'r', 'e', 'e', '</w>'), 2),
#  (('m', 'e', 't', '</w>'), 2),
#  (('w', 'o', 'm', 'a', 'n', '</w>'), 2),
#  (('t', 'i', 'r', 'e', 'd', '</w>'), 2),
#  (('p', 'r', 'i', 'd', 'e', '</w>'), 2),
#  (('o', 't', 'h', 'e', 'r', '</w>'), 2),
#  (('b', 'r', 'o', 'w', 'n', '</w>'), 2),
#  (('c', 'h', 'e', 'e', 'k', 's', '</w>'), 2),
#  (('c', 'o', 'n', 'f', 'i', 'd', 'e', 'n', 't', '</w>'), 2),
#  (('q', 'u', 'a', 'l', 'i', 't', 'y', '</w>'), 2),
#  (('t', 'h', 'a', 'n', '</w>'), 2),
#  (('w', 'a', 'n', 't', 'e', 'd', '</w>'), 2),
#  (('m', 'i', 'n', 'e', '</w>'), 2),
#  (('r', 'e', 's', 't', '</w>'), 2),
#  (('s', 'p', 'i', 't', 'e', '</w>'), 2),
#  (('l', 'o', 'n', 'g', 'e', 'd', '</w>'), 2),
#  (('c', 'r', 'y', '</w>'), 2),
#  (('B', 'e', '</w>'), 2),
#  (('d', 'i', 's', 's', 'a', 't', 'i', 's', 'f', 'i', 'e', 'd', '</w>'), 2),
#  (('u', 'n', 'e', 'x', 'p', 'e', 'c', 't', 'e', 'd', '</w>'), 2),
#  (('p', 'o', 's', 'i', 'n', 'g', '</w>'), 2),
#  (('D', 'o', '</w>'), 2),
#  (('d', 'a', 'b', 'b', 'l', 'e', '</w>'), 2),
#  (('N', 'e', 'v', 'e', 'r', '</w>'), 2),
#  (('c', 'o', 'l', 'o', 'u', 'r', '</w>'), 2),
#  (('a', 'n', 'y', 't', 'h', 'i', 'n', 'g', '</w>'), 2),
#  (('e', 'l', 's', 'e', '</w>'), 2),
#  (('i', 'n', 's', 't', 'i', 'n', 'c', 't', 'i', 'v', 'e', 'l', 'y', '</w>'),
#   2),
#  (('w', 'a', 'l', 'l', '</w>'), 2),
#  (('B', 'y', '</w>'), 2),
#  (('c', 'l', 'o', 's', 'e', '</w>'), 2),
#  (('e', 'v', 'e', 'r', 'l', 'a', 's', 't', 'i', 'n', 'g', '</w>'), 2),
#  (('a', 'n', 's', 'w', 'e', 'r', 'e', 'd', '</w>'), 2),
#  (('A', 'h', '</w>'), 2),
#  (('S', 't', 'r', 'o', 'u', 'd', 's', '</w>'), 2),
#  (('m', 'u', 'c', 'h', '</w>'), 2),
#  (('d', 'e', 'p', 'r', 'e', 'c', 'a', 't', 'i', 'n', 'g', '</w>'), 2),
#  (('i', 'd', 'e', 'a', '</w>'), 2),
#  (('f', 'a', 's', 'h', 'i', 'o', 'n', 'a', 'b', 'l', 'e', '</w>'), 2),
#  (('p', 'a', 'i', 'n', 't', 'e', 'r', '</w>'), 2),
#  (('p', 'u', 'b', 'l', 'i', 'c', '</w>'), 2),
#  (('b', 'e', 'l', 'i', 'e', 'v', 'e', 'd', '</w>'), 2),
#  (('b', 'e', 'a', 'r', '</w>'), 2),
#  (('d', 'a', 'y', 's', '</w>'), 2),
#  (('g', 'r', 'o', 'p', 'i', 'n', 'g', '</w>'), 2),
#  (('w', 'h', 'o', 'l', 'e', '</w>'), 2),
#  (('i', 'r', 'o', 'n', 'y', '</w>'), 2),
#  (('l', 'a', 'u', 'g', 'h', 'e', 'd', '</w>'), 2),
#  (('t', 'h', 'r', 'e', 'w', '</w>'), 2),
#  (('c', 'u', 'r', 'e', 'd', '</w>'), 2),
#  (('r', 'e', 'a', 's', 'o', 'n', '</w>'), 2),
#  (('u', 'n', 'd', 'e', 'r', 's', 't', 'a', 'n', 'd', '</w>'), 2),
#  (('u', 's', '</w>'), 2),
#  (('d', 'e', 'e', 'p', '</w>'), 2),
#  (('h', 'a', 'p', 'p', 'e', 'n', '</w>'), 2),
#  (('r', 'e', 'm', 'e', 'm', 'b', 'e', 'r', '</w>'), 2),
#  (('s', 't', 'r', 'e', 'a', 'm', '</w>'), 2),
#  (('f', 'a', 'i', 'l', 'u', 'r', 'e', '</w>'), 2),
#  (('c', 'u', 'r', 'r', 'e', 'n', 't', '</w>'), 2),
#  (('g', 'e', 't', 't', 'i', 'n', 'g', '</w>'), 2),
#  (('T', 'h', 'e', 'n', '</w>'), 2),
#  (('a', 'l', 'o', 'n', 'e', '</w>'), 2),
#  (('t', 'r', 'a', 'p', 's', '</w>'), 2),
#  (('t', 'w', 'e', 'n', 't', 'y', '</w>'), 2),
#  (('h', 'e', 'a', 'r', 't', '</w>'), 2),
#  (('g', 'l', 'a', 'd', '</w>'), 2),
#  (('s', 'u', 'b', 'j', 'e', 'c', 't', '</w>'), 2),
#  (('b', 'e', 'a', 'r', 'd', '</w>'), 2),
#  (('c', 'o', 'v', 'e', 'r', 'e', 'd', '</w>'), 2),
#  (('l', 'a', 'y', '</w>'), 2),
#  (('c', 'o', 'm', 'i', 'n', 'g', '</w>'), 2),
#  (('a', 'l', 'i', 'v', 'e', '</w>'), 2),
#  (('l', 'a', 't', 'e', '</w>'), 2),
#  (('H', 'A', 'D', '</w>'), 1),
#  (('c', 'h', 'e', 'a', 'p', '</w>'), 1),
#  (('g', 'e', 'n', 'i', 'u', 's', '</w>'), 1),
#  (('w', 'i', 'd', 'o', 'w', '</w>'), 1),
#  (('e', 's', 't', 'a', 'b', 'l', 'i', 's', 'h', 'e', 'd', '</w>'), 1),
#  (('v', 'i', 'l', 'l', 'a', '</w>'), 1),
#  (('T', 'h', 'o', 'u', 'g', 'h', '</w>'), 1),
#  (('R', 'o', 'm', 'e', '</w>'), 1),
#  (('F', 'l', 'o', 'r', 'e', 'n', 'c', 'e', '</w>'), 1),
#  (('G', 'i', 'd', 'e', 'o', 'n', '</w>'), 1),
#  (('C', 'h', 'i', 'c', 'a', 'g', 'o', '</w>'), 1),
#  (('s', 'i', 't', 't', 'e', 'r', '</w>'), 1),
#  (('d', 'e', 'p', 'l', 'o', 'r', 'i', 'n', 'g', '</w>'), 1),
#  (('u', 'n', 'a', 'c', 'c', 'o', 'u', 'n', 't', 'a', 'b', 'l', 'e', '</w>'),
#   1),
#  (('g', 'o', 'i', 'n', 'g', '</w>'), 1),
#  (('s', 'e', 'n', 'd', '</w>'), 1),
#  (('v', 'a', 'l', 'u', 'e', '</w>'), 1),
#  (('l', 'o', 's', 's', '</w>'), 1),
#  (('A', 'r', 'r', 't', '</w>'), 1),
#  (('m', 'u', 'l', 't', 'i', 'p', 'l', 'i', 'e', 'd', '</w>'), 1),
#  (('r', 's', '</w>'), 1),
#  (('r', 'e', 'f', 'l', 'e', 'c', 't', 'e', 'd', '</w>'), 1),
#  (('e', 'n', 'd', 'l', 'e', 's', 's', '</w>'), 1),
#  (('m', 'i', 'r', 'r', 'o', 'r', 's', '</w>'), 1),
#  (('T', 'h', 'w', 'i', 'n', 'g', 's', '</w>'), 1),
#  (('m', 'o', 'u', 'r', 'n', 'e', 'd', '</w>'), 1),
#  (('H', 'a', 'd', '</w>'), 1),
#  (('e', 'x', 'q', 'u', 'i', 's', 'i', 't', 'e', '</w>'), 1),
#  (('G', 'r', 'a', 'f', 't', 'o', 'n', '</w>'), 1),
#  (('G', 'a', 'l', 'l', 'e', 'r', 'y', '</w>'), 1),
#  (('s', 't', 'o', 'p', 'p', 'e', 'd', '</w>'), 1),
#  (('M', 'o', 'o', 'n', '</w>'), 1),
#  (('d', 'a', 'n', 'c', 'e', 'r', 's', '</w>'), 1),
#  (('W', 'e', '</w>'), 1),
#  (('s', 'h', 'a', 'l', 'l', '</w>'), 1),
#  (('u', 'p', 'o', 'n', '</w>'), 1),
#  (('p', 'r', 'i', 's', 'm', '</w>'), 1),
#  (('e', 'q', 'u', 'a', 'n', 'i', 'm', 'i', 't', 'y', '</w>'), 1),
#  (('f', 'i', 't', 't', 'i', 'n', 'g', '</w>'), 1),
#  (('m', 'o', 'u', 'r', 'n', '</w>'), 1),
#  (('A', 'm', 'o', 'n', 'g', '</w>'), 1),
#  (('s', 'e', 'x', '</w>'), 1),
#  (('f', 'e', 'w', 'e', 'r', '</w>'), 1),
#  (('r', 'e', 'g', 'r', 'e', 't', 's', '</w>'), 1),
#  (('t', 'r', 'a', 'd', 'e', '</w>'), 1),
#  (('h', 'a', 'r', 'd', 'l', 'y', '</w>'), 1),
#  (('m', 'u', 'r', 'm', 'u', 'r', '</w>'), 1),
#  (('P', 'r', 'o', 'f', 'e', 's', 's', 'i', 'o', 'n', 'a', 'l', '</w>'), 1),
#  (('P', 'e', 'r', 'h', 'a', 'p', 's', '</w>'), 1),
#  (('c', 'r', 'a', 'f', 't', '</w>'), 1),
#  (('C', 'l', 'a', 'u', 'd', 'e', '</w>'), 1),
#  (('N', 'u', 't', 'l', 'e', 'y', '</w>'), 1),
#  (('f', 'a', 'i', 't', 'h', '</w>'), 1),
#  (('B', 'u', 'r', 'l', 'i', 'n', 'g', 't', 'o', 'n', '</w>'), 1),
#  (('v', 'e', 'r', 'y', '</w>'), 1),
#  (('o', 'b', 'i', 't', 'u', 'a', 'r', 'y', '</w>'), 1),
#  (('a', 'r', 't', 'i', 'c', 'l', 'e', 's', '</w>'), 1),
#  (('s', 't', 'o', 'c', 'k', 'e', 'd', '</w>'), 1),
#  (('r', 'a', 'n', 'd', 'o', 'm', '</w>'), 1),
#  (('t',
#    'e',
#    'c',
#    'h',
#    'n',
#    'i',
#    'c',
#    'a',
#    'l',
#    'i',
#    't',
#    'i',
#    'e',
#    's',
#    '</w>'),
#   1),
#  (('w', 'o', '</w>'), 1),
#  (('w', 'h', 'o', 'm', '</w>'), 1),
#  (('c', 'o', 'm', 'p', 'a', 'r', 'e', 'd', '</w>'), 1),
#  (('a', 'p', 'p', 'a', 'r', 'e', 'n', 't', 'l', 'y', '</w>'), 1),
#  (('i', 'r', 'r', 'e', 'v', 'o', 'c', 'a', 'b', 'l', 'e', '</w>'), 1),
#  (('d', 'i', 's', 'c', 'u', 's', 's', 'i', 'o', 'n', '</w>'), 1),
#  (('g', 'r', 'a', 'd', 'u', 'a', 'l', 'l', 'y', '</w>'), 1),
#  (('p', 'r', 'e', 'd', 'i', 'c', 't', 'e', 'd', '</w>'), 1),
#  (('p', 'r', 'i', 'c', 'e', '</w>'), 1),
#  (('G', 'i', 's', 'b', 'u', 'r', 'n', 's', '</w>'), 1),
#  (('t', 'h', 'r', 'e', 'e', '</w>'), 1),
#  (('f', 'e', 'w', '</w>'), 1),
#  (('i', 'd', 'l', 'i', 'n', 'g', '</w>'), 1),
#  (('o', 'c', 'c', 'u', 'r', 'r', 'e', 'd', '</w>'), 1),
#  (('O', 'n', '</w>'), 1),
#  (('r', 'e', 'f', 'l', 'e', 'c', 't', 'i', 'o', 'n', '</w>'), 1),
#  (('t', 'e', 'm', 'p', 't', 'i', 'n', 'g', '</w>'), 1),
#  (('p', 'r', 'o', 'b', 'l', 'e', 'm', '</w>'), 1),
#  (('a', 'c', 'c', 'u', 's', 'e', '</w>'), 1),
#  (('e', 'a', 's', 'y', '</w>'), 1),
#  (('f', 'a', 'i', 'r', '</w>'), 1),
#  (('d', 'e', 'n', 'i', 'e', 'd', '</w>'), 1),
#  (('s', 'o', 'l', 'a', 'c', 'e', '</w>'), 1),
#  (('s', 'a', 'y', 'i', 'n', 'g', '</w>'), 1),
#  (('e', 'x', 'i', 's', 't', 'e', 'd', '</w>'), 1),
#  (('n', 'e', 'a', 'r', 'l', 'y', '</w>'), 1),
#  (('y', 'e', 'a', 'r', '</w>'), 1),
#  (('e', 'a', 's', 'e', '</w>'), 1),
#  (('p', 'r', 'o', 'v', 'e', '</w>'), 1),
#  (('e', 'q', 'u', 'a', 'l', 'l', 'y', '</w>'), 1),
#  (('c', 'o', 'n', 't', 'e', 'n', 'd', 'e', 'd', '</w>'), 1),
#  (('l', 'e', 'd', '</w>'), 1),
#  (('v', 'o', 'c', 'a', 't', 'i', 'o', 'n', '</w>'), 1),
#  (('a', 'p', 'p', 'e', 'a', 'r', 'e', 'd', '</w>'), 1),
#  (('d', 'i', 's', 'd', 'a', 'i', 'n', 'e', 'd', '</w>'), 1),
#  (('f', 'i', 'n', 'd', '</w>'), 1),
#  (('d', 'e', 's', 'u', 'l', 't', 'o', 'r', 'y', '</w>'), 1),
#  (('l', 'e', 'n', 'd', 's', '</w>'), 1),
#  (('i', 't', 's', 'e', 'l', 'f', '</w>'), 1),
#  (('p', 'u', 'r', 'e', 'l', 'y', '</w>'), 1),
#  (('a', 'c', 'a', 'd', 'e', 'm', 'i', 'c', '</w>'), 1),
#  (('s', 'p', 'e', 'c', 'u', 'l', 'a', 't', 'i', 'o', 'n', 's', '</w>'), 1),
#  (('g', 'l', 'i', 'm', 'p', 's', 'e', '</w>'), 1),
#  (('b', 'a', 'l', 'u', 's', 't', 'r', 'a', 'd', 'e', 'd', '</w>'), 1),
#  (('t', 'e', 'r', 'r', 'a', 'c', 'e', 's', '</w>'), 1),
#  (('p', 'i', 'n', 'e', 's', '</w>'), 1),
#  (('b', 'o', 'r', 'n', 'e', '</w>'), 1),
#  (('t', 'h', 'i', 't', 'h', 'e', 'r', '</w>'), 1),
#  (('c', 'o', 'u', 'p', 'l', 'e', '</w>'), 1),
#  (('t', 'e', 'a', '</w>'), 1),
#  (('p', 'a', 'l', 'm', '</w>'), 1),
#  (('t', 'r', 'e', 'e', 's', '</w>'), 1),
#  (('w', 'e', 'l', 'c', 'o', 'm', 'e', '</w>'), 1),
#  (('g', 'e', 'n', 'i', 'a', 'l', '</w>'), 1),
#  (('e', 'n', 's', 'u', 'i', 'n', 'g', '</w>'), 1),
#  (('c', 'l', 'a', 'i', 'm', 'e', 'd', '</w>'), 1),
#  (('f', 'r', 'e', 'q', 'u', 'e', 'n', 't', 'l', 'y', '</w>'), 1),
#  (('f', 'u', 'l', 'l', 'e', 's', 't', '</w>'), 1),
#  (('r', 'e', 'a', 's', 's', 'u', 'r', 'a', 'n', 'c', 'e', '</w>'), 1),
#  (('m', 'a', 'y', '</w>'), 1),
#  (('p', 'a', 'r', 'd', 'o', 'n', 'e', 'd', '</w>'), 1),
#  (('b', 'u', 'l', 'l', '</w>'), 1),
#  (('s', 'u', 'r', 'r', 'o', 'u', 'n', 'd', 'e', 'd', '</w>'), 1),
#  (('f', 'o', 's', 't', 'e', 'r', 'e', 'd', '</w>'), 1),
#  (('r', 'e', 'a', 'r', 'e', 'd', '</w>'), 1),
#  (('h', 'o', 't', '</w>'), 1),
#  (('a', 'd', 'u', 'l', 'a', 't', 'i', 'o', 'n', '</w>'), 1),
#  (('t', 'h', 'e', 'r', 'e', 'f', 'o', 'r', 'e', '</w>'), 1),
#  (('i', 'n', 's', 't', 'r', 'u', 'c', 't', 'i', 'v', 'e', '</w>'), 1),
#  (('e', 'f', 'f', 'e', 'c', 't', '</w>'), 1),
#  (('d', 'e', 'a', 'd', 'e', 'n', 'i', 'n', 'g', '</w>'), 1),
#  (('a', 't', 'm', 'o', 's', 'p', 'h', 'e', 'r', 'e', '</w>'), 1),
#  (('m', 'e', 'd', 'i', 'o', 'c', 'r', 'i', 't', 'y', '</w>'), 1),
#  (('q', 'u', 'o', 't', 'e', '</w>'), 1),
#  (('m', 'e', 'n', 't', 'i', 'o', 'n', 'e', 'd', '</w>'), 1),
#  (('i', 'm', 'm', 'e', 'd', 'i', 'a', 't', 'e', 'l', 'y', '</w>'), 1),
#  (('p', 'e', 'r', 'c', 'e', 'p', 't', 'i', 'b', 'l', 'e', '</w>'), 1),
#  (('e', 'x', 't', 'r', 'a', 'c', 't', 'i', 'n', 'g', '</w>'), 1),
#  (('c', 'i', 'r', 'c', 'u', 'm', 's', 't', 'a', 'n', 'c', 'e', '</w>'), 1),
#  (('s', 'u', 'b', 's', 't', 'a', 'n', 't', 'i', 'a', 'l', '</w>'), 1),
#  (('r', 'u', 'l', 'e', '</w>'), 1),
#  (('s', 'c', 'o', 'r', 'n', '</w>'), 1),
#  (('m', 'o', 'n', 'e', 'y', '</w>'), 1),
#  (('e', 'l', 'e', 'g', 'a', 'n', 't', '</w>'), 1),
#  (('d', 'i', 's', 'd', 'a', 'i', 'n', '</w>'), 1),
#  (('b', 'i', 'g', '</w>'), 1),
#  (('b', 'a', 'l', 'a', 'n', 'c', 'e', '</w>'), 1),
#  (('e', 'n', 'a', 'b', 'l', 'e', 'd', '</w>'), 1),
#  (('a', 'p', 'p', 'e', 'a', 'r', 'a', 'n', 'c', 'e', '</w>'), 1),
#  (('p', 'e', 'r', 'f', 'e', 'c', 't', '</w>'), 1),
#  (('b', 'r', 'e', 'e', 'd', 'i', 'n', 'g', '</w>'), 1),
#  (('t', 'r', 'a', 'n', 's', 'm', 'u', 't', 'e', '</w>'), 1),
#  (('l', 'u', 'x', 'u', 'r', 'y', '</w>'), 1),
#  (('a', 'd', 'd', '</w>'), 1),
#  (('r', 'e', 'm', 'a', 'i', 'n', 'e', 'd', '</w>'), 1),
#  (('r', 'e', 'l', 'a', 't', 'i', 'v', 'e', 'l', 'y', '</w>'), 1),
#  (('i', 'n', 'd', 'i', 'f', 'f', 'e', 'r', 'e', 'n', 't', '</w>'), 1),
#  (('b', 'u', 'y', 'i', 'n', 'g', '</w>'), 1),
#  (('R', 'e', 'n', 'a', 'i', 's', 's', 'a', 'n', 'c', 'e', '</w>'), 1),
#  (('b', 'r', 'o', 'n', 'z', 'e', 's', '</w>'), 1),
#  (('d',
#    'i',
#    's',
#    'c',
#    'r',
#    'i',
#    'm',
#    'i',
#    'n',
#    'a',
#    't',
#    'i',
#    'o',
#    'n',
#    '</w>'),
#   1),
#  (('b', 'e', 's', 'p', 'o', 'k', 'e', '</w>'), 1),
#  (('a', 'm', 'p', 'l', 'e', 's', 't', '</w>'), 1),
#  (('r', 'e', 's', 'o', 'u', 'r', 'c', 'e', 's', '</w>'), 1),
#  (('M', 'o', 'n', 'e', 'y', '</w>'), 1),
#  (('e', 'x', 'c', 'u', 's', 'e', '</w>'), 1),
#  (('c', 'i', 'r', 'c', 'u', 'l', 'a', 't', 'i', 'o', 'n', '</w>'), 1),
#  (('a', 'x', 'i', 'o', 'm', 's', '</w>'), 1),
#  (('a', 'c', 'r', 'o', 's', 's', '</w>'), 1),
#  (('S', 'e', 'v', 'r', 'e', 's', '</w>'), 1),
#  (('s', 'i', 'l', 'v', 'e', 'r', '</w>'), 1),
#  (('e', 'x', 'q', 'u', 'i', 's', 'i', 't', 'e', 'l', 'y', '</w>'), 1),
#  (('a', 'p', 'p', 'o', 'i', 'n', 't', 'e', 'd', '</w>'), 1),
#  (('l', 'u', 'n', 'c', 'h', 'e', 'o', 'n', '</w>'), 1),
#  (('r', 'u', 'n', '</w>'), 1),
#  (('b', 'e', 'a', 'm', 'i', 'n', 'g', '</w>'), 1),
#  (('e', 'n', 'l', 'i', 'g', 'h', 't', 'e', 'n', 'm', 'e', 'n', 't', '</w>'),
#   1),
#  (('m', 'o', 'r', 'b', 'i', 'd', 'l', 'y', '</w>'), 1),
#  (('s', 'e', 'n', 's', 'i', 't', 'i', 'v', 'e', '</w>'), 1),
#  (('f', 'o', 'r', 'm', '</w>'), 1),
#  (('f', 'a', 't', 'e', '</w>'), 1),
#  (('e', 'x', 't', 'e', 'n', 'u', 'a', 't', 'i', 'o', 'n', '</w>'), 1),
#  (('r', 'e', 's', 'e', 'n', 't', 'e', 'd', '</w>'), 1),
#  (('o', 'f', 't', 'e', 'n', '</w>'), 1),
#  (('b', 'a', 's', 'k', 'i', 'n', 'g', '</w>'), 1),
#  (('s', 'i', 'm', 'i', 'l', 'a', 'r', '</w>'), 1),
#  (('t', 'r', 'i', 'b', 'u', 't', 'e', 's', '</w>'), 1),
#  (('c', 'o', 'n', 'j', 'u', 'g', 'a', 'l', '</w>'), 1),
#  (('r', 'o', 'b', 'b', 'e', 'd', '</w>'), 1),
#  (('s', 'a', 'v', 'o', 'u', 'r', '</w>'), 1),
#  (('N', 'o', '</w>'), 1),
#  (('o', 'd', 'd', 'l', 'y', '</w>'), 1),
#  (('a', 'p', 'p', 'a', 'r', 'e', 'n', 't', '</w>'), 1),
#  (('a', 't', 't', 'i', 't', 'u', 'd', 'e', '</w>'), 1),
#  (('g', 'a', 'r', 'l', 'a', 'n', 'd', 's', '</w>'), 1),
#  (('i', 'n', 'c', 'e', 'n', 's', 'e', '</w>'), 1),
#  (('s', 't', 'u', 'f', 'f', '</w>'), 1),
#  (('p', 'r', 'o', 't', 'e', 's', 't', '</w>'), 1),
#  (('s', 't', 'r', 'o', 'l', 'l', 'e', 'd', '</w>'), 1),
#  (('o', 'n', 't', 'o', '</w>'), 1),
#  (('s', 'u', 'n', 'l', 'i', 't', '</w>'), 1),
#  (('b', 'e', 'c', 'o', 'm', 'i', 'n', 'g', '</w>'), 1),
#  (('h', 'o', 'u', 'r', '</w>'), 1),
#  (('y', 'o', 'u', 'n', 'g', 'e', 'r', '</w>'), 1),
#  (('a', 'r', 't', 'i', 's', 't', '</w>'), 1),
#  (('f', 'o', 'r', 'm', 'e', 'd', '</w>'), 1),
#  (('f', 'r', 'i', 'e', 'n', 'd', '</w>'), 1),
#  (('f', 'e', 'e', 't', '</w>'), 1),
#  (('w', 'o', 'n', 'd', 'e', 'r', 'e', 'd', '</w>'), 1),
#  (('t', 'i', 'n', 'g', 'e', '</w>'), 1),
#  (('u', 'n', 'd', 'e', 'r', 'l', 'a', 'y', '</w>'), 1),
#  (('m', 'y', 's', 't', 'e', 'r', 'i', 'o', 'u', 's', '</w>'), 1),
#  (('e', 'v', 'e', 'n', 't', '</w>'), 1),
#  (('b', 'e', 'g', 'u', 'n', '</w>'), 1),
#  (('G', 'r', 'i', 'n', 'd', 'l', 'e', 's', '</w>'), 1),
#  (('l', 'i', 'n', 'g', 'e', 'r', 'e', 'd', '</w>'), 1),
#  (('l', 'u', 'm', 'p', '</w>'), 1),
#  (('s', 'u', 'g', 'a', 'r', '</w>'), 1),
#  (('s', 'p', 'a', 'n', 'i', 'e', 'l', '</w>'), 1),
#  (('d', 'i', 'n', 'i', 'n', 'g', '</w>'), 1),
#  (('h', 'a', 's', '</w>'), 1),
#  (('a', 'b', 'r', 'u', 'p', 't', 'l', 'y', '</w>'), 1),
#  (('r', 'a', 'i', 's', 'e', 'd', '</w>'), 1),
#  (('e', 'y', 'e', 'b', 'r', 'o', 'w', 's', '</w>'), 1),
#  (('h', 'i', 'n', 't', '</w>'), 1),
#  (('e', 'n', 'j', 'o', 'y', '</w>'), 1),
#  (('s', 'p', 'a', 'c', 'i', 'o', 'u', 's', '</w>'), 1),
#  (('p', 'a', 'n', 'e', 'l', 'l', 'e', 'd', '</w>'), 1),
#  (('f', 'a', 'm', 'i', 'l', 'l', 'e', '</w>'), 1),
#  (('v', 'e', 'r', 't', 'e', '</w>'), 1),
#  (('v', 'a', 's', 'e', 's', '</w>'), 1),
#  (('r', 'e', 'p', 'e', 'a', 't', 'i', 'n', 'g', '</w>'), 1),
#  (('t', 'o', 'n', 'e', 's', '</w>'), 1),
#  (('d', 'a', 'm', 'a', 's', 'k', '</w>'), 1),
#  (('p', 'a', 's', 't', 'e', 'l', 's', '</w>'), 1),
#  (('f', 'a', 'd', 'e', 'd', '</w>'), 1),
#  (('f', 'r', 'a', 'm', 'e', 's', '</w>'), 1),
#  (('H', 'a', 's', '</w>'), 1),
#  (('s', 'i', 'n', 'g', 'l', 'e', '</w>'), 1),
#  (('s', 'l', 'i', 'g', 'h', 't', '</w>'), 1),
#  (('s', 'h', 'a', 'd', 'e', '</w>'), 1),
#  (('c', 'o', 'n', 's', 't', 'r', 'a', 'i', 'n', 't', '</w>'), 1),
#  (('c', 'r', 'o', 's', 's', 'e', 'd', '</w>'), 1),
#  (('o', 'p', 'e', 'n', '</w>'), 1),
#  (('c', 'o', 'u', 'n', 't', 'e', 'n', 'a', 'n', 'c', 'e', '</w>'), 1),
#  (('f', 'i', 't', '</w>'), 1),
#  (('e', 'x', 'c', 'e', 'p', 't', '</w>'), 1),
#  (('k', 'e', 'e', 'p', '</w>'), 1),
#  (('u', 'p', 's', 't', 'a', 'i', 'r', 's', '</w>'), 1),
#  (('g', 'r', 'o', 'w', 'i', 'n', 'g', '</w>'), 1),
#  (('b', 'e', 'a', 'n', '</w>'), 1),
#  (('s', 't', 'a', 'l', 'k', '</w>'), 1),
#  (('p', 'e', 'r', 's', 'u', 'a', 's', 'i', 'v', 'e', 'l', 'y', '</w>'), 1),
#  (('a', 'l', 'm', 'o', 's', 't', '</w>'), 1),
#  (('t', 'i', 'm', 'o', 'r', 'o', 'u', 's', 'l', 'y', '</w>'), 1),
#  (('l', 'o', 'u', 'n', 'g', 'i', 'n', 'g', '</w>'), 1),
#  (('h', 'o', 'o', 'd', 'e', 'd', '</w>'), 1),
#  (('l', 'i', 't', '</w>'), 1),
#  (('c', 'i', 'g', 'a', 'r', '</w>'), 1),
#  (('d', 'r', 'a', 'w', 'n', '</w>'), 1),
#  (('R', 'u', 's', 's', 'i', 'a', 'n', '</w>'), 1),
#  (('d', 'e', 'e', 'r', 'h', 'o', 'u', 'n', 'd', '</w>'), 1),
#  (('k', 'n', 'e', 'e', 's', '</w>'), 1),
#  (('w', 'h', 'i', 'l', 'e', '</w>'), 1),
#  (('h', 'i', 'd', 'e', '</w>'), 1),
#  (('n', 'e', 'r', 'v', 'o', 'u', 's', 'n', 'e', 's', 's', '</w>'), 1),
#  (('m', 'a', 'r', 'b', 'l', 'e', '</w>'), 1),
#  (('E', 'm', 'p', 'e', 'r', 'o', 'r', 's', '</w>'), 1),
#  (('h', 'a', 'l', 'l', '</w>'), 1),
#  (('w', 'i', 'd', 'e', '</w>'), 1),
#  (('s', 't', 'a', 'i', 'r', 's', '</w>'), 1),
#  (('t', 'e', 'r', 'r', 'a', '</w>'), 1),
#  (('c', 'o', 't', 't', 'a', '</w>'), 1),
#  (('n', 'y', 'm', 'p', 'h', 's', '</w>'), 1),
#  (('p', 'o', 'i', 's', 'e', 'd', '</w>'), 1),
#  (('f', 'l', 'o', 'w', 'e', 'r', 's', '</w>'), 1),
#  (('e', 'a', 'c', 'h', '</w>'), 1),
#  (('l', 'a', 'n', 'd', 'i', 'n', 'g', '</w>'), 1),
#  (('I', 'n', '</w>'), 1),
#  (('d', 'i', 'm', 'm', 'e', 's', 't', '</w>'), 1),
#  (('c', 'o', 'r', 'n', 'e', 'r', '</w>'), 1),
#  (('b', 'o', 'u', 'd', 'o', 'i', 'r', '</w>'), 1),
#  (('a', 'm', 'i', 'd', '</w>'), 1),
#  (('p', 'r', 'o', 'f', 'u', 's', 'i', 'o', 'n', '</w>'), 1),
#  (('d', 'i', 's', 't', 'i', 'n', 'g', 'u', 'i', 's', 'h', 'e', 'd', '</w>'),
#   1),
#  (('f', 'a', 'm', 'i', 'l', 'i', 'a', 'r', '</w>'), 1),
#  (('o', 'v', 'a', 'l', '</w>'), 1),
#  (('c', 'a', 'n', 'v', 'a', 's', 'e', 's', '</w>'), 1),
#  (('i', 'n', 'e', 'v', 'i', 't', 'a', 'b', 'l', 'e', '</w>'), 1),
#  (('g', 'a', 'r', 'l', 'a', 'n', 'd', 'e', 'd', '</w>'), 1),
#  (('m', 'e', 'r', 'e', '</w>'), 1),
#  (('o', 'u', 't', 'l', 'i', 'n', 'e', '</w>'), 1),
#  (('d', 'r', 'e', 'w', '</w>'), 1),
#  (('w', 'i', 'n', 'd', 'o', 'w', '</w>'), 1),
#  (('a', 's', 'i', 'd', 'e', '</w>'), 1),
#  (('j', 'a', 'r', 'd', 'i', 'n', 'i', 'e', 'r', 'e', '</w>'), 1),
#  (('f', 'u', 'l', 'l', '</w>'), 1),
#  (('p', 'i', 'n', 'k', '</w>'), 1),
#  (('a', 'z', 'a', 'l', 'e', 'a', 's', '</w>'), 1),
#  (('s', 't', 'r', 'a', 'i', 'n', '</w>'), 1),
#  (('U', 's', 'u', 'a', 'l', 'l', 'y', '</w>'), 1),
#  (('c', 'e', 'n', 't', 'r', 'a', 'l', '</w>'), 1),
#  (('p', 'a', 'n', 'e', 'l', '</w>'), 1),
#  (('y', 'e', 'l', 'l', 'o', 'w', '</w>'), 1),
#  (('m', 'o', 'n', 'u', 'm', 'e', 'n', 't', 'a', 'l', '</w>'), 1),
#  (('t', 'o', 'o', 'k', '</w>'), 1),
#  (('V', 'e', 'n', 'e', 't', 'i', 'a', 'n', '</w>'), 1),
#  (('m', 'o', 'd', 'e', 's', 't', '</w>'), 1),
#  (('a', 'c', 'c', 'u', 's', 't', 'o', 'm', 'e', 'd', '</w>'), 1),
#  (('c',
#    'h',
#    'a',
#    'r',
#    'a',
#    'c',
#    't',
#    'e',
#    'r',
#    'i',
#    's',
#    't',
#    'i',
#    'c',
#    '</w>'),
#   1),
#  (('q', 'u', 'a', 'l', 'i', 't', 'i', 'e', 's', '</w>'), 1),
#  (('c', 'a', 'm', 'e', '</w>'), 1),
#  (('h', 'e', 's', 'i', 't', 'a', 't', 'i', 'o', 'n', 's', '</w>'), 1),
#  (('d', 'i', 's', 'g', 'u', 'i', 's', 'e', 'd', '</w>'), 1),
#  (('a', 'u', 'd', 'a', 'c', 'i', 't', 'i', 'e', 's', '</w>'), 1),
#  (('p',
#    'r',
#    'e',
#    's',
#    't',
#    'i',
#    'd',
#    'i',
#    'g',
#    'i',
#    't',
#    'a',
#    't',
#    'i',
#    'o',
#    'n',
#    '</w>'),
#   1),
#  (('c', 'o', 'n', 's', 'u', 'm', 'm', 'a', 't', 'e', '</w>'), 1),
#  (('s', 'k', 'i', 'l', 'l', '</w>'), 1),
#  (('m', 'a', 'n', 'a', 'g', 'e', 'd', '</w>'), 1),
#  (('d', 'i', 'v', 'e', 'r', 't', '</w>'), 1),
#  (('r', 'e', 'a', 'l', '</w>'), 1),
#  (('b', 'u', 's', 'i', 'n', 'e', 's', 's', '</w>'), 1),
#  (('p', 'r', 'e', 't', 't', 'y', '</w>'), 1),
#  (('i', 'r', 'r', 'e', 'l', 'e', 'v', 'a', 'n', 'c', 'e', '</w>'), 1),
#  (('d', 'e', 't', 'a', 'i', 'l', '</w>'), 1),
#  (('p', 'r', 'e', 's', 'e', 'n', 't', 'i', 'n', 'g', '</w>'), 1),
#  (('n', 'e', 'u', 't', 'r', 'a', 'l', '</w>'), 1),
#  (('s', 'u', 'r', 'f', 'a', 'c', 'e', '</w>'), 1),
#  (('f', 'o', 'r', 'm', 'i', 'n', 'g', '</w>'), 1),
#  (('i', 'n', 'e', 'v', 'i', 't', 'a', 'b', 'l', 'y', '</w>'), 1),
#  (('b', 'a', 'c', 'k', 'g', 'r', 'o', 'u', 'n', 'd', '</w>'), 1),
#  (('l', 'e', 'n', 't', '</w>'), 1),
#  (('u', 'n', 'u', 's', 'u', 'a', 'l', '</w>'), 1),
#  (('f', 'a', 'l', 's', 'e', '</w>'), 1),
#  (('v', 'i', 'r', 't', 'u', 'o', 's', 'i', 't', 'y', '</w>'), 1),
#  (('s', 't', 'r', 'o', 'n', 'g', 'e', 's', 't', '</w>'), 1),
#  (('a', 'd', 'm', 'i', 'r', 'e', 'r', 's', '</w>'), 1),
#  (('r', 'e', 'p', 'r', 'e', 's', 'e', 'n', 't', 'e', 'd', '</w>'), 1),
#  (('p', 'a', 'r', 't', '</w>'), 1),
#  (('s', 'w', 'e', 'l', 'l', 'i', 'n', 'g', '</w>'), 1),
#  (('m', 'u', 's', 'c', 'l', 'e', 's', '</w>'), 1),
#  (('c', 'o', 'n', 'g', 'e', 's', 't', 'i', 'n', 'g', '</w>'), 1),
#  (('v', 'e', 'i', 'n', 's', '</w>'), 1),
#  (('b', 'a', 'l', 'a', 'n', 'c', 'i', 'n', 'g', '</w>'), 1),
#  (('s', 't', 'r', 'a', 'd', 'd', 'l', 'i', 'n', 'g', '</w>'), 1),
#  (('s', 't', 'r', 'a', 'i', 'n', 'i', 'n', 'g', '</w>'), 1),
#  (('r', 'e', 'm', 'i', 'n', 'd', 'e', 'd', '</w>'), 1),
#  (('c', 'i', 'r', 'c', 'u', 's', '</w>'), 1),
#  (('c', 'l', 'o', 'w', 'n', '</w>'), 1),
#  (('i', 'r', 'o', 'n', 'i', 'c', '</w>'), 1),
#  (('e', 'f', 'f', 'o', 'r', 't', 's', '</w>'), 1),
#  (('f', 'e', 'a', 't', 'h', 'e', 'r', '</w>'), 1),
#  (('s', 'h', 'o', 'r', 't', '</w>'), 1),
#  (('d', 'e', 'm', 'a', 'n', 'd', '</w>'), 1),
#  (('l', 'o', 'v', 'e', 'l', 'y', '</w>'), 1),
#  (('s', 't', 'r', 'o', 'n', 'g', 'l', 'y', '</w>'), 1),
#  (('l', 'o', 's', 'e', '</w>'), 1),
#  (('a', 't', 'o', 'm', '</w>'), 1),
#  (('s', 'w', 'e', 'e', 't', 'n', 'e', 's', 's', '</w>'), 1),
#  (('p', 'a', 'r', 'd', 'o', 'n', 'a', 'b', 'l', 'e', '</w>'), 1),
#  (('c', 'o', 'r', 'r', 'e', 'c', 't', 'e', 'd', '</w>'), 1),
#  (('c', 'o', 'u', 'n', 't', '</w>'), 1),
#  (('d', 'e', 's', 't', 'r', 'o', 'y', 'e', 'd', '</w>'), 1),
#  (('D', 'e', 's', 't', 'r', 'o', 'y', 'e', 'd', '</w>'), 1),
#  (('f', 'o', 'l', 'l', 'o', 'w', '</w>'), 1),
#  (('c', 'l', 'u', 'e', '</w>'), 1),
#  (('f', 'o', 'o', 't', 's', 't', 'e', 'p', '</w>'), 1),
#  (('t', 'h', 'r', 'e', 's', 'h', 'o', 'l', 'd', '</w>'), 1),
#  (('A', 's', '</w>'), 1),
#  (('h', 'a', 'n', 'd', 's', '</w>'), 1),
#  (('p', 'o', 'c', 'k', 'e', 't', 's', '</w>'), 1),
#  (('v', 'e', 'l', 'v', 'e', 't', 'e', 'e', 'n', '</w>'), 1),
#  (('c', 'o', 'a', 't', '</w>'), 1),
#  (('t', 'h', 'i', 'n', '</w>'), 1),
#  (('w', 'a', 'v', 'e', 's', '</w>'), 1),
#  (('h', 'a', 'i', 'r', '</w>'), 1),
#  (('f', 'o', 'r', 'e', 'h', 'e', 'a', 'd', '</w>'), 1),
#  (('l', 'e', 'a', 'n', '</w>'), 1),
#  (('s', 'u', 'n', 'b', 'u', 'r', 'n', 't', '</w>'), 1),
#  (('f', 'u', 'r', 'r', 'o', 'w', 'e', 'd', '</w>'), 1),
#  (('l', 'i', 'f', 't', 'e', 'd', '</w>'), 1),
#  (('t', 'i', 'p', 's', '</w>'), 1),
#  (('s', 'e', 'l', 'f', '</w>'), 1),
#  (('m', 'o', 'u', 's', 't', 'a', 'c', 'h', 'e', '</w>'), 1),
#  (('s', 'a', 'm', 'e', '</w>'), 1),
#  (('c', 'l', 'e', 'v', 'e', 'r', 'e', 'r', '</w>'), 1),
#  (('d', 'e', 'p', 'r', 'e', 'c', 'a', 't', 'i', 'n', 'g', 'l', 'y', '</w>'),
#   1),
#  (('t', 'r', 'a', 'v', 'e', 'l', 'l', 'e', 'd', '</w>'), 1),
#  (('e', 'x', 'c', 'u', 's', 'i', 'n', 'g', '</w>'), 1),
#  (('s', 'h', 'r', 'u', 'g', 'g', 'e', 'd', '</w>'), 1),
#  (('s', 'h', 'o', 'u', 'l', 'd', 'e', 'r', 's', '</w>'), 1),
#  (('s', 'm', 'i', 'l', 'i', 'n', 'g', '</w>'), 1),
#  (('l', 'o', 'n', 'g', '</w>'), 1),
#  (('a', 'g', 'o', '</w>'), 1),
#  (('l', 'i', 'g', 'h', 't', 'l', 'y', '</w>'), 1),
#  (('p', 'a', 's', 's', 'i', 'n', 'g', '</w>'), 1),
#  (('C', 'o', 'm', 'e', '</w>'), 1),
#  (('s', 'h', 'o', 'w', 'e', 'd', '</w>'), 1),
#  (('n', 'a', 'i', 'v', 'e', '</w>'), 1),
#  (('s', 'u', 'b', 'u', 'r', 'b', 'a', 'n', '</w>'), 1),
#  (('b', 'a', 't', 'h', '</w>'), 1),
#  (('s', 'p', 'e', 'a', 'k', 'i', 'n', 'g', '</w>'), 1),
#  (('t', 'u', 'b', 'e', 's', '</w>'), 1),
#  (('d', 'r', 'e', 's', 's', '</w>'), 1),
#  (('c', 'l', 'o', 's', 'e', 't', 's', '</w>'), 1),
#  (('t', 'r', 'o', 'u', 's', 'e', 'r', '</w>'), 1),
#  (('p', 'r', 'e', 's', 's', 'e', 's', '</w>'), 1),
#  (('c', 'o', 'm', 'p', 'l', 'e', 'x', '</w>'), 1),
#  (('s',
#    'i',
#    'm',
#    'p',
#    'l',
#    'i',
#    'f',
#    'i',
#    'c',
#    'a',
#    't',
#    'i',
#    'o',
#    'n',
#    's',
#    '</w>'),
#   1),
#  (('m', 'i', 'l', 'l', 'i', 'o', 'n', 'a', 'i', 'r', 'e', '</w>'), 1),
#  (('d', 'o', 'm', 'e', 's', 't', 'i', 'c', '</w>'), 1),
#  (('e', 'c', 'o', 'n', 'o', 'm', 'y', '</w>'), 1),
#  (('w', 'h', 'e', 'n', 'e', 'v', 'e', 'r', '</w>'), 1),
#  (('p', 'a', 'i', 'd', '</w>'), 1),
#  (('e', 'x', 'p', 'e', 'c', 't', 'e', 'd', '</w>'), 1),
#  (('t', 'r', 'i', 'b', 'u', 't', 'e', '</w>'), 1),
#  (('t', 'h', 'r', 'o', 'w', 'i', 'n', 'g', '</w>'), 1),
#  (('c', 'h', 'e', 's', 't', '</w>'), 1),
#  (('l', 'i', 'v', 'e', '</w>'), 1),
#  (('f', 'o', 'r', 'e', 's', 'e', 'e', 'n', '</w>'), 1),
#  (('c', 'h', 'a', 'r', 'm', 'i', 'n', 'g', '</w>'), 1),
#  (('d', 'i', 's', 'a', 'r', 'm', 'i', 'n', 'g', '</w>'), 1),
#  (('l', 'e', 'i', 's', 'u', 'r', 'e', '</w>'), 1),
#  (('d', 'i', 'a', 'g', 'n', 'o', 's', 'i', 's', '</w>'), 1),
#  (('s', 'u', 'f', 'f', 'e', 'r', 'e', 'd', '</w>'), 1),
#  (('c', 'h', 'e', 'c', 'k', '</w>'), 1),
#  (('T', 'h', 'i', 's', '</w>'), 1),
#  (('l', 'a', 'i', 'r', '</w>'), 1),
#  (('l', 'e', 'a', 'd', 'i', 'n', 'g', '</w>'), 1),
#  (('d', 'a', 'r', 'k', '</w>'), 1),
#  (('f', 'l', 'o', 'r', 'i', 'd', '</w>'), 1),
#  (('s', 'q', 'u', 'a', 'r', 'e', '</w>'), 1),
#  (('l', 'e', 'a', 't', 'h', 'e', 'r', 'y', '</w>'), 1),
#  (('e', 'f', 'f', 'e', 'c', 't', 's', '</w>'), 1),
#  (('b', 'r', 'i', 'c', '</w>'), 1),
#  (('b', 'r', 'a', 'c', '</w>'), 1),
#  (('n', 'o', 'n', 'e', '</w>'), 1),
#  (('a', 'i', 'r', '</w>'), 1),
#  (('r', 'e', 'p', 'r', 'o', 'd', 'u', 'c', 't', 'i', 'o', 'n', '</w>'), 1),
#  (('w', 'e', 'e', 'k', 'l', 'y', '</w>'), 1),
#  (('l', 'e', 'a', 's', 't', '</w>'), 1),
#  (('s', 'i', 'g', 'n', '</w>'), 1),
#  (('u', 's', 'e', 'd', '</w>'), 1),
#  (('s', 't', 'u', 'd', 'i', 'o', '</w>'), 1),
#  (('h', 'o', 'm', 'e', '</w>'), 1),
#  (('a', 'b', 's', 'o', 'l', 'u', 't', 'e', '</w>'), 1),
#  (('f', 'i', 'n', 'a', 'l', 'i', 't', 'y', '</w>'), 1),
#  (('b', 'r', 'e', 'a', 'k', '</w>'), 1),
#  (('t', 'r', 'a', 'c', 'e', '</w>'), 1),
#  (('a', 'c', 't', 'i', 'v', 'i', 't', 'y', '</w>'), 1),
#  (('b', 'r', 'i', 'e', 'f', 'l', 'y', '</w>'), 1),
#  (('O', 'r', '</w>'), 1),
#  (('w', 'a', 't', 'e', 'r', '</w>'), 1),
#  (('e', 't', 'c', 'h', 'i', 'n', 'g', '</w>'), 1),
#  (('d', 'i', 'm', '</w>'), 1),
#  (('p', 'a', 'l', 'e', 'd', '</w>'), 1),
#  (('s', 'u', 'n', 'b', 'u', 'r', 'n', '</w>'), 1),
#  (('t', 'o', 'u', 'c', 'h', 'e', 'd', '</w>'), 1),
#  (('f', 'l', 'a', 's', 'h', '</w>'), 1),
#  (('e', 'm', 'b', 'a', 'r', 'r', 'a', 's', 's', 'e', 'd', '</w>'), 1),
#  (('d', 'i', 's', 'c', 'o', 'v', 'e', 'r', 'y', '</w>'), 1),
#  (('e', 'y', 'e', '</w>'), 1),
#  (('f', 'e', 'l', 'l', '</w>'), 1),
#  (('s', 'm', 'a', 'l', 'l', '</w>'), 1),
#  (('b', 'r', 'e', 'a', 'k', 'i', 'n', 'g', '</w>'), 1),
#  (('o', 'a', 'k', '</w>'), 1),
#  (('p', 'a', 'n', 'e', 'l', 'l', 'i', 'n', 'g', '</w>'), 1),
#  (('s', 't', 'a', 'n', 'd', 'i', 'n', 'g', '</w>'), 1),
#  (('r', 'a', 'i', 'n', '</w>'), 1),
#  (('c', 'r', 'i', 'e', 'd', '</w>'), 1),
#  (('s', 'i', 'l', 'e', 'n', 't', '</w>'), 1),
#  (('b', 'r', 'e', 'a', 't', 'h', 'i', 'n', 'g', '</w>'), 1),
#  (('q', 'u', 'i', 'c', 'k', 'l', 'y', '</w>'), 1),
#  (('M', 'a', 'd', 'e', '</w>'), 1),
#  (('d', 'o', 'z', 'e', 'n', '</w>'), 1),
#  (('l', 'i', 'n', 'e', 's', '</w>'), 1),
#  (('l', 'u', 'c', 'k', 'y', '</w>'), 1),
#  (('c', 'h', 'a', 'p', '</w>'), 1),
#  (('s', 'l', 'o', 'w', 'l', 'y', '</w>'), 1),
#  (('g', 'a', 'v', 'e', '</w>'), 1),
#  (('i', 'n', 'f', 'l', 'e', 'x', 'i', 'b', 'l', 'e', '</w>'), 1),
#  (('h', 'e', 'r', 'm', 'i', 't', '</w>'), 1),
#  (('a', 'm', 'a', 'z', 'e', 'm', 'e', 'n', 't', '</w>'), 1),
#  (('e', 's', 'c', 'a', 'p', 'e', '</w>'), 1),
#  (('a', 'w', 'f', 'u', 'l', '</w>'), 1),
#  (('s', 'i', 'm', 'p', 'l', 'e', 't', 'o', 'n', '</w>'), 1),
#  (('H', 'e', 'r', '</w>'), 1),
#  (('a', 'h', '</w>'), 1),
#  (('s', 'u', 'r', 'e', 's', 't', '</w>'), 1),
#  (('p', 'r', 'o', 'c', 'l', 'a', 'i', 'm', 'i', 'n', 'g', '</w>'), 1),
#  (('g', 'r', 'e', 'a', 't', 'n', 'e', 's', 's', '</w>'), 1),
#  (('f', 'o', 'r', 'c', 'i', 'n', 'g', '</w>'), 1),
#  (('p', 'u', 'r', 'b', 'l', 'i', 'n', 'd', '</w>'), 1),
#  (('W', 'a', 's', '</w>'), 1),
#  (('g', 'l', 'o', 'r', 'i', 'e', 'd', '</w>'), 1),
#  (('v', 'a', 'r', 'n', 'i', 's', 'h', 'i', 'n', 'g', '</w>'), 1),
#  (('f', 'r', 'a', 'g', 'm', 'e', 'n', 't', '</w>'), 1),
#  (('f', 'r', 'a', 'g', 'm', 'e', 'n', 't', 's', '</w>'), 1),
#  (('c', 'u', 'r', 'i', 'o', 'u', 's', '</w>'), 1),
#  (('v', 'o', 'i', 'c', 'e', '</w>'), 1),
#  (('i', 'n', 's', 'e', 'n', 's', 'i', 'b', 'l', 'e', '</w>'), 1),
#  (('f', 'o', 'r', 'c', 'e', 'd', '</w>'), 1),
#  (('i', 'd', 'l', 'e', '</w>'), 1),
#  (('c', 'o', 'm', 'p', 'a', 'n', 'i', 'o', 'n', '</w>'), 1),
#  (('s', 'e', 'r', 'i', 'o', 'u', 's', '</w>'), 1),
#  (('d', 'e', 's', 'i', 'r', 'e', '</w>'), 1),
#  (('w', 'i', 's', 'h', '</w>'), 1),
#  (('t', 'w', 'i', 'r', 'l', 'i', 'n', 'g', '</w>'), 1),
#  (('f', 'i', 'n', 'g', 'e', 'r', 's', '</w>'), 1),
#  (('c', 'i', 'g', 'a', 'r', 'e', 't', 't', 'e', '</w>'), 1),
#  (('f', 'o', 'r', 'g', 'o', 't', 't', 'e', 'n', '</w>'), 1),
#  (('S', 'u', 'd', 'd', 'e', 'n', 'l', 'y', '</w>'), 1),
#  (('t', 'o', 'w', 'a', 'r', 'd', '</w>'), 1),
#  (('s', 'u', 's', 'p', 'e', 'c', 't', 'e', 'd', '</w>'), 1),
#  (('l', 'o', 'a', 't', 'h', 'i', 'n', 'g', '</w>'), 1),
#  (('g', 'e', 's', 't', 'u', 'r', 'e', '</w>'), 1),
#  (('n', 'e', 'g', 'a', 't', 'i', 'v', 'e', 'd', '</w>'), 1),
#  (('s', 'h', 'r', 'u', 'g', '</w>'), 1),
#  (('c', 'a', 'r', 'e', '</w>'), 1),
#  (('s', 't', 'r', 'a', 'w', '</w>'), 1),
#  (('t', 'i', 'e', '</w>'), 1),
#  (('s', 'l', 'i', 'g', 'h', 't', 'l', 'y', '</w>'), 1),
#  (('b', 'i', 't', 't', 'e', 'r', 'n', 'e', 's', 's', '</w>'), 1),
#  (('c', 'h', 'a', 'i', 'r', 's', '</w>'), 1),
#  (('f', 'o', 'r', 'w', 'a', 'r', 'd', '</w>'), 1),
#  (('m', 'a', 'k', 'e', '</w>'), 1),
#  (('y', 'o', 'u', 'r', 's', 'e', 'l', 'f', '</w>'), 1),
#  (('c', 'o', 'm', 'f', 'o', 'r', 't', 'a', 'b', 'l', 'e', '</w>'), 1),
#  (('c', 'i', 'g', 'a', 'r', 's', '</w>'), 1),
#  (('e', 'l', 'b', 'o', 'w', '</w>'), 1),
#  (('c', 'o', 'n', 't', 'i', 'n', 'u', 'e', 'd', '</w>'), 1),
#  (('w', 'a', 'n', 'd', 'e', 'r', '</w>'), 1),
#  (('s', 't', 'o', 'p', 'p', 'i', 'n', 'g', '</w>'), 1),
#  (('H', 'o', 'w', '</w>'), 1),
#  (('f', 'i', 'v', 'e', '</w>'), 1),
#  (('m', 'i', 'n', 'u', 't', 'e', 's', '</w>'), 1),
#  (('t', 'a', 'k', 'e', '</w>'), 1),
#  (('l', 'o', 'n', 'g', 'e', 'r', '</w>'), 1),
#  (('s', 'u', 'r', 'p', 'r', 'i', 's', 'e', 'd', '</w>'), 1),
#  (('p', 'l', 'e', 'a', 's', 'e', 'd', '</w>'), 1),
#  (('g', 'o', 'n', 'e', '</w>'), 1),
#  (('e', 'c', 'h', 'o', 'e', 'd', '</w>'), 1),
#  (('u', 's', 'u', 'a', 'l', '</w>'), 1),
#  (('p', 'l', 'a', 't', 'i', 't', 'u', 'd', 'e', 's', '</w>'), 1),
#  (('o', 'u', 'r', 's', 'e', 'l', 'v', 'e', 's', '</w>'), 1),
#  (('s', 'w', 'e', 'p', 't', '</w>'), 1),
#  (('a', 'l', 'o', 'n', 'g', '</w>'), 1),
#  (('h', 'i', 'g', 'h', '</w>'), 1),
#  (('e', 'g', 'r', 'e', 'g', 'i', 'o', 'u', 's', '</w>'), 1),
#  (('m', 'o', 'o', 'd', '</w>'), 1),
#  (('L', 'o', 'r', 'd', '</w>'), 1),
#  (('f', 'o', 'r', 'g', 'i', 'v', 'e', '</w>'), 1),
#  (('p', 'a', 't', 'h', 'o', 's', '</w>'), 1),
#  (('c', 'a', 'r', 'e', 'e', 'r', '</w>'), 1),
#  (('c', 'r', 'o', 'w', 'n', 'e', 'd', '</w>'), 1),
#  (('m', 'e', 'a', 'n', 't', '</w>'), 1),
#  (('n', 'o', 't', 'h', 'i', 'n', 'g', '</w>'), 1),
#  (('s', 't', 'a', 'm', 'm', 'e', 'r', '</w>'), 1),
#  (('s', 'o', 'm', 'e', 't', 'h', 'i', 'n', 'g', '</w>'), 1),
#  (('p', 'o', 'v', 'e', 'r', 't', 'y', '</w>'), 1),
#  (('p', 'r', 'o', 'd', 'i', 'g', 'i', 'o', 'u', 's', '</w>'), 1),
#  (('p', 'h', 'r', 'a', 's', 'e', '</w>'), 1),
#  (('p', 'r', 'i', 'n', 'c', 'e', 'l', 'y', '</w>'), 1),
#  (('a', 'd', 'v', 'a', 'n', 'c', 'e', '</w>'), 1),
#  (('f', 'o', 'u', 'r', '</w>'), 1),
#  (('h', 'o', 'u', 'r', 's', '</w>'), 1),
#  (('d', 'i', 's', 'e', 'a', 's', 'e', '</w>'), 1),
#  (('p', 'r', 'e', 'l', 'i', 'm', 'i', 'n', 'a', 'r', 'y', '</w>'), 1),
#  (('d', 'e', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'n', '</w>'), 1),
#  (('c', 'l', 'e', 'a', 'r', '</w>'), 1),
#  (('u', 'n', 't', 'o', 'u', 'c', 'h', 'e', 'd', '</w>'), 1),
#  (('t', 'w', 'i', 'c', 'e', '</w>'), 1),
#  (('i', 'n', 's', 'i', 'g', 'n', 'i', 'f', 'i', 'c', 'a', 'n', 't', '</w>'),
#   1),
#  (('d', 'i', 'n', 'g', 'y', '</w>'), 1),
#  (('N', 'o', 'w', '</w>'), 1),
#  (('s', 'u', 'p', 'e', 'r', 'b', '</w>'), 1),
#  (('m', 'e', 'r', 'e', 'l', 'y', '</w>'), 1),
#  (('a', 'e', 's', 't', 'h', 'e', 't', 'i', 'c', '</w>'), 1),
#  (('s', 't', 'r', 'a', 'n', 'g', 'e', '</w>'), 1),
#  (('l', 'i', 'k', 'e', 'n', 'e', 's', 's', '</w>'), 1),
#  (('a', 'f', 'f', 'e', 'c', 't', '</w>'), 1),
#  ...]

# %%
from llmscratch.utils.bpe_format_utils import convert_to_sennrich_format


sennrich_format = convert_to_sennrich_format(init_vocab)
sennrich_format
# Out:
# {('I</w>',): 120,
#  ('H', 'A', 'D</w>'): 1,
#  ('a', 'l', 'w', 'a', 'y', 's</w>'): 6,
#  ('t', 'h', 'o', 'u', 'g', 'h', 't</w>'): 8,
#  ('J', 'a', 'c', 'k</w>'): 15,
#  ('G', 'i', 's', 'b', 'u', 'r', 'n</w>'): 19,
#  ('r', 'a', 't', 'h', 'e', 'r</w>'): 6,
#  ('a</w>',): 82,
#  ('c', 'h', 'e', 'a', 'p</w>'): 1,
#  ('g', 'e', 'n', 'i', 'u', 's</w>'): 1,
#  ('t', 'h', 'o', 'u', 'g', 'h</w>'): 2,
#  ('g', 'o', 'o', 'd</w>'): 5,
#  ('f', 'e', 'l', 'l', 'o', 'w</w>'): 2,
#  ('e', 'n', 'o', 'u', 'g', 'h</w>'): 5,
#  ('s', 'o</w>'): 16,
#  ('i', 't</w>'): 66,
#  ('w', 'a', 's</w>'): 72,
#  ('n', 'o</w>'): 8,
#  ('g', 'r', 'e', 'a', 't</w>'): 2,
#  ('s', 'u', 'r', 'p', 'r', 'i', 's', 'e</w>'): 3,
#  ('t', 'o</w>'): 97,
#  ('m', 'e</w>'): 37,
#  ('h', 'e', 'a', 'r</w>'): 4,
#  ('t', 'h', 'a', 't</w>'): 55,
#  ('i', 'n</w>'): 40,
#  ('t', 'h', 'e</w>'): 168,
#  ('h', 'e', 'i', 'g', 'h', 't</w>'): 2,
#  ('o', 'f</w>'): 98,
#  ('h', 'i', 's</w>'): 61,
#  ('g', 'l', 'o', 'r', 'y</w>'): 2,
#  ('h', 'e</w>'): 64,
#  ('h', 'a', 'd</w>'): 54,
#  ('d', 'r', 'o', 'p', 'p', 'e', 'd</w>'): 2,
#  ('p', 'a', 'i', 'n', 't', 'i', 'n', 'g</w>'): 9,
#  ('m', 'a', 'r', 'r', 'i', 'e', 'd</w>'): 3,
#  ('r', 'i', 'c', 'h</w>'): 2,
#  ('w', 'i', 'd', 'o', 'w</w>'): 1,
#  ('a', 'n', 'd</w>'): 74,
#  ('e', 's', 't', 'a', 'b', 'l', 'i', 's', 'h', 'e', 'd</w>'): 1,
#  ('h', 'i', 'm', 's', 'e', 'l', 'f</w>'): 9,
#  ('v', 'i', 'l', 'l', 'a</w>'): 1,
#  ('o', 'n</w>'): 27,
#  ('R', 'i', 'v', 'i', 'e', 'r', 'a</w>'): 3,
#  ('T', 'h', 'o', 'u', 'g', 'h</w>'): 1,
#  ('w', 'o', 'u', 'l', 'd</w>'): 12,
#  ('h', 'a', 'v', 'e</w>'): 27,
#  ('b', 'e', 'e', 'n</w>'): 18,
#  ('R', 'o', 'm', 'e</w>'): 1,
#  ('o', 'r</w>'): 9,
#  ('F', 'l', 'o', 'r', 'e', 'n', 'c', 'e</w>'): 1,
#  ('T', 'h', 'e</w>'): 16,
#  ('w', 'h', 'a', 't</w>'): 9,
#  ('w', 'o', 'm', 'e', 'n</w>'): 4,
#  ('c', 'a', 'l', 'l', 'e', 'd</w>'): 3,
#  ('c', 'a', 'n</w>'): 5,
#  ('G', 'i', 'd', 'e', 'o', 'n</w>'): 1,
#  ('T', 'h', 'w', 'i', 'n', 'g</w>'): 3,
#  ('l', 'a', 's', 't</w>'): 6,
#  ('C', 'h', 'i', 'c', 'a', 'g', 'o</w>'): 1,
#  ('s', 'i', 't', 't', 'e', 'r</w>'): 1,
#  ('d', 'e', 'p', 'l', 'o', 'r', 'i', 'n', 'g</w>'): 1,
#  ('u', 'n', 'a', 'c', 'c', 'o', 'u', 'n', 't', 'a', 'b', 'l', 'e</w>'): 1,
#  ('a', 'b', 'd', 'i', 'c', 'a', 't', 'i', 'o', 'n</w>'): 2,
#  ('O', 'f</w>'): 5,
#  ('c', 'o', 'u', 'r', 's', 'e</w>'): 6,
#  ('g', 'o', 'i', 'n', 'g</w>'): 1,
#  ('s', 'e', 'n', 'd</w>'): 1,
#  ('v', 'a', 'l', 'u', 'e</w>'): 1,
#  ('m', 'y</w>'): 40,
#  ('p', 'i', 'c', 't', 'u', 'r', 'e</w>'): 11,
#  ('w', 'a', 'y</w>'): 5,
#  ('u', 'p</w>'): 20,
#  ('b', 'u', 't</w>'): 12,
#  ('d', 'o</w>'): 7,
#  ('t', 'h', 'i', 'n', 'k</w>'): 4,
#  ('R', 'i', 'c', 'k', 'h', 'a', 'm</w>'): 7,
#  ('l', 'o', 's', 's</w>'): 1,
#  ('A', 'r', 'r', 't</w>'): 1,
#  ('i', 's</w>'): 9,
#  ('a', 'l', 'l</w>'): 13,
#  ('w', 'o', 'r', 'd</w>'): 2,
#  ('l', 'i', 'p', 's</w>'): 3,
#  ('m', 'u', 'l', 't', 'i', 'p', 'l', 'i', 'e', 'd</w>'): 1,
#  ('i', 't', 's</w>'): 4,
#  ('r', 's</w>'): 1,
#  ('a', 's</w>'): 24,
#  ('t', 'h', 'e', 'y</w>'): 9,
#  ('w', 'e', 'r', 'e</w>'): 9,
#  ('r', 'e', 'f', 'l', 'e', 'c', 't', 'e', 'd</w>'): 1,
#  ('a', 'n</w>'): 12,
#  ('e', 'n', 'd', 'l', 'e', 's', 's</w>'): 1,
#  ('v', 'i', 's', 't', 'a</w>'): 2,
#  ('m', 'i', 'r', 'r', 'o', 'r', 's</w>'): 1,
#  ('A', 'n', 'd</w>'): 9,
#  ('n', 'o', 't</w>'): 18,
#  ('o', 'n', 'l', 'y</w>'): 10,
#  ('T', 'h', 'w', 'i', 'n', 'g', 's</w>'): 1,
#  ('w', 'h', 'o</w>'): 7,
#  ('m', 'o', 'u', 'r', 'n', 'e', 'd</w>'): 1,
#  ('H', 'a', 'd</w>'): 1,
#  ('e', 'x', 'q', 'u', 'i', 's', 'i', 't', 'e</w>'): 1,
#  ('H', 'e', 'r', 'm', 'i', 'a</w>'): 2,
#  ('C', 'r', 'o', 'f', 't</w>'): 4,
#  ('a', 't</w>'): 21,
#  ('G', 'r', 'a', 'f', 't', 'o', 'n</w>'): 1,
#  ('G', 'a', 'l', 'l', 'e', 'r', 'y</w>'): 1,
#  ('s', 'h', 'o', 'w</w>'): 2,
#  ('s', 't', 'o', 'p', 'p', 'e', 'd</w>'): 1,
#  ('b', 'e', 'f', 'o', 'r', 'e</w>'): 3,
#  ('M', 'o', 'o', 'n</w>'): 1,
#  ('d', 'a', 'n', 'c', 'e', 'r', 's</w>'): 1,
#  ('s', 'a', 'y</w>'): 12,
#  ('w', 'i', 't', 'h</w>'): 32,
#  ('t', 'e', 'a', 'r', 's</w>'): 2,
#  ('h', 'e', 'r</w>'): 20,
#  ('e', 'y', 'e', 's</w>'): 8,
#  ('W', 'e</w>'): 1,
#  ('s', 'h', 'a', 'l', 'l</w>'): 1,
#  ('l', 'o', 'o', 'k</w>'): 3,
#  ('u', 'p', 'o', 'n</w>'): 1,
#  ('l', 'i', 'k', 'e</w>'): 8,
#  ('a', 'g', 'a', 'i', 'n</w>'): 7,
#  ('t', 'h', 'r', 'o', 'u', 'g', 'h</w>'): 9,
#  ('p', 'r', 'i', 's', 'm</w>'): 1,
#  ('f', 'e', 'l', 't</w>'): 7,
#  ('a', 'b', 'l', 'e</w>'): 2,
#  ('f', 'a', 'c', 'e</w>'): 5,
#  ('f', 'a', 'c', 't</w>'): 6,
#  ('e', 'q', 'u', 'a', 'n', 'i', 'm', 'i', 't', 'y</w>'): 1,
#  ('P', 'o', 'o', 'r</w>'): 3,
#  ('m', 'a', 'd', 'e</w>'): 3,
#  ('h', 'i', 'm</w>'): 33,
#  ('f', 'i', 't', 't', 'i', 'n', 'g</w>'): 1,
#  ('s', 'h', 'o', 'u', 'l', 'd</w>'): 3,
#  ('m', 'o', 'u', 'r', 'n</w>'): 1,
#  ('A', 'm', 'o', 'n', 'g</w>'): 1,
#  ('o', 'w', 'n</w>'): 7,
#  ('s', 'e', 'x</w>'): 1,
#  ('f', 'e', 'w', 'e', 'r</w>'): 1,
#  ('r', 'e', 'g', 'r', 'e', 't', 's</w>'): 1,
#  ('h', 'e', 'a', 'r', 'd</w>'): 3,
#  ('t', 'r', 'a', 'd', 'e</w>'): 1,
#  ('h', 'a', 'r', 'd', 'l', 'y</w>'): 1,
#  ('m', 'u', 'r', 'm', 'u', 'r</w>'): 1,
#  ('P', 'r', 'o', 'f', 'e', 's', 's', 'i', 'o', 'n', 'a', 'l</w>'): 1,
#  ('j', 'e', 'a', 'l', 'o', 'u', 's', 'y</w>'): 2,
#  ('P', 'e', 'r', 'h', 'a', 'p', 's</w>'): 1,
#  ('I', 'f</w>'): 3,
#  ('h', 'o', 'n', 'o', 'u', 'r</w>'): 3,
#  ('c', 'r', 'a', 'f', 't</w>'): 1,
#  ('v', 'i', 'n', 'd', 'i', 'c', 'a', 't', 'e', 'd</w>'): 2,
#  ('b', 'y</w>'): 14,
#  ('l', 'i', 't', 't', 'l', 'e</w>'): 6,
#  ('C', 'l', 'a', 'u', 'd', 'e</w>'): 1,
#  ('N', 'u', 't', 'l', 'e', 'y</w>'): 1,
#  ('f', 'a', 'i', 't', 'h</w>'): 1,
#  ('b', 'r', 'o', 'u', 'g', 'h', 't</w>'): 2,
#  ('o', 'u', 't</w>'): 12,
#  ('B', 'u', 'r', 'l', 'i', 'n', 'g', 't', 'o', 'n</w>'): 1,
#  ('v', 'e', 'r', 'y</w>'): 1,
#  ('h', 'a', 'n', 'd', 's', 'o', 'm', 'e</w>'): 3,
#  ('o', 'b', 'i', 't', 'u', 'a', 'r', 'y</w>'): 1,
#  ('o', 'n', 'e</w>'): 23,
#  ('t', 'h', 'o', 's', 'e</w>'): 2,
#  ('s', 'h', 'o', 'w', 'y</w>'): 4,
#  ('a', 'r', 't', 'i', 'c', 'l', 'e', 's</w>'): 1,
#  ('s', 't', 'o', 'c', 'k', 'e', 'd</w>'): 1,
#  ('r', 'a', 'n', 'd', 'o', 'm</w>'): 1,
#  ('t', 'e', 'c', 'h', 'n', 'i', 'c', 'a', 'l', 'i', 't', 'i', 'e', 's</w>'): 1,
#  ('w', 'o</w>'): 1,
#  ('w', 'h', 'o', 'm</w>'): 1,
#  ('c', 'o', 'm', 'p', 'a', 'r', 'e', 'd</w>'): 1,
#  ('r', 'e', 's', 'o', 'l', 'v', 'e</w>'): 2,
#  ('b', 'e', 'i', 'n', 'g</w>'): 4,
#  ('a', 'p', 'p', 'a', 'r', 'e', 'n', 't', 'l', 'y</w>'): 1,
#  ('i', 'r', 'r', 'e', 'v', 'o', 'c', 'a', 'b', 'l', 'e</w>'): 1,
#  ('d', 'i', 's', 'c', 'u', 's', 's', 'i', 'o', 'n</w>'): 1,
#  ('g', 'r', 'a', 'd', 'u', 'a', 'l', 'l', 'y</w>'): 1,
#  ('d', 'i', 'e', 'd</w>'): 2,
#  ('p', 'r', 'e', 'd', 'i', 'c', 't', 'e', 'd</w>'): 1,
#  ('p', 'r', 'i', 'c', 'e</w>'): 1,
#  ('G', 'i', 's', 'b', 'u', 'r', 'n', 's</w>'): 1,
#  ('w', 'e', 'n', 't</w>'): 4,
#  ('I', 't</w>'): 15,
#  ('t', 'i', 'l', 'l</w>'): 5,
#  ('t', 'h', 'r', 'e', 'e</w>'): 1,
#  ('y', 'e', 'a', 'r', 's</w>'): 3,
#  ('l', 'a', 't', 'e', 'r</w>'): 2,
#  ('f', 'e', 'w</w>'): 1,
#  ('w', 'e', 'e', 'k', 's</w>'): 2,
#  ('i', 'd', 'l', 'i', 'n', 'g</w>'): 1,
#  ('s', 'u', 'd', 'd', 'e', 'n', 'l', 'y</w>'): 2,
#  ('o', 'c', 'c', 'u', 'r', 'r', 'e', 'd</w>'): 1,
#  ('w', 'o', 'n', 'd', 'e', 'r</w>'): 3,
#  ('w', 'h', 'y</w>'): 3,
#  ('g', 'i', 'v', 'e', 'n</w>'): 6,
#  ('O', 'n</w>'): 1,
#  ('r', 'e', 'f', 'l', 'e', 'c', 't', 'i', 'o', 'n</w>'): 1,
#  ('r', 'e', 'a', 'l', 'l', 'y</w>'): 3,
#  ('t', 'e', 'm', 'p', 't', 'i', 'n', 'g</w>'): 1,
#  ('p', 'r', 'o', 'b', 'l', 'e', 'm</w>'): 1,
#  ('T', 'o</w>'): 3,
#  ('a', 'c', 'c', 'u', 's', 'e</w>'): 1,
#  ('w', 'i', 'f', 'e</w>'): 5,
#  ('t', 'o', 'o</w>'): 6,
#  ('e', 'a', 's', 'y</w>'): 1,
#  ('f', 'a', 'i', 'r</w>'): 1,
#  ('s', 'i', 't', 't', 'e', 'r', 's</w>'): 3,
#  ('d', 'e', 'n', 'i', 'e', 'd</w>'): 1,
#  ('s', 'o', 'l', 'a', 'c', 'e</w>'): 1,
#  ('s', 'a', 'y', 'i', 'n', 'g</w>'): 1,
#  ('d', 'r', 'a', 'g', 'g', 'e', 'd</w>'): 2,
#  ('d', 'o', 'w', 'n</w>'): 9,
#  ('F', 'o', 'r</w>'): 3,
#  ('s', 'u', 'c', 'h</w>'): 7,
#  ('e', 'x', 'i', 's', 't', 'e', 'd</w>'): 1,
#  ('n', 'e', 'a', 'r', 'l', 'y</w>'): 1,
#  ('y', 'e', 'a', 'r</w>'): 1,
#  ('a', 'f', 't', 'e', 'r</w>'): 5,
#  ('t', 'a', 'k', 'e', 'n</w>'): 3,
#  ('m', 'i', 'g', 'h', 't</w>'): 4,
#  ('b', 'e</w>'): 9,
#  ('s', 'i', 'n', 'c', 'e</w>'): 3,
#  ('l', 'i', 'k', 'e', 'd</w>'): 2,
#  ('e', 'a', 's', 'e</w>'): 1,
#  ('b', 'e', 'c', 'a', 'u', 's', 'e</w>'): 7,
#  ('d', 'i', 'd</w>'): 10,
#  ('w', 'a', 'n', 't</w>'): 3,
#  ('g', 'o</w>'): 3,
#  ('h', 'a', 'r', 'd</w>'): 2,
#  ('p', 'r', 'o', 'v', 'e</w>'): 1,
#  ('i', 'f</w>'): 10,
#  ('s', 'h', 'e</w>'): 19,
#  ('e', 'q', 'u', 'a', 'l', 'l', 'y</w>'): 1,
#  ('M', 'i', 's', 's</w>'): 3,
#  ('c', 'o', 'n', 't', 'e', 'n', 'd', 'e', 'd</w>'): 1,
#  ('f', 'a', 'i', 'l', 'e', 'd</w>'): 2,
#  ('l', 'i', 'f', 't</w>'): 2,
#  ('l', 'e', 'd</w>'): 1,
#  ('b', 'a', 'c', 'k</w>'): 7,
#  ('e', 'a', 's', 'e', 'l</w>'): 3,
#  ('p', 'u', 't</w>'): 7,
#  ('b', 'r', 'u', 's', 'h</w>'): 2,
#  ('i', 'n', 't', 'o</w>'): 6,
#  ('h', 'a', 'n', 'd</w>'): 4,
#  ('v', 'o', 'c', 'a', 't', 'i', 'o', 'n</w>'): 1,
#  ('f', 'o', 'r</w>'): 15,
#  ('B', 'u', 't</w>'): 10,
#  ('a', 'p', 'p', 'e', 'a', 'r', 'e', 'd</w>'): 1,
#  ('d', 'i', 's', 'd', 'a', 'i', 'n', 'e', 'd</w>'): 1,
#  ('i', 'n', 't', 'e', 'r', 'e', 's', 't', 'i', 'n', 'g</w>'): 4,
#  ('f', 'i', 'n', 'd</w>'): 1,
#  ('d', 'e', 's', 'u', 'l', 't', 'o', 'r', 'y</w>'): 1,
#  ('l', 'i', 'f', 'e</w>'): 4,
#  ('l', 'e', 'n', 'd', 's</w>'): 1,
#  ('i', 't', 's', 'e', 'l', 'f</w>'): 1,
#  ('p', 'u', 'r', 'e', 'l', 'y</w>'): 1,
#  ('a', 'c', 'a', 'd', 'e', 'm', 'i', 'c</w>'): 1,
#  ('s', 'p', 'e', 'c', 'u', 'l', 'a', 't', 'i', 'o', 'n', 's</w>'): 1,
#  ('h', 'a', 'v', 'i', 'n', 'g</w>'): 3,
#  ('M', 'o', 'n', 't', 'e</w>'): 2,
#  ('C', 'a', 'r', 'l', 'o</w>'): 2,
#  ('c', 'a', 'u', 'g', 'h', 't</w>'): 2,
#  ('g', 'l', 'i', 'm', 'p', 's', 'e</w>'): 1,
#  ('b', 'a', 'l', 'u', 's', 't', 'r', 'a', 'd', 'e', 'd</w>'): 1,
#  ('t', 'e', 'r', 'r', 'a', 'c', 'e', 's</w>'): 1,
#  ('b', 'e', 't', 'w', 'e', 'e', 'n</w>'): 6,
#  ('p', 'i', 'n', 'e', 's</w>'): 1,
#  ('m', 'y', 's', 'e', 'l', 'f</w>'): 4,
#  ('b', 'o', 'r', 'n', 'e</w>'): 1,
#  ('t', 'h', 'i', 't', 'h', 'e', 'r</w>'): 1,
#  ('n', 'e', 'x', 't</w>'): 2,
#  ('d', 'a', 'y</w>'): 3,
#  ('f', 'o', 'u', 'n', 'd</w>'): 3,
#  ('c', 'o', 'u', 'p', 'l', 'e</w>'): 1,
#  ('t', 'e', 'a</w>'): 1,
#  ('b', 'e', 'n', 'e', 'a', 't', 'h</w>'): 3,
#  ('t', 'h', 'e', 'i', 'r</w>'): 6,
#  ('p', 'a', 'l', 'm</w>'): 1,
#  ('t', 'r', 'e', 'e', 's</w>'): 1,
#  ('w', 'e', 'l', 'c', 'o', 'm', 'e</w>'): 1,
#  ('g', 'e', 'n', 'i', 'a', 'l</w>'): 1,
#  ('e', 'n', 's', 'u', 'i', 'n', 'g</w>'): 1,
#  ('c', 'l', 'a', 'i', 'm', 'e', 'd</w>'): 1,
#  ('f', 'r', 'e', 'q', 'u', 'e', 'n', 't', 'l', 'y</w>'): 1,
#  ('h', 'o', 's', 't', 'e', 's', 's</w>'): 2,
#  ('p', 'o', 'i', 'n', 't</w>'): 3,
#  ('c', 'o', 'u', 'l', 'd</w>'): 12,
#  ('f', 'u', 'l', 'l', 'e', 's', 't</w>'): 1,
#  ('r', 'e', 'a', 's', 's', 'u', 'r', 'a', 'n', 'c', 'e</w>'): 1,
#  ('j', 'u', 's', 't</w>'): 12,
#  ('m', 'a', 'y</w>'): 1,
#  ('p', 'a', 'r', 'd', 'o', 'n', 'e', 'd</w>'): 1,
#  ('b', 'u', 'l', 'l</w>'): 1,
#  ('s', 'u', 'r', 'r', 'o', 'u', 'n', 'd', 'e', 'd</w>'): 1,
#  ('f', 'o', 's', 't', 'e', 'r', 'e', 'd</w>'): 1,
#  ('a', 'r', 't</w>'): 3,
#  ('r', 'e', 'a', 'r', 'e', 'd</w>'): 1,
#  ('h', 'o', 't</w>'): 1,
#  ('h', 'o', 'u', 's', 'e</w>'): 5,
#  ('a', 'd', 'u', 'l', 'a', 't', 'i', 'o', 'n</w>'): 1,
#  ('t', 'h', 'e', 'r', 'e', 'f', 'o', 'r', 'e</w>'): 1,
#  ('i', 'n', 's', 't', 'r', 'u', 'c', 't', 'i', 'v', 'e</w>'): 1,
#  ('n', 'o', 't', 'e</w>'): 5,
#  ('e', 'f', 'f', 'e', 'c', 't</w>'): 1,
#  ('d', 'e', 'a', 'd', 'e', 'n', 'i', 'n', 'g</w>'): 1,
#  ('a', 't', 'm', 'o', 's', 'p', 'h', 'e', 'r', 'e</w>'): 1,
#  ('m', 'e', 'd', 'i', 'o', 'c', 'r', 'i', 't', 'y</w>'): 1,
#  ('q', 'u', 'o', 't', 'e</w>'): 1,
#  ('m', 'e', 'n', 't', 'i', 'o', 'n', 'e', 'd</w>'): 1,
#  ('i', 'm', 'm', 'e', 'd', 'i', 'a', 't', 'e', 'l', 'y</w>'): 1,
#  ('p', 'e', 'r', 'c', 'e', 'p', 't', 'i', 'b', 'l', 'e</w>'): 1,
#  ('h', 'u', 's', 'b', 'a', 'n', 'd</w>'): 3,
#  ('e', 'x', 't', 'r', 'a', 'c', 't', 'i', 'n', 'g</w>'): 1,
#  ('f', 'r', 'o', 'm</w>'): 7,
#  ('t', 'h', 'i', 's</w>'): 3,
#  ('c', 'i', 'r', 'c', 'u', 'm', 's', 't', 'a', 'n', 'c', 'e</w>'): 1,
#  ('d', 'e', 'l', 'i', 'c', 'a', 't', 'e</w>'): 3,
#  ('s', 'u', 'b', 's', 't', 'a', 'n', 't', 'i', 'a', 'l</w>'): 1,
#  ('s', 'a', 't', 'i', 's', 'f', 'a', 'c', 't', 'i', 'o', 'n</w>'): 2,
#  ('r', 'u', 'l', 'e</w>'): 1,
#  ('p', 'e', 'o', 'p', 'l', 'e</w>'): 3,
#  ('s', 'c', 'o', 'r', 'n</w>'): 1,
#  ('m', 'o', 'n', 'e', 'y</w>'): 1,
#  ('g', 'e', 't</w>'): 4,
#  ('m', 'o', 's', 't</w>'): 2,
#  ('e', 'l', 'e', 'g', 'a', 'n', 't</w>'): 1,
#  ('d', 'i', 's', 'd', 'a', 'i', 'n</w>'): 1,
#  ('b', 'i', 'g</w>'): 1,
#  ('b', 'a', 'l', 'a', 'n', 'c', 'e</w>'): 1,
#  ('e', 'n', 'a', 'b', 'l', 'e', 'd</w>'): 1,
#  ('a', 'p', 'p', 'e', 'a', 'r', 'a', 'n', 'c', 'e</w>'): 1,
#  ('p', 'e', 'r', 'f', 'e', 'c', 't</w>'): 1,
#  ('b', 'r', 'e', 'e', 'd', 'i', 'n', 'g</w>'): 1,
#  ('t', 'r', 'a', 'n', 's', 'm', 'u', 't', 'e</w>'): 1,
#  ('o', 'b', 'j', 'e', 'c', 't', 's</w>'): 2,
#  ('l', 'u', 'x', 'u', 'r', 'y</w>'): 1,
#  ('l', 'a', 't', 't', 'e', 'r</w>'): 2,
#  ('m', 'u', 's', 't</w>'): 3,
#  ('a', 'd', 'd</w>'): 1,
#  ('r', 'e', 'm', 'a', 'i', 'n', 'e', 'd</w>'): 1,
#  ('r', 'e', 'l', 'a', 't', 'i', 'v', 'e', 'l', 'y</w>'): 1,
#  ('i', 'n', 'd', 'i', 'f', 'f', 'e', 'r', 'e', 'n', 't</w>'): 1,
#  ('b', 'u', 'y', 'i', 'n', 'g</w>'): 1,
#  ('R', 'e', 'n', 'a', 'i', 's', 's', 'a', 'n', 'c', 'e</w>'): 1,
#  ('b', 'r', 'o', 'n', 'z', 'e', 's</w>'): 1,
#  ('e', 'i', 'g', 'h', 't', 'e', 'e', 'n', 't', 'h</w>'): 2,
#  ('c', 'e', 'n', 't', 'u', 'r', 'y</w>'): 2,
#  ('p', 'i', 'c', 't', 'u', 'r', 'e', 's</w>'): 6,
#  ('d', 'i', 's', 'c', 'r', 'i', 'm', 'i', 'n', 'a', 't', 'i', 'o', 'n</w>'): 1,
#  ('b', 'e', 's', 'p', 'o', 'k', 'e</w>'): 1,
#  ('a', 'm', 'p', 'l', 'e', 's', 't</w>'): 1,
#  ('r', 'e', 's', 'o', 'u', 'r', 'c', 'e', 's</w>'): 1,
#  ('M', 'o', 'n', 'e', 'y</w>'): 1,
#  ('e', 'x', 'c', 'u', 's', 'e</w>'): 1,
#  ('b', 'e', 'a', 'u', 't', 'y</w>'): 2,
#  ('c', 'i', 'r', 'c', 'u', 'l', 'a', 't', 'i', 'o', 'n</w>'): 1,
#  ('a', 'x', 'i', 'o', 'm', 's</w>'): 1,
#  ('l', 'a', 'i', 'd</w>'): 4,
#  ('a', 'c', 'r', 'o', 's', 's</w>'): 1,
#  ('S', 'e', 'v', 'r', 'e', 's</w>'): 1,
#  ('s', 'i', 'l', 'v', 'e', 'r</w>'): 1,
#  ('e', 'x', 'q', 'u', 'i', 's', 'i', 't', 'e', 'l', 'y</w>'): 1,
#  ('a', 'p', 'p', 'o', 'i', 'n', 't', 'e', 'd</w>'): 1,
#  ('l', 'u', 'n', 'c', 'h', 'e', 'o', 'n</w>'): 1,
#  ('t', 'a', 'b', 'l', 'e</w>'): 2,
#  ('w', 'h', 'e', 'n</w>'): 10,
#  ('r', 'u', 'n</w>'): 1,
#  ('o', 'v', 'e', 'r</w>'): 3,
#  ('b', 'e', 'a', 'm', 'i', 'n', 'g</w>'): 1,
#  ('a', 'd', 'd', 'e', 'd</w>'): 2,
#  ('e', 'n', 'l', 'i', 'g', 'h', 't', 'e', 'n', 'm', 'e', 'n', 't</w>'): 1,
#  ('m', 'o', 'r', 'b', 'i', 'd', 'l', 'y</w>'): 1,
#  ('s', 'e', 'n', 's', 'i', 't', 'i', 'v', 'e</w>'): 1,
#  ('e', 'v', 'e', 'r', 'y</w>'): 3,
#  ('f', 'o', 'r', 'm</w>'): 1,
#  ('f', 'a', 't', 'e</w>'): 1,
#  ('t', 'h', 'i', 'n', 'g', 's</w>'): 3,
#  ('s', 'e', 't</w>'): 2,
#  ('e', 'x', 't', 'e', 'n', 'u', 'a', 't', 'i', 'o', 'n</w>'): 1,
#  ('W', 'h', 'a', 't</w>'): 2,
#  ('s', 't', 'r', 'u', 'c', 'k</w>'): 2,
#  ('n', 'o', 'w</w>'): 6,
#  ('f', 'i', 'r', 's', 't</w>'): 6,
#  ('t', 'i', 'm', 'e</w>'): 3,
#  ('r', 'e', 's', 'e', 'n', 't', 'e', 'd</w>'): 1,
#  ('t', 'o', 'n', 'e</w>'): 2,
#  ('s', 'e', 'e', 'n</w>'): 2,
#  ('o', 'f', 't', 'e', 'n</w>'): 1,
#  ('b', 'a', 's', 'k', 'i', 'n', 'g</w>'): 1,
#  ('u', 'n', 'd', 'e', 'r</w>'): 5,
#  ('s', 'i', 'm', 'i', 'l', 'a', 'r</w>'): 1,
#  ('t', 'r', 'i', 'b', 'u', 't', 'e', 's</w>'): 1,
#  ('c', 'o', 'n', 'j', 'u', 'g', 'a', 'l</w>'): 1,
#  ('r', 'o', 'b', 'b', 'e', 'd</w>'): 1,
#  ('t', 'h', 'e', 'm</w>'): 4,
#  ('s', 'a', 'v', 'o', 'u', 'r</w>'): 1,
#  ('N', 'o</w>'): 1,
#  ('o', 'd', 'd', 'l', 'y</w>'): 1,
#  ('b', 'e', 'c', 'a', 'm', 'e</w>'): 2,
#  ('a', 'p', 'p', 'a', 'r', 'e', 'n', 't</w>'): 1,
#  ('f', 'o', 'n', 'd</w>'): 2,
#  ('s', 'e', 'e</w>'): 12,
#  ('a', 'b', 's', 'u', 'r', 'd', 'i', 't', 'y</w>'): 2,
#  ('s', 'e', 'e', 'm', 'e', 'd</w>'): 3,
#  ('w', 'i', 'n', 'c', 'i', 'n', 'g</w>'): 2,
#  ('a', 't', 't', 'i', 't', 'u', 'd', 'e</w>'): 1,
#  ('o', 'b', 'j', 'e', 'c', 't</w>'): 2,
#  ('g', 'a', 'r', 'l', 'a', 'n', 'd', 's</w>'): 1,
#  ('i', 'n', 'c', 'e', 'n', 's', 'e</w>'): 1,
#  ('M', 'y</w>'): 3,
#  ('d', 'e', 'a', 'r</w>'): 4,
#  ('c', 'h', 'u', 'c', 'k', 'e', 'd</w>'): 3,
#  ('s', 't', 'u', 'f', 'f</w>'): 1,
#  ('a', 'b', 'o', 'u', 't</w>'): 11,
#  ('V', 'i', 'c', 't', 'o', 'r</w>'): 2,
#  ('G', 'r', 'i', 'n', 'd', 'l', 'e</w>'): 5,
#  ('p', 'r', 'o', 't', 'e', 's', 't</w>'): 1,
#  ('r', 'o', 's', 'e</w>'): 3,
#  ('s', 't', 'r', 'o', 'l', 'l', 'e', 'd</w>'): 1,
#  ('o', 'n', 't', 'o</w>'): 1,
#  ('s', 'u', 'n', 'l', 'i', 't</w>'): 1,
#  ('t', 'e', 'r', 'r', 'a', 'c', 'e</w>'): 2,
#  ('g', 'l', 'a', 'n', 'c', 'e', 'd</w>'): 3,
#  ('b', 'e', 'c', 'o', 'm', 'i', 'n', 'g</w>'): 1,
#  ('m', 'a', 'n</w>'): 4,
#  ('m', 'o', 'm', 'e', 'n', 't</w>'): 2,
#  ('h', 'o', 'u', 'r</w>'): 1,
#  ('y', 'o', 'u', 'n', 'g', 'e', 'r</w>'): 1,
#  ('a', 'r', 't', 'i', 's', 't</w>'): 1,
#  ('s', 'a', 'i', 'd</w>'): 13,
#  ('f', 'o', 'r', 'm', 'e', 'd</w>'): 1,
#  ('f', 'r', 'i', 'e', 'n', 'd</w>'): 1,
#  ('f', 'e', 'e', 't</w>'): 1,
#  ('w', 'o', 'n', 'd', 'e', 'r', 'e', 'd</w>'): 1,
#  ('t', 'i', 'n', 'g', 'e</w>'): 1,
#  ('u', 'n', 'd', 'e', 'r', 'l', 'a', 'y</w>'): 1,
#  ('m', 'y', 's', 't', 'e', 'r', 'i', 'o', 'u', 's</w>'): 1,
#  ('e', 'v', 'e', 'n', 't</w>'): 1,
#  ('D', 'u', 'b', 'a', 'r', 'r', 'y</w>'): 2,
#  ('d', 'r', 'a', 'w', 'i', 'n', 'g</w>'): 3,
#  ('r', 'o', 'o', 'm', 's</w>'): 3,
#  ('b', 'e', 'g', 'u', 'n</w>'): 1,
#  ('d', 'i', 's', 'p', 'l', 'a', 'y</w>'): 2,
#  ('G', 'r', 'i', 'n', 'd', 'l', 'e', 's</w>'): 1,
#  ('t', 'u', 'r', 'n', 'e', 'd</w>'): 5,
#  ('l', 'i', 'n', 'g', 'e', 'r', 'e', 'd</w>'): 1,
#  ('g', 'i', 'v', 'e</w>'): 2,
#  ('l', 'u', 'm', 'p</w>'): 1,
#  ('s', 'u', 'g', 'a', 'r</w>'): 1,
#  ('s', 'p', 'a', 'n', 'i', 'e', 'l</w>'): 1,
#  ('d', 'i', 'n', 'i', 'n', 'g</w>'): 1,
#  ('r', 'o', 'o', 'm</w>'): 6,
#  ('W', 'h', 'y</w>'): 2,
#  ('h', 'a', 's</w>'): 1,
#  ('a', 's', 'k', 'e', 'd</w>'): 2,
#  ('a', 'b', 'r', 'u', 'p', 't', 'l', 'y</w>'): 1,
#  ('S', 'h', 'e</w>'): 9,
#  ('r', 'a', 'i', 's', 'e', 'd</w>'): 1,
#  ('e', 'y', 'e', 'b', 'r', 'o', 'w', 's</w>'): 1,
#  ('h', 'i', 'n', 't</w>'): 1,
#  ('h', 'u', 'm', 'o', 'u', 'r', 'e', 'd</w>'): 2,
#  ('O', 'h</w>'): 5,
#  ('d', 'o', 'e', 's</w>'): 2,
#  ('y', 'o', 'u</w>'): 25,
#  ('k', 'n', 'o', 'w</w>'): 9,
#  ('e', 'n', 'j', 'o', 'y</w>'): 1,
#  ('q', 'u', 'i', 't', 'e</w>'): 2,
#  ('s', 'i', 'm', 'p', 'l', 'y</w>'): 2,
#  ('l', 'o', 'o', 'k', 'e', 'd</w>'): 5,
#  ('s', 'p', 'a', 'c', 'i', 'o', 'u', 's</w>'): 1,
#  ('w', 'h', 'i', 't', 'e</w>'): 2,
#  ('p', 'a', 'n', 'e', 'l', 'l', 'e', 'd</w>'): 1,
#  ('f', 'a', 'm', 'i', 'l', 'l', 'e</w>'): 1,
#  ('v', 'e', 'r', 't', 'e</w>'): 1,
#  ('v', 'a', 's', 'e', 's</w>'): 1,
#  ('r', 'e', 'p', 'e', 'a', 't', 'i', 'n', 'g</w>'): 1,
#  ('t', 'o', 'n', 'e', 's</w>'): 1,
#  ('p', 'a', 'l', 'e</w>'): 2,
#  ('d', 'a', 'm', 'a', 's', 'k</w>'): 1,
#  ('c', 'u', 'r', 't', 'a', 'i', 'n', 's</w>'): 3,
#  ('p', 'a', 's', 't', 'e', 'l', 's</w>'): 1,
#  ('f', 'a', 'd', 'e', 'd</w>'): 1,
#  ('f', 'r', 'a', 'm', 'e', 's</w>'): 1,
#  ('H', 'a', 's</w>'): 1,
#  ('s', 'i', 'n', 'g', 'l', 'e</w>'): 1,
#  ('A</w>',): 2,
#  ('s', 'l', 'i', 'g', 'h', 't</w>'): 1,
#  ('s', 'h', 'a', 'd', 'e</w>'): 1,
#  ('c', 'o', 'n', 's', 't', 'r', 'a', 'i', 'n', 't</w>'): 1,
#  ('c', 'r', 'o', 's', 's', 'e', 'd</w>'): 1,
#  ('o', 'p', 'e', 'n</w>'): 1,
#  ('c', 'o', 'u', 'n', 't', 'e', 'n', 'a', 'n', 'c', 'e</w>'): 1,
#  ('r', 'i', 'd', 'i', 'c', 'u', 'l', 'o', 'u', 's</w>'): 2,
#  ('m', 'o', 'd', 'e', 's', 't', 'y</w>'): 3,
#  ('H', 'e</w>'): 15,
#  ('s', 'a', 'y', 's</w>'): 2,
#  ('f', 'i', 't</w>'): 1,
#  ('s', 'e', 'n', 't</w>'): 4,
#  ('a', 'w', 'a', 'y</w>'): 3,
#  ('e', 'x', 'c', 'e', 'p', 't</w>'): 1,
#  ('p', 'o', 'r', 't', 'r', 'a', 'i', 't</w>'): 5,
#  ('k', 'e', 'e', 'p</w>'): 1,
#  ('u', 'p', 's', 't', 'a', 'i', 'r', 's</w>'): 1,
#  ('H', 'i', 's</w>'): 4,
#  ('c', 'u', 'r', 'i', 'o', 's', 'i', 't', 'y</w>'): 2,
#  ('g', 'r', 'o', 'w', 'i', 'n', 'g</w>'): 1,
#  ('b', 'e', 'a', 'n</w>'): 1,
#  ('s', 't', 'a', 'l', 'k</w>'): 1,
#  ('p', 'e', 'r', 's', 'u', 'a', 's', 'i', 'v', 'e', 'l', 'y</w>'): 1,
#  ('y', 'o', 'u', 'r</w>'): 3,
#  ('a', 'l', 'm', 'o', 's', 't</w>'): 1,
#  ('t', 'i', 'm', 'o', 'r', 'o', 'u', 's', 'l', 'y</w>'): 1,
#  ('w', 'h', 'e', 'r', 'e</w>'): 4,
#  ('l', 'o', 'u', 'n', 'g', 'i', 'n', 'g</w>'): 1,
#  ('h', 'o', 'o', 'd', 'e', 'd</w>'): 1,
#  ('c', 'h', 'a', 'i', 'r</w>'): 3,
#  ('l', 'i', 't</w>'): 1,
#  ('c', 'i', 'g', 'a', 'r</w>'): 1,
#  ('d', 'r', 'a', 'w', 'n</w>'): 1,
#  ('R', 'u', 's', 's', 'i', 'a', 'n</w>'): 1,
#  ('d', 'e', 'e', 'r', 'h', 'o', 'u', 'n', 'd</w>'): 1,
#  ('h', 'e', 'a', 'd</w>'): 4,
#  ('k', 'n', 'e', 'e', 's</w>'): 1,
#  ('W', 'e', 'l', 'l</w>'): 5,
#  ('c', 'o', 'm', 'e</w>'): 2,
#  ('w', 'h', 'i', 'l', 'e</w>'): 1,
#  ('l', 'o', 'o', 'k', 'i', 'n', 'g</w>'): 4,
#  ('l', 'a', 'u', 'g', 'h</w>'): 3,
#  ('t', 'r', 'i', 'e', 'd</w>'): 2,
#  ('h', 'i', 'd', 'e</w>'): 1,
#  ('n', 'e', 'r', 'v', 'o', 'u', 's', 'n', 'e', 's', 's</w>'): 1,
#  ('f', 'o', 'l', 'l', 'o', 'w', 'e', 'd</w>'): 2,
#  ('m', 'a', 'r', 'b', 'l', 'e</w>'): 1,
#  ('E', 'm', 'p', 'e', 'r', 'o', 'r', 's</w>'): 1,
#  ('h', 'a', 'l', 'l</w>'): 1,
#  ('w', 'i', 'd', 'e</w>'): 1,
#  ('s', 't', 'a', 'i', 'r', 's</w>'): 1,
#  ('t', 'e', 'r', 'r', 'a</w>'): 1,
#  ('c', 'o', 't', 't', 'a</w>'): 1,
#  ('n', 'y', 'm', 'p', 'h', 's</w>'): 1,
#  ('p', 'o', 'i', 's', 'e', 'd</w>'): 1,
#  ('a', 'm', 'o', 'n', 'g</w>'): 2,
#  ('f', 'l', 'o', 'w', 'e', 'r', 's</w>'): 1,
#  ('e', 'a', 'c', 'h</w>'): 1,
#  ('l', 'a', 'n', 'd', 'i', 'n', 'g</w>'): 1,
#  ('I', 'n</w>'): 1,
#  ('d', 'i', 'm', 'm', 'e', 's', 't</w>'): 1,
#  ('c', 'o', 'r', 'n', 'e', 'r</w>'): 1,
#  ('b', 'o', 'u', 'd', 'o', 'i', 'r</w>'): 1,
#  ('a', 'm', 'i', 'd</w>'): 1,
#  ('p', 'r', 'o', 'f', 'u', 's', 'i', 'o', 'n</w>'): 1,
#  ('d', 'i', 's', 't', 'i', 'n', 'g', 'u', 'i', 's', 'h', 'e', 'd</w>'): 1,
#  ('h', 'u', 'n', 'g</w>'): 2,
#  ('f', 'a', 'm', 'i', 'l', 'i', 'a', 'r</w>'): 1,
#  ('o', 'v', 'a', 'l</w>'): 1,
#  ('c', 'a', 'n', 'v', 'a', 's', 'e', 's</w>'): 1,
#  ('i', 'n', 'e', 'v', 'i', 't', 'a', 'b', 'l', 'e</w>'): 1,
#  ('g', 'a', 'r', 'l', 'a', 'n', 'd', 'e', 'd</w>'): 1,
#  ('f', 'r', 'a', 'm', 'e</w>'): 2,
#  ('m', 'e', 'r', 'e</w>'): 1,
#  ('o', 'u', 't', 'l', 'i', 'n', 'e</w>'): 1,
#  ('p', 'a', 's', 't</w>'): 2,
#  ('d', 'r', 'e', 'w</w>'): 1,
#  ('w', 'i', 'n', 'd', 'o', 'w</w>'): 1,
#  ('m', 'o', 'v', 'e', 'd</w>'): 4,
#  ('a', 's', 'i', 'd', 'e</w>'): 1,
#  ('j', 'a', 'r', 'd', 'i', 'n', 'i', 'e', 'r', 'e</w>'): 1,
#  ('f', 'u', 'l', 'l</w>'): 1,
#  ('p', 'i', 'n', 'k</w>'): 1,
#  ('a', 'z', 'a', 'l', 'e', 'a', 's</w>'): 1,
#  ('p', 'u', 's', 'h', 'e', 'd</w>'): 3,
#  ('a', 'r', 'm</w>'): 4,
#  ('s', 't', 'a', 'n', 'd</w>'): 2,
#  ('h', 'e', 'r', 'e</w>'): 3,
#  ('m', 'a', 'n', 'a', 'g', 'e</w>'): 3,
#  ('m', 'a', 'n', 't', 'e', 'l</w>'): 2,
#  ('p', 'i', 'e', 'c', 'e</w>'): 3,
#  ('l', 'e', 't</w>'): 4,
#  ('s', 't', 'a', 'y</w>'): 2,
#  ('Y', 'e', 's</w>'): 5,
#  ('e', 'v', 'e', 'r</w>'): 5,
#  ('s', 't', 'r', 'a', 'i', 'n</w>'): 1,
#  ('U', 's', 'u', 'a', 'l', 'l', 'y</w>'): 1,
#  ('p', 'l', 'a', 'c', 'e</w>'): 2,
#  ('c', 'e', 'n', 't', 'r', 'a', 'l</w>'): 1,
#  ('p', 'a', 'n', 'e', 'l</w>'): 1,
#  ('y', 'e', 'l', 'l', 'o', 'w</w>'): 1,
#  ('m', 'o', 'n', 'u', 'm', 'e', 'n', 't', 'a', 'l</w>'): 1,
#  ('p', 'l', 'a', 'c', 'e', 'd</w>'): 2,
#  ('t', 'o', 'o', 'k</w>'): 1,
#  ('l', 'i', 'g', 'h', 't</w>'): 3,
#  ('o', 'l', 'd</w>'): 3,
#  ('V', 'e', 'n', 'e', 't', 'i', 'a', 'n</w>'): 1,
#  ('m', 'o', 'r', 'e</w>'): 5,
#  ('m', 'o', 'd', 'e', 's', 't</w>'): 1,
#  ('b', 'e', 't', 't', 'e', 'r</w>'): 2,
#  ('y', 'e', 't</w>'): 2,
#  ('g', 'r', 'e', 'w</w>'): 2,
#  ('a', 'c', 'c', 'u', 's', 't', 'o', 'm', 'e', 'd</w>'): 1,
#  ('h', 'a', 'l', 'f</w>'): 4,
#  ('c', 'h', 'a', 'r', 'a', 'c', 't', 'e', 'r', 'i', 's', 't', 'i', 'c</w>'): 1,
#  ('q', 'u', 'a', 'l', 'i', 't', 'i', 'e', 's</w>'): 1,
#  ('c', 'a', 'm', 'e</w>'): 1,
#  ('h', 'e', 's', 'i', 't', 'a', 't', 'i', 'o', 'n', 's</w>'): 1,
#  ('d', 'i', 's', 'g', 'u', 'i', 's', 'e', 'd</w>'): 1,
#  ('a', 'u', 'd', 'a', 'c', 'i', 't', 'i', 'e', 's</w>'): 1,
#  ('t', 'r', 'i', 'c', 'k', 's</w>'): 2,
#  ('p',
#   'r',
#   'e',
#   's',
#   't',
#   'i',
#   'd',
#   'i',
#   'g',
#   'i',
#   't',
#   'a',
#   't',
#   'i',
#   'o',
#   'n</w>'): 1,
#  ('w', 'h', 'i', 'c', 'h</w>'): 2,
#  ('c', 'o', 'n', 's', 'u', 'm', 'm', 'a', 't', 'e</w>'): 1,
#  ('s', 'k', 'i', 'l', 'l</w>'): 1,
#  ('m', 'a', 'n', 'a', 'g', 'e', 'd</w>'): 1,
#  ('d', 'i', 'v', 'e', 'r', 't</w>'): 1,
#  ('a', 't', 't', 'e', 'n', 't', 'i', 'o', 'n</w>'): 2,
#  ('r', 'e', 'a', 'l</w>'): 1,
#  ('b', 'u', 's', 'i', 'n', 'e', 's', 's</w>'): 1,
#  ('s', 'o', 'm', 'e</w>'): 4,
#  ('p', 'r', 'e', 't', 't', 'y</w>'): 1,
#  ('i', 'r', 'r', 'e', 'l', 'e', 'v', 'a', 'n', 'c', 'e</w>'): 1,
#  ('d', 'e', 't', 'a', 'i', 'l</w>'): 1,
#  ('p', 'r', 'e', 's', 'e', 'n', 't', 'i', 'n', 'g</w>'): 1,
#  ('n', 'e', 'u', 't', 'r', 'a', 'l</w>'): 1,
#  ('s', 'u', 'r', 'f', 'a', 'c', 'e</w>'): 1,
#  ('w', 'o', 'r', 'k</w>'): 6,
#  ('f', 'o', 'r', 'm', 'i', 'n', 'g</w>'): 1,
#  ('i', 'n', 'e', 'v', 'i', 't', 'a', 'b', 'l', 'y</w>'): 1,
#  ('b', 'a', 'c', 'k', 'g', 'r', 'o', 'u', 'n', 'd</w>'): 1,
#  ('l', 'e', 'n', 't</w>'): 1,
#  ('h', 'e', 'r', 's', 'e', 'l', 'f</w>'): 2,
#  ('u', 'n', 'u', 's', 'u', 'a', 'l</w>'): 1,
#  ('d', 'e', 'g', 'r', 'e', 'e</w>'): 2,
#  ('f', 'a', 'l', 's', 'e</w>'): 1,
#  ('v', 'i', 'r', 't', 'u', 'o', 's', 'i', 't', 'y</w>'): 1,
#  ('s', 't', 'r', 'o', 'n', 'g', 'e', 's', 't</w>'): 1,
#  ('a', 'd', 'm', 'i', 'r', 'e', 'r', 's</w>'): 1,
#  ('r', 'e', 'p', 'r', 'e', 's', 'e', 'n', 't', 'e', 'd</w>'): 1,
#  ('p', 'a', 'r', 't</w>'): 1,
#  ('s', 'w', 'e', 'l', 'l', 'i', 'n', 'g</w>'): 1,
#  ('m', 'u', 's', 'c', 'l', 'e', 's</w>'): 1,
#  ('c', 'o', 'n', 'g', 'e', 's', 't', 'i', 'n', 'g</w>'): 1,
#  ('v', 'e', 'i', 'n', 's</w>'): 1,
#  ('b', 'a', 'l', 'a', 'n', 'c', 'i', 'n', 'g</w>'): 1,
#  ('s', 't', 'r', 'a', 'd', 'd', 'l', 'i', 'n', 'g</w>'): 1,
#  ('s', 't', 'r', 'a', 'i', 'n', 'i', 'n', 'g</w>'): 1,
#  ('r', 'e', 'm', 'i', 'n', 'd', 'e', 'd</w>'): 1,
#  ('c', 'i', 'r', 'c', 'u', 's</w>'): 1,
#  ('c', 'l', 'o', 'w', 'n</w>'): 1,
#  ('i', 'r', 'o', 'n', 'i', 'c</w>'): 1,
#  ('e', 'f', 'f', 'o', 'r', 't', 's</w>'): 1,
#  ('f', 'e', 'a', 't', 'h', 'e', 'r</w>'): 1,
#  ('m', 'e', 't</w>'): 2,
#  ('s', 'h', 'o', 'r', 't</w>'): 1,
#  ('d', 'e', 'm', 'a', 'n', 'd</w>'): 1,
#  ('l', 'o', 'v', 'e', 'l', 'y</w>'): 1,
#  ('w', 'o', 'm', 'a', 'n</w>'): 2,
#  ('p', 'a', 'i', 'n', 't', 'e', 'd</w>'): 6,
#  ('s', 't', 'r', 'o', 'n', 'g', 'l', 'y</w>'): 1,
#  ('t', 'i', 'r', 'e', 'd</w>'): 2,
#  ('l', 'o', 's', 'e</w>'): 1,
#  ('a', 't', 'o', 'm</w>'): 1,
#  ('s', 'w', 'e', 'e', 't', 'n', 'e', 's', 's</w>'): 1,
#  ('p', 'a', 'r', 'd', 'o', 'n', 'a', 'b', 'l', 'e</w>'): 1,
#  ('p', 'r', 'i', 'd', 'e</w>'): 2,
#  ('c', 'o', 'r', 'r', 'e', 'c', 't', 'e', 'd</w>'): 1,
#  ('o', 't', 'h', 'e', 'r</w>'): 2,
#  ('c', 'o', 'u', 'n', 't</w>'): 1,
#  ('d', 'e', 's', 't', 'r', 'o', 'y', 'e', 'd</w>'): 1,
#  ('D', 'e', 's', 't', 'r', 'o', 'y', 'e', 'd</w>'): 1,
#  ('f', 'o', 'l', 'l', 'o', 'w</w>'): 1,
#  ('c', 'l', 'u', 'e</w>'): 1,
#  ('f', 'o', 'o', 't', 's', 't', 'e', 'p</w>'): 1,
#  ('s', 'a', 'w</w>'): 5,
#  ('t', 'h', 'r', 'e', 's', 'h', 'o', 'l', 'd</w>'): 1,
#  ('A', 's</w>'): 1,
#  ('s', 't', 'o', 'o', 'd</w>'): 3,
#  ('t', 'h', 'e', 'r', 'e</w>'): 7,
#  ('h', 'a', 'n', 'd', 's</w>'): 1,
#  ('p', 'o', 'c', 'k', 'e', 't', 's</w>'): 1,
#  ('v', 'e', 'l', 'v', 'e', 't', 'e', 'e', 'n</w>'): 1,
#  ('c', 'o', 'a', 't</w>'): 1,
#  ('t', 'h', 'i', 'n</w>'): 1,
#  ('b', 'r', 'o', 'w', 'n</w>'): 2,
#  ('w', 'a', 'v', 'e', 's</w>'): 1,
#  ('h', 'a', 'i', 'r</w>'): 1,
#  ('f', 'o', 'r', 'e', 'h', 'e', 'a', 'd</w>'): 1,
#  ('l', 'e', 'a', 'n</w>'): 1,
#  ('s', 'u', 'n', 'b', 'u', 'r', 'n', 't</w>'): 1,
#  ('c', 'h', 'e', 'e', 'k', 's</w>'): 2,
#  ('f', 'u', 'r', 'r', 'o', 'w', 'e', 'd</w>'): 1,
#  ('s', 'm', 'i', 'l', 'e</w>'): 3,
#  ('l', 'i', 'f', 't', 'e', 'd</w>'): 1,
#  ('t', 'i', 'p', 's</w>'): 1,
#  ('s', 'e', 'l', 'f</w>'): 1,
#  ('c', 'o', 'n', 'f', 'i', 'd', 'e', 'n', 't</w>'): 2,
#  ('m', 'o', 'u', 's', 't', 'a', 'c', 'h', 'e</w>'): 1,
#  ('s', 'a', 'm', 'e</w>'): 1,
#  ('q', 'u', 'a', 'l', 'i', 't', 'y</w>'): 2,
#  ('c', 'l', 'e', 'v', 'e', 'r', 'e', 'r</w>'): 1,
#  ('t', 'h', 'a', 'n</w>'): 2,
#  ('d', 'e', 'p', 'r', 'e', 'c', 'a', 't', 'i', 'n', 'g', 'l', 'y</w>'): 1,
#  ('t', 'r', 'a', 'v', 'e', 'l', 'l', 'e', 'd</w>'): 1,
#  ('w', 'a', 'n', 't', 'e', 'd</w>'): 2,
#  ('b', 'e', 'g', 'a', 'n</w>'): 4,
#  ('e', 'x', 'c', 'u', 's', 'i', 'n', 'g</w>'): 1,
#  ('s', 'h', 'r', 'u', 'g', 'g', 'e', 'd</w>'): 1,
#  ('s', 'h', 'o', 'u', 'l', 'd', 'e', 'r', 's</w>'): 1,
#  ('s', 't', 'i', 'l', 'l</w>'): 4,
#  ('s', 'm', 'i', 'l', 'i', 'n', 'g</w>'): 1,
#  ('l', 'o', 'n', 'g</w>'): 1,
#  ('a', 'g', 'o</w>'): 1,
#  ('l', 'i', 'g', 'h', 't', 'l', 'y</w>'): 1,
#  ('t', 'h', 'e', 'n</w>'): 3,
#  ('p', 'a', 's', 's', 'i', 'n', 'g</w>'): 1,
#  ('m', 'i', 'n', 'e</w>'): 2,
#  ('C', 'o', 'm', 'e</w>'): 1,
#  ('r', 'e', 's', 't</w>'): 2,
#  ('s', 'h', 'o', 'w', 'e', 'd</w>'): 1,
#  ('k', 'i', 'n', 'd</w>'): 3,
#  ('n', 'a', 'i', 'v', 'e</w>'): 1,
#  ('s', 'u', 'b', 'u', 'r', 'b', 'a', 'n</w>'): 1,
#  ('b', 'a', 't', 'h</w>'): 1,
#  ('s', 'p', 'e', 'a', 'k', 'i', 'n', 'g</w>'): 1,
#  ('t', 'u', 'b', 'e', 's</w>'): 1,
#  ('d', 'r', 'e', 's', 's</w>'): 1,
#  ('c', 'l', 'o', 's', 'e', 't', 's</w>'): 1,
#  ('t', 'r', 'o', 'u', 's', 'e', 'r</w>'): 1,
#  ('p', 'r', 'e', 's', 's', 'e', 's</w>'): 1,
#  ('c', 'o', 'm', 'p', 'l', 'e', 'x</w>'): 1,
#  ('s',
#   'i',
#   'm',
#   'p',
#   'l',
#   'i',
#   'f',
#   'i',
#   'c',
#   'a',
#   't',
#   'i',
#   'o',
#   'n',
#   's</w>'): 1,
#  ('m', 'i', 'l', 'l', 'i', 'o', 'n', 'a', 'i', 'r', 'e</w>'): 1,
#  ('d', 'o', 'm', 'e', 's', 't', 'i', 'c</w>'): 1,
#  ('e', 'c', 'o', 'n', 'o', 'm', 'y</w>'): 1,
#  ('w', 'h', 'e', 'n', 'e', 'v', 'e', 'r</w>'): 1,
#  ('p', 'a', 'i', 'd</w>'): 1,
#  ('e', 'x', 'p', 'e', 'c', 't', 'e', 'd</w>'): 1,
#  ('t', 'r', 'i', 'b', 'u', 't', 'e</w>'): 1,
#  ('t', 'h', 'r', 'o', 'w', 'i', 'n', 'g</w>'): 1,
#  ('c', 'h', 'e', 's', 't</w>'): 1,
#  ('h', 'o', 'w</w>'): 6,
#  ('l', 'i', 'v', 'e</w>'): 1,
#  ('w', 'i', 't', 'h', 'o', 'u', 't</w>'): 3,
#  ('e', 'n', 'd</w>'): 4,
#  ('f', 'o', 'r', 'e', 's', 'e', 'e', 'n</w>'): 1,
#  ('O', 'n', 'l', 'y</w>'): 3,
#  ('s', 'p', 'i', 't', 'e</w>'): 2,
#  ('c', 'h', 'a', 'r', 'm', 'i', 'n', 'g</w>'): 1,
#  ('d', 'i', 's', 'a', 'r', 'm', 'i', 'n', 'g</w>'): 1,
#  ('l', 'o', 'n', 'g', 'e', 'd</w>'): 2,
#  ('c', 'r', 'y</w>'): 2,
#  ('B', 'e</w>'): 2,
#  ('d', 'i', 's', 's', 'a', 't', 'i', 's', 'f', 'i', 'e', 'd</w>'): 2,
#  ('l', 'e', 'i', 's', 'u', 'r', 'e</w>'): 1,
#  ('o', 'n', 'c', 'e</w>'): 3,
#  ('d', 'i', 'a', 'g', 'n', 'o', 's', 'i', 's</w>'): 1,
#  ('s', 'u', 'f', 'f', 'e', 'r', 'e', 'd</w>'): 1,
#  ('u', 'n', 'e', 'x', 'p', 'e', 'c', 't', 'e', 'd</w>'): 2,
#  ('c', 'h', 'e', 'c', 'k</w>'): 1,
#  ('T', 'h', 'i', 's</w>'): 1,
#  ('l', 'a', 'i', 'r</w>'): 1,
#  ('l', 'e', 'a', 'd', 'i', 'n', 'g</w>'): 1,
#  ('d', 'a', 'r', 'k</w>'): 1,
#  ('p', 'l', 'a', 'i', 'n</w>'): 3,
#  ('f', 'l', 'o', 'r', 'i', 'd</w>'): 1,
#  ('s', 'q', 'u', 'a', 'r', 'e</w>'): 1,
#  ('l', 'e', 'a', 't', 'h', 'e', 'r', 'y</w>'): 1,
#  ('e', 'f', 'f', 'e', 'c', 't', 's</w>'): 1,
#  ('b', 'r', 'i', 'c</w>'): 1,
#  ('b', 'r', 'a', 'c</w>'): 1,
#  ('n', 'o', 'n', 'e</w>'): 1,
#  ('a', 'i', 'r</w>'): 1,
#  ('p', 'o', 's', 'i', 'n', 'g</w>'): 2,
#  ('r', 'e', 'p', 'r', 'o', 'd', 'u', 'c', 't', 'i', 'o', 'n</w>'): 1,
#  ('w', 'e', 'e', 'k', 'l', 'y</w>'): 1,
#  ('a', 'b', 'o', 'v', 'e</w>'): 4,
#  ('l', 'e', 'a', 's', 't</w>'): 1,
#  ('s', 'i', 'g', 'n</w>'): 1,
#  ('u', 's', 'e', 'd</w>'): 1,
#  ('s', 't', 'u', 'd', 'i', 'o</w>'): 1,
#  ('h', 'o', 'm', 'e</w>'): 1,
#  ('a', 'b', 's', 'o', 'l', 'u', 't', 'e</w>'): 1,
#  ('f', 'i', 'n', 'a', 'l', 'i', 't', 'y</w>'): 1,
#  ('b', 'r', 'e', 'a', 'k</w>'): 1,
#  ('D', 'o</w>'): 2,
#  ('d', 'a', 'b', 'b', 'l', 'e</w>'): 2,
#  ('p', 'a', 'i', 'n', 't</w>'): 6,
#  ('a', 'n', 'y</w>'): 4,
#  ('t', 'r', 'a', 'c', 'e</w>'): 1,
#  ('a', 'c', 't', 'i', 'v', 'i', 't', 'y</w>'): 1,
#  ('N', 'e', 'v', 'e', 'r</w>'): 2,
#  ('b', 'r', 'i', 'e', 'f', 'l', 'y</w>'): 1,
#  ('O', 'r</w>'): 1,
#  ('w', 'a', 't', 'e', 'r</w>'): 1,
#  ('c', 'o', 'l', 'o', 'u', 'r</w>'): 2,
#  ('e', 't', 'c', 'h', 'i', 'n', 'g</w>'): 1,
#  ('d', 'i', 'm</w>'): 1,
#  ('p', 'a', 'l', 'e', 'd</w>'): 1,
#  ('s', 'u', 'n', 'b', 'u', 'r', 'n</w>'): 1,
#  ('n', 'e', 'v', 'e', 'r</w>'): 4,
#  ('t', 'o', 'u', 'c', 'h', 'e', 'd</w>'): 1,
#  ('t', 'o', 'l', 'd</w>'): 6,
#  ('f', 'l', 'a', 's', 'h</w>'): 1,
#  ('a', 'n', 'y', 't', 'h', 'i', 'n', 'g</w>'): 2,
#  ('e', 'l', 's', 'e</w>'): 2,
#  ('i', 'n', 's', 't', 'i', 'n', 'c', 't', 'i', 'v', 'e', 'l', 'y</w>'): 2,
#  ('e', 'm', 'b', 'a', 'r', 'r', 'a', 's', 's', 'e', 'd</w>'): 1,
#  ('d', 'i', 's', 'c', 'o', 'v', 'e', 'r', 'y</w>'): 1,
#  ('e', 'y', 'e</w>'): 1,
#  ('f', 'e', 'l', 'l</w>'): 1,
#  ('s', 'm', 'a', 'l', 'l</w>'): 1,
#  ('b', 'r', 'e', 'a', 'k', 'i', 'n', 'g</w>'): 1,
#  ('o', 'a', 'k</w>'): 1,
#  ('p', 'a', 'n', 'e', 'l', 'l', 'i', 'n', 'g</w>'): 1,
#  ('J', 'o', 'v', 'e</w>'): 3,
#  ('s', 'k', 'e', 't', 'c', 'h</w>'): 4,
#  ('d', 'o', 'n', 'k', 'e', 'y</w>'): 6,
#  ('s', 't', 'a', 'n', 'd', 'i', 'n', 'g</w>'): 1,
#  ('r', 'a', 'i', 'n</w>'): 1,
#  ('w', 'a', 'l', 'l</w>'): 2,
#  ('B', 'y</w>'): 2,
#  ('S', 't', 'r', 'o', 'u', 'd</w>'): 17,
#  ('c', 'r', 'i', 'e', 'd</w>'): 1,
#  ('s', 'i', 'l', 'e', 'n', 't</w>'): 1,
#  ('c', 'l', 'o', 's', 'e</w>'): 2,
#  ('b', 'e', 'h', 'i', 'n', 'd</w>'): 4,
#  ('b', 'r', 'e', 'a', 't', 'h', 'i', 'n', 'g</w>'): 1,
#  ('q', 'u', 'i', 'c', 'k', 'l', 'y</w>'): 1,
#  ('M', 'a', 'd', 'e</w>'): 1,
#  ('d', 'o', 'z', 'e', 'n</w>'): 1,
#  ('l', 'i', 'n', 'e', 's</w>'): 1,
#  ('e', 'v', 'e', 'r', 'l', 'a', 's', 't', 'i', 'n', 'g</w>'): 2,
#  ('f', 'o', 'u', 'n', 'd', 'a', 't', 'i', 'o', 'n', 's</w>'): 3,
#  ('Y', 'o', 'u</w>'): 3,
#  ('l', 'u', 'c', 'k', 'y</w>'): 1,
#  ('c', 'h', 'a', 'p</w>'): 1,
#  ('a', 'n', 's', 'w', 'e', 'r', 'e', 'd</w>'): 2,
#  ('s', 'l', 'o', 'w', 'l', 'y</w>'): 1,
#  ('g', 'a', 'v', 'e</w>'): 1,
#  ('A', 'h</w>'): 2,
#  ('e', 'v', 'e', 'n</w>'): 3,
#  ('k', 'n', 'e', 'w</w>'): 7,
#  ('S', 't', 'r', 'o', 'u', 'd', 's</w>'): 2,
#  ('i', 'n', 'f', 'l', 'e', 'x', 'i', 'b', 'l', 'e</w>'): 1,
#  ('h', 'e', 'r', 'm', 'i', 't</w>'): 1,
#  ('d', 'e', 'a', 'd</w>'): 5,
#  ('W', 'h', 'e', 'n</w>'): 4,
#  ('m', 'u', 'c', 'h</w>'): 2,
#  ('a', 'm', 'a', 'z', 'e', 'm', 'e', 'n', 't</w>'): 1,
#  ('e', 's', 'c', 'a', 'p', 'e</w>'): 1,
#  ('d', 'e', 'p', 'r', 'e', 'c', 'a', 't', 'i', 'n', 'g</w>'): 2,
#  ('a', 'w', 'f', 'u', 'l</w>'): 1,
#  ('s', 'i', 'm', 'p', 'l', 'e', 't', 'o', 'n</w>'): 1,
#  ('H', 'e', 'r</w>'): 1,
#  ('i', 'd', 'e', 'a</w>'): 2,
#  ('d', 'o', 'n', 'e</w>'): 5,
#  ('f', 'a', 's', 'h', 'i', 'o', 'n', 'a', 'b', 'l', 'e</w>'): 2,
#  ('p', 'a', 'i', 'n', 't', 'e', 'r</w>'): 2,
#  ('a', 'h</w>'): 1,
#  ('p', 'o', 'o', 'r</w>'): 4,
#  ('s', 'u', 'r', 'e', 's', 't</w>'): 1,
#  ('p', 'r', 'o', 'c', 'l', 'a', 'i', 'm', 'i', 'n', 'g</w>'): 1,
#  ('g', 'r', 'e', 'a', 't', 'n', 'e', 's', 's</w>'): 1,
#  ('f', 'o', 'r', 'c', 'i', 'n', 'g</w>'): 1,
#  ('p', 'u', 'r', 'b', 'l', 'i', 'n', 'd</w>'): 1,
#  ('p', 'u', 'b', 'l', 'i', 'c</w>'): 2,
#  ('W', 'a', 's</w>'): 1,
#  ('h', 'i', 's', 't', 'o', 'r', 'y</w>'): 3,
#  ('T', 'h', 'a', 't</w>'): 3,
#  ('b', 'e', 'l', 'i', 'e', 'v', 'e', 'd</w>'): 2,
#  ('g', 'l', 'o', 'r', 'i', 'e', 'd</w>'): 1,
#  ('b', 'e', 'a', 'r</w>'): 2,
#  ('v', 'a', 'r', 'n', 'i', 's', 'h', 'i', 'n', 'g</w>'): 1,
#  ('d', 'a', 'y', 's</w>'): 2,
#  ('n', 'e', 'a', 'r</w>'): 4,
#  ('f', 'r', 'a', 'g', 'm', 'e', 'n', 't</w>'): 1,
#  ('g', 'r', 'o', 'p', 'i', 'n', 'g</w>'): 2,
#  ('f', 'r', 'a', 'g', 'm', 'e', 'n', 't', 's</w>'): 1,
#  ('w', 'h', 'o', 'l', 'e</w>'): 2,
#  ('c', 'u', 'r', 'i', 'o', 'u', 's</w>'): 1,
#  ('h', 'a', 'p', 'p', 'e', 'n', 'e', 'd</w>'): 3,
#  ('v', 'o', 'i', 'c', 'e</w>'): 1,
#  ('i', 'n', 's', 'e', 'n', 's', 'i', 'b', 'l', 'e</w>'): 1,
#  ('i', 'r', 'o', 'n', 'y</w>'): 2,
#  ('l', 'a', 'u', 'g', 'h', 'e', 'd</w>'): 2,
#  ('t', 'h', 'r', 'e', 'w</w>'): 2,
#  ('T', 'h', 'e', 'r', 'e</w>'): 3,
#  ('t', 'h', 'i', 'n', 'g</w>'): 6,
#  ('f', 'o', 'r', 'c', 'e', 'd</w>'): 1,
#  ('c', 'u', 'r', 'e', 'd</w>'): 2,
#  ('r', 'e', 'a', 's', 'o', 'n</w>'): 2,
#  ('i', 'd', 'l', 'e</w>'): 1,
#  ('c', 'o', 'm', 'p', 'a', 'n', 'i', 'o', 'n</w>'): 1,
#  ('s', 'e', 'r', 'i', 'o', 'u', 's</w>'): 1,
#  ('d', 'e', 's', 'i', 'r', 'e</w>'): 1,
#  ('u', 'n', 'd', 'e', 'r', 's', 't', 'a', 'n', 'd</w>'): 2,
#  ('w', 'i', 's', 'h</w>'): 1,
#  ('t', 'e', 'l', 'l</w>'): 4,
#  ('t', 'w', 'i', 'r', 'l', 'i', 'n', 'g</w>'): 1,
#  ('f', 'i', 'n', 'g', 'e', 'r', 's</w>'): 1,
#  ('c', 'i', 'g', 'a', 'r', 'e', 't', 't', 'e</w>'): 1,
#  ('f', 'o', 'r', 'g', 'o', 't', 't', 'e', 'n</w>'): 1,
#  ('S', 'u', 'd', 'd', 'e', 'n', 'l', 'y</w>'): 1,
#  ('t', 'o', 'w', 'a', 'r', 'd</w>'): 1,
#  ('s', 'u', 's', 'p', 'e', 'c', 't', 'e', 'd</w>'): 1,
#  ('l', 'o', 'a', 't', 'h', 'i', 'n', 'g</w>'): 1,
#  ('g', 'e', 's', 't', 'u', 'r', 'e</w>'): 1,
#  ('n', 'e', 'g', 'a', 't', 'i', 'v', 'e', 'd</w>'): 1,
#  ('s', 'h', 'r', 'u', 'g</w>'): 1,
#  ('c', 'a', 'r', 'e</w>'): 1,
#  ('s', 't', 'r', 'a', 'w</w>'): 1,
#  ('t', 'i', 'e</w>'): 1,
#  ('u', 's</w>'): 2,
#  ('s', 'l', 'i', 'g', 'h', 't', 'l', 'y</w>'): 1,
#  ('b', 'i', 't', 't', 'e', 'r', 'n', 'e', 's', 's</w>'): 1,
#  ('d', 'e', 'e', 'p</w>'): 2,
#  ('c', 'h', 'a', 'i', 'r', 's</w>'): 1,
#  ('f', 'o', 'r', 'w', 'a', 'r', 'd</w>'): 1,
#  ('m', 'a', 'k', 'e</w>'): 1,
#  ('y', 'o', 'u', 'r', 's', 'e', 'l', 'f</w>'): 1,
#  ('c', 'o', 'm', 'f', 'o', 'r', 't', 'a', 'b', 'l', 'e</w>'): 1,
#  ('a', 'r', 'e</w>'): 3,
#  ('c', 'i', 'g', 'a', 'r', 's</w>'): 1,
#  ('e', 'l', 'b', 'o', 'w</w>'): 1,
#  ('c', 'o', 'n', 't', 'i', 'n', 'u', 'e', 'd</w>'): 1,
#  ('w', 'a', 'n', 'd', 'e', 'r</w>'): 1,
#  ('s', 't', 'o', 'p', 'p', 'i', 'n', 'g</w>'): 1,
#  ('H', 'o', 'w</w>'): 1,
#  ('f', 'i', 'v', 'e</w>'): 1,
#  ('m', 'i', 'n', 'u', 't', 'e', 's</w>'): 1,
#  ('t', 'a', 'k', 'e</w>'): 1,
#  ('l', 'o', 'n', 'g', 'e', 'r</w>'): 1,
#  ('h', 'a', 'p', 'p', 'e', 'n</w>'): 2,
#  ('r', 'e', 'm', 'e', 'm', 'b', 'e', 'r</w>'): 2,
#  ('s', 'u', 'r', 'p', 'r', 'i', 's', 'e', 'd</w>'): 1,
#  ('p', 'l', 'e', 'a', 's', 'e', 'd</w>'): 1,
#  ('g', 'o', 't</w>'): 3,
#  ('g', 'o', 'n', 'e</w>'): 1,
#  ('s', 't', 'r', 'e', 'a', 'm</w>'): 2,
#  ('e', 'c', 'h', 'o', 'e', 'd</w>'): 1,
#  ('u', 's', 'u', 'a', 'l</w>'): 1,
#  ('p', 'l', 'a', 't', 'i', 't', 'u', 'd', 'e', 's</w>'): 1,
#  ('f', 'a', 'i', 'l', 'u', 'r', 'e</w>'): 2,
#  ('l', 'e', 'f', 't</w>'): 3,
#  ('o', 'u', 'r', 's', 'e', 'l', 'v', 'e', 's</w>'): 1,
#  ('s', 'w', 'e', 'p', 't</w>'): 1,
#  ('a', 'l', 'o', 'n', 'g</w>'): 1,
#  ('h', 'i', 'g', 'h</w>'): 1,
#  ('c', 'u', 'r', 'r', 'e', 'n', 't</w>'): 2,
#  ('o', 'f', 'f</w>'): 4,
#  ('e', 'g', 'r', 'e', 'g', 'i', 'o', 'u', 's</w>'): 1,
#  ('m', 'o', 'o', 'd</w>'): 1,
#  ('L', 'o', 'r', 'd</w>'): 1,
#  ('f', 'o', 'r', 'g', 'i', 'v', 'e</w>'): 1,
#  ('p', 'a', 't', 'h', 'o', 's</w>'): 1,
#  ('c', 'a', 'r', 'e', 'e', 'r</w>'): 1,
#  ('c', 'r', 'o', 'w', 'n', 'e', 'd</w>'): 1,
#  ('m', 'e', 'a', 'n', 't</w>'): 1,
#  ('n', 'o', 't', 'h', 'i', 'n', 'g</w>'): 1,
#  ('s', 't', 'a', 'm', 'm', 'e', 'r</w>'): 1,
#  ('s', 'o', 'm', 'e', 't', 'h', 'i', 'n', 'g</w>'): 1,
#  ('p', 'o', 'v', 'e', 'r', 't', 'y</w>'): 1,
#  ('g', 'e', 't', 't', 'i', 'n', 'g</w>'): 2,
#  ('p', 'r', 'o', 'd', 'i', 'g', 'i', 'o', 'u', 's</w>'): 1,
#  ('p', 'h', 'r', 'a', 's', 'e</w>'): 1,
#  ('p', 'r', 'i', 'n', 'c', 'e', 'l', 'y</w>'): 1,
#  ('T', 'h', 'e', 'n</w>'): 2,
#  ('a', 'l', 'o', 'n', 'e</w>'): 2,
#  ('t', 'r', 'a', 'p', 's</w>'): 2,
#  ('a', 'd', 'v', 'a', 'n', 'c', 'e</w>'): 1,
#  ('t', 'w', 'e', 'n', 't', 'y</w>'): 2,
#  ('f', 'o', 'u', 'r</w>'): 1,
#  ('h', 'o', 'u', 'r', 's</w>'): 1,
#  ('h', 'e', 'a', 'r', 't</w>'): 2,
#  ('d', 'i', 's', 'e', 'a', 's', 'e</w>'): 1,
#  ('p', 'r', 'e', 'l', 'i', 'm', 'i', 'n', 'a', 'r', 'y</w>'): 1,
#  ('d', 'e', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'n</w>'): 1,
#  ('c', 'l', 'e', 'a', 'r</w>'): 1,
#  ('u', 'n', 't', 'o', 'u', 'c', 'h', 'e', 'd</w>'): 1,
#  ('t', 'w', 'i', 'c', 'e</w>'): 1,
#  ('i', 'n', 's', 'i', 'g', 'n', 'i', 'f', 'i', 'c', 'a', 'n', 't</w>'): 1,
#  ('d', 'i', 'n', 'g', 'y</w>'): 1,
#  ('N', 'o', 'w</w>'): 1,
#  ('s', 'u', 'p', 'e', 'r', 'b</w>'): 1,
#  ('g', 'l', 'a', 'd</w>'): 2,
#  ('m', 'e', 'r', 'e', 'l', 'y</w>'): 1,
#  ('a', 'e', 's', 't', 'h', 'e', 't', 'i', 'c</w>'): 1,
#  ('s', 'u', 'b', 'j', 'e', 'c', 't</w>'): 2,
#  ('s', 't', 'r', 'a', 'n', 'g', 'e</w>'): 1,
#  ('l', 'i', 'k', 'e', 'n', 'e', 's', 's</w>'): 1,
#  ('a', 'f', 'f', 'e', 'c', 't</w>'): 1,
#  ('q', 'u', 'e', 'e', 'r', 'l', 'y</w>'): 1,
#  ('b', 'l', 'o', 'c', 'k', 'e', 'd</w>'): 1,
#  ('w', 'a', 't', 'c', 'h', 'i', 'n', 'g</w>'): 5,
#  ('s', 'e', 'n', 's', 'a', 't', 'i', 'o', 'n</w>'): 1,
#  ('w', 'o', 'r', 'k', 'i', 'n', 'g</w>'): 1,
#  ('s', 't', 'r', 'o', 'k', 'e', 's</w>'): 1,
#  ('w', 'i', 'l', 'd</w>'): 1,
#  ('n', 'e', 'r', 'v', 'o', 'u', 's</w>'): 1,
#  ('u', 'n', 'c', 'e', 'r', 't', 'a', 'i', 'n</w>'): 1,
#  ('O', 'n', 'c', 'e</w>'): 1,
#  ...}

# %%
symbol_pairs = trainer._count_symbol_pairs(init_vocab)
sorted_symbol_pairs = sorted(symbol_pairs.items(), key=lambda x: x[1], reverse=True)
sorted_symbol_pairs[:10]
# Out:
# [(('e', '</w>'), 727),
#  (('d', '</w>'), 464),
#  (('t', '</w>'), 437),
#  (('h', 'e'), 408),
#  (('t', 'h'), 365),
#  (('s', '</w>'), 352),
#  (('i', 'n'), 289),
#  (('n', '</w>'), 266),
#  (('y', '</w>'), 234),
#  (('h', 'a'), 197)]

# %%
from collections import defaultdict
from typing import Dict, List, Tuple


merges: List[Tuple[str, str]] = []

# %%
best_pair = max(symbol_pairs, key=symbol_pairs.get)
best_pair
# Out:
# ('e', '</w>')

# %%
# add the best pair to the merges list
merges.append(best_pair)

# %%
merged_vocab = trainer._merge_vocab(best_pair, init_vocab)
sorted_merged_vocab = sorted(merged_vocab.items(), key=lambda x: x[1], reverse=True)
sorted_merged_vocab[:10]
# Out:
# [(('t', 'h', 'e</w>'), 168),
#  (('I', '</w>'), 120),
#  (('o', 'f', '</w>'), 98),
#  (('t', 'o', '</w>'), 97),
#  (('a', '</w>'), 82),
#  (('a', 'n', 'd', '</w>'), 74),
#  (('w', 'a', 's', '</w>'), 72),
#  (('i', 't', '</w>'), 66),
#  (('h', 'e</w>'), 64),
#  (('h', 'i', 's', '</w>'), 61)]

# %%
num_merges = 10000
for i in range(num_merges):
    symbol_pairs = trainer._count_symbol_pairs(vocab)

    if not symbol_pairs:
        print(f"🛑 No more symbol pairs left after {i} merges.")
        break

    best_pair = max(symbol_pairs, key=symbol_pairs.get)
    vocab = trainer._merge_vocab(best_pair, vocab)
    merges.append(best_pair)
# Out:
# 🛑 No more symbol pairs left after 2159 merges.

# %%
merges
# Out:
# [('e', '</w>'),
#  ('h', 'e'),
#  ('i', 'n'),
#  ('t', 'he'),
#  ('h', 'a'),
#  ('o', 'u'),
#  ('r', 'e'),
#  ('a', 'n'),
#  ('o', 'n'),
#  ('i', 't'),
#  ('i', 's'),
#  ('e', 'd'),
#  ('a', 's'),
#  ('t', 'o'),
#  ('in', 'g'),
#  ('e', 'n'),
#  ('o', 'f'),
#  ('e', 'r'),
#  ('s', 't'),
#  ('a', 't'),
#  ('an', 'd'),
#  ('s', 'e'),
#  ('o', 'r'),
#  ('l', 'e'),
#  ('b', 'e'),
#  ('w', 'as'),
#  ('a', 'r'),
#  ('m', 'e'),
#  ('ha', 't'),
#  ('h', 'is'),
#  ('o', 'w'),
#  ('a', 'l'),
#  ('a', 'c'),
#  ('v', 'e'),
#  ('i', 'c'),
#  ('i', 'm'),
#  ('l', 'y'),
#  ('u', 'r'),
#  ('t', 'hat'),
#  ('ha', 'd'),
#  ('g', 'h'),
#  ('t', 'h'),
#  ('d', 'e'),
#  ('m', 'y'),
#  ('e', 's'),
#  ('a', 'y'),
#  ('a', 'in'),
#  ('h', 'im'),
#  ('t', 'r'),
#  ('l', 'd'),
#  ('r', 'o'),
#  ('i', 'd'),
#  ('l', 'l'),
#  ('a', 'b'),
#  ('u', 't'),
#  ('w', 'it'),
#  ('on', 'e'),
#  ('l', 'i'),
#  ('i', 'r'),
#  ('n', 'd'),
#  ('wit', 'h'),
#  ('n', 'o'),
#  ('i', 'on'),
#  ('en', 't'),
#  ('t', 'e'),
#  ('s', 'u'),
#  ('y', 'ou'),
#  ('f', 'e'),
#  ('s', 'o'),
#  ('ou', 'ld'),
#  ('gh', 't'),
#  ('r', 'a'),
#  ('n', 'e'),
#  ('ur', 'n'),
#  ('ha', 've'),
#  ('o', 'm'),
#  ('k', 'e'),
#  ('ou', 't'),
#  ('v', 'er'),
#  ('ac', 'k'),
#  ('t', 'er'),
#  ('c', 'h'),
#  ('f', 'or'),
#  ('u', 're'),
#  ('u', 'p'),
#  ('w', 'e'),
#  ('p', 'ain'),
#  ('l', 'o'),
#  ('c', 'e'),
#  ('a', 'd'),
#  ('he', 'r'),
#  ('b', 'urn'),
#  ('l', 'f'),
#  ('T', 'he'),
#  ('c', 't'),
#  ('s', 'he'),
#  ('pain', 't'),
#  ('ow', 'n'),
#  ('s', 'a'),
#  ('G', 'is'),
#  ('Gis', 'burn'),
#  ('al', 'l'),
#  ('ou', 'r'),
#  ('s', 'h'),
#  ('in', 'd'),
#  ('ou', 'd'),
#  ('q', 'u'),
#  ('S', 'tr'),
#  ('Str', 'oud'),
#  ('se', 'lf'),
#  ('be', 'en'),
#  ('ic', 't'),
#  ('no', 't'),
#  ('w', 'h'),
#  ('m', 'o'),
#  ('ou', 'gh'),
#  ('p', 'ict'),
#  ('pict', 'ure'),
#  ('t', 'i'),
#  ('re', 'd'),
#  ('u', 'st'),
#  ('u', 's'),
#  ('ou', 's'),
#  ('a', 'u'),
#  ('w', 'he'),
#  ('J', 'ack'),
#  ('g', 'o'),
#  ('at', 'ion'),
#  ('m', 'i'),
#  ('s', 'ay'),
#  ('f', 'ac'),
#  ('k', 'ed'),
#  ('I', 't'),
#  ('p', 'o'),
#  ('g', 'e'),
#  ('n', 'ow'),
#  ('se', 'e'),
#  ('H', 'e'),
#  ('w', 'ay'),
#  ('b', 'ut'),
#  ('b', 'y'),
#  ('d', 'is'),
#  ('p', 'p'),
#  ('i', 've'),
#  ('th', 'ing'),
#  ('sa', 'id'),
#  ('the', 'r'),
#  ('o', 'd'),
#  ('i', 'ed'),
#  ('w', 'ould'),
#  ('l', 'as'),
#  ('d', 'o'),
#  ('f', 'o'),
#  ('lo', 'o'),
#  ('ar', 'd'),
#  ('b', 'r'),
#  ('i', 'f'),
#  ('c', 'o'),
#  ('c', 'ould'),
#  ('j', 'ust'),
#  ('a', 'm'),
#  ('e', 'ver'),
#  ('p', 'l'),
#  ('ab', 'le'),
#  ('e', 'x'),
#  ('it', 'y'),
#  ('p', 'e'),
#  ('ab', 'out'),
#  ('m', 'an'),
#  ('ou', 'ght'),
#  ('g', 're'),
#  ('p', 'r'),
#  ('i', 'v'),
#  ('u', 'n'),
#  ('ic', 'k'),
#  ('w', 'or'),
#  ('on', 'ly'),
#  ('e', 'y'),
#  ('th', 'r'),
#  ('be', 'c'),
#  ('d', 'id'),
#  ('B', 'ut'),
#  ('st', 'r'),
#  ('e', 'v'),
#  ('whe', 'n'),
#  ('k', 'ing'),
#  ('p', 're'),
#  ('c', 'he'),
#  ('s', 'ur'),
#  ('g', 'l'),
#  ('paint', 'ing'),
#  ('him', 'self'),
#  ('w', 'hat'),
#  ('en', 'd'),
#  ('u', 'l'),
#  ('the', 'y'),
#  ('we', 're'),
#  ('A', 'nd'),
#  ('wh', 'o'),
#  ('a', 'g'),
#  ('thr', 'ough'),
#  ('t', 'ing'),
#  ('on', 'g'),
#  ('tr', 'a'),
#  ('es', 's'),
#  ('so', 'me'),
#  ('ar', 't'),
#  ('a', 're'),
#  ('c', 'ur'),
#  ('d', 'own'),
#  ('an', 't'),
#  ('c', 'on'),
#  ('ou', 'nd'),
#  ('at', 'e'),
#  ('i', 'g'),
#  ('u', 'nd'),
#  ('und', 'er'),
#  ('ro', 'om'),
#  ('S', 'he'),
#  ('k', 'now'),
#  ('th', 'ought'),
#  ('i', 'de'),
#  ('n', 't'),
#  ('p', 's'),
#  ('t', 'a'),
#  ('it', 'e'),
#  ('f', 't'),
#  ('ey', 'es'),
#  ('li', 'ke'),
#  ('fac', 't'),
#  ('j', 'e'),
#  ('l', 'it'),
#  ('f', 'a'),
#  ('ha', 'nd'),
#  ('a', 'f'),
#  ('i', 'l'),
#  ('b', 'ack'),
#  ('e', 'l'),
#  ('r', 'y'),
#  ('be', 't'),
#  ('p', 'le'),
#  ('at', 'h'),
#  ('an', 'ce'),
#  ('the', 're'),
#  ('m', 'ed'),
#  ('u', 'm'),
#  ('i', 'ous'),
#  ('e', 'll'),
#  ('k', 'ne'),
#  ('c', 'an'),
#  ('w', 'ing'),
#  ('our', 'se'),
#  ('R', 'ick'),
#  ('Rick', 'ha'),
#  ('Rickha', 'm'),
#  ('sh', 'ow'),
#  ('fo', 're'),
#  ('ag', 'ain'),
#  ('fe', 'l'),
#  ('fel', 't'),
#  ('l', 'ing'),
#  ('b', 'le'),
#  ('to', 'o'),
#  ('ac', 'e'),
#  ('su', 'ch'),
#  ('bec', 'au'),
#  ('becau', 'se'),
#  ('p', 'ut'),
#  ('re', 'st'),
#  ('l', 'a'),
#  ('h', 'o'),
#  ('p', 'er'),
#  ('f', 'ro'),
#  ('fro', 'm'),
#  ('li', 'ght'),
#  ('s', 'ent'),
#  ('st', 'ro'),
#  ('c', 'ha'),
#  ('o', 've'),
#  ('an', 'y'),
#  ('w', 'at'),
#  ('kne', 'w'),
#  ('al', 'way'),
#  ('alway', 's'),
#  ('ra', 'ther'),
#  ('he', 'd'),
#  ('i', 'll'),
#  ('w', 'om'),
#  ('las', 't'),
#  ('s', 'it'),
#  ('c', 'ourse'),
#  ('s', 's'),
#  ('ct', 'ed'),
#  ('s', 'to'),
#  ('an', 'c'),
#  ('ar', 's'),
#  ('fac', 'e'),
#  ('lit', 't'),
#  ('litt', 'le'),
#  ('l', 'au'),
#  ('c', 'om'),
#  ('al', 'ly'),
#  ('w', 'ent'),
#  ('y', 'e'),
#  ('e', 'k'),
#  ('g', 'iv'),
#  ('giv', 'en'),
#  ('p', 'ro'),
#  ('w', 'i'),
#  ('e', 'as'),
#  ('d', 'ra'),
#  ('af', 'ter'),
#  ('w', 'ant'),
#  ('in', 'to'),
#  ('ation', 's'),
#  ('bet', 'we'),
#  ('betwe', 'en'),
#  ('f', 'ound'),
#  ('the', 'ir'),
#  ('de', 'ad'),
#  ('s', 'p'),
#  ('ge', 't'),
#  ('b', 'je'),
#  ('bje', 'ct'),
#  ('picture', 's'),
#  ('u', 'c'),
#  ('f', 'ir'),
#  ('fir', 'st'),
#  ('G', 'r'),
#  ('Gr', 'ind'),
#  ('Grind', 'le'),
#  ('i', 'e'),
#  ('ar', 'm'),
#  ('wor', 'k'),
#  ('paint', 'ed'),
#  ('h', 'ow'),
#  ('ch', 'ing'),
#  ('to', 'ld'),
#  ('d', 'on'),
#  ('don', 'ke'),
#  ('donke', 'y'),
#  ('go', 'od'),
#  ('ll', 'ow'),
#  ('en', 'ough'),
#  ('pr', 'is'),
#  ('T', 'h'),
#  ('O', 'f'),
#  ('th', 'in'),
#  ('it', 's'),
#  ('r', 'of'),
#  ('a', 'de'),
#  ('sh', 'ould'),
#  ('ti', 'll'),
#  ('l', 'at'),
#  ('d', 'd'),
#  ('on', 'd'),
#  ('O', 'n'),
#  ('wi', 'fe'),
#  ('ne', 'ar'),
#  ('mi', 'ght'),
#  ('d', 'ay'),
#  ('in', 't'),
#  ('h', 'ou'),
#  ('hou', 'se'),
#  ('no', 'te'),
#  ('c', 'r'),
#  ('m', 'ent'),
#  ('l', 'ic'),
#  ('s', 'im'),
#  ('be', 'g'),
#  ('t', 'urn'),
#  ('turn', 'ed'),
#  ('O', 'h'),
#  ('loo', 'ked'),
#  ('at', 'ing'),
#  ('p', 'as'),
#  ('f', 'ra'),
#  ('p', 'or'),
#  ('por', 'tra'),
#  ('portra', 'it'),
#  ('g', 'r'),
#  ('whe', 're'),
#  ('he', 'ad'),
#  ('W', 'ell'),
#  ('p', 'u'),
#  ('st', 'and'),
#  ('Y', 'es'),
#  ('mo', 're'),
#  ('s', 'we'),
#  ('sa', 'w'),
#  ('ke', 't'),
#  ('m', 'in'),
#  ('ne', 'ver'),
#  ('d', 'one'),
#  ('ha', 'pp'),
#  ('happ', 'en'),
#  ('te', 'll'),
#  ('qu', 'e'),
#  ('wat', 'ching'),
#  ('sur', 'pris'),
#  ('he', 'ar'),
#  ('i', 'ght'),
#  ('m', 'ar'),
#  ('ic', 'h'),
#  ('wom', 'en'),
#  ('Th', 'wing'),
#  ('sit', 'ter'),
#  ('c', 'ou'),
#  ('thin', 'k'),
#  ('C', 'rof'),
#  ('Crof', 't'),
#  ('er', 's'),
#  ('at', 'ed'),
#  ('show', 'y'),
#  ('p', 'a'),
#  ('so', 'l'),
#  ('be', 'ing'),
#  ('a', 'pp'),
#  ('c', 'us'),
#  ('th', 're'),
#  ('ek', 's'),
#  ('is', 't'),
#  ('k', 'en'),
#  ('in', 'ce'),
#  ('is', 's'),
#  ('fa', 'il'),
#  ('in', 'te'),
#  ('inte', 'rest'),
#  ('interest', 'ing'),
#  ('to', 'ry'),
#  ('li', 'fe'),
#  ('ter', 'r'),
#  ('my', 'self'),
#  ('ne', 'x'),
#  ('en', 'e'),
#  ('po', 'int'),
#  ('fe', 'ct'),
#  ('he', 're'),
#  ('i', 'o'),
#  ('s', 'at'),
#  ('sat', 'is'),
#  ('c', 'or'),
#  ('b', 're'),
#  ('o', 'bject'),
#  ('ive', 'ly'),
#  ('la', 'id'),
#  ('se', 't'),
#  ('the', 'm'),
#  ('at', 't'),
#  ('de', 'ar'),
#  ('p', 'an'),
#  ('t', 'ain'),
#  ('s', 'ing'),
#  ('mo', 'de'),
#  ('mode', 'st'),
#  ('p', 't'),
#  ('e', 'p'),
#  ('H', 'is'),
#  ('you', 'r'),
#  ('cha', 'ir'),
#  ('loo', 'king'),
#  ('n', 'ess'),
#  ('f', 'l'),
#  ('mo', 'v'),
#  ('mov', 'ed'),
#  ('a', 'ge'),
#  ('le', 't'),
#  ('o', 'ld'),
#  ('ha', 'lf'),
#  ('ge', 'st'),
#  ('s', 'mi'),
#  ('beg', 'an'),
#  ('st', 'ill'),
#  ('l', 'ong'),
#  ('pe', 'cted'),
#  ('ab', 'ove'),
#  ('s', 'ket'),
#  ('sket', 'ch'),
#  ('be', 'h'),
#  ('beh', 'ind'),
#  ('W', 'he'),
#  ('Whe', 'n'),
#  ('po', 'or'),
#  ('go', 't'),
#  ('of', 'f'),
#  ('c', 're'),
#  ('gre', 'at'),
#  ('surpris', 'e'),
#  ('gl', 'or'),
#  ('pp', 'ed'),
#  ('mar', 'r'),
#  ('marr', 'ied'),
#  ('R', 'iv'),
#  ('Riv', 'i'),
#  ('Rivi', 'er'),
#  ('Rivier', 'a'),
#  ('c', 'all'),
#  ('call', 'ed'),
#  ('cou', 'nt'),
#  ('u', 'e'),
#  ('li', 'ps'),
#  ('f', 'le'),
#  ('H', 'er'),
#  ('be', 'fore'),
#  ('loo', 'k'),
#  ('P', 'o'),
#  ('Po', 'or'),
#  ('m', 'ade'),
#  ('he', 'ard'),
#  ('ha', 'r'),
#  ('har', 'd'),
#  ('I', 'f'),
#  ('h', 'on'),
#  ('hon', 'our'),
#  ('t', 'on'),
#  ('hand', 'some'),
#  ('it', 'u'),
#  ('it', 'i'),
#  ('iti', 'es'),
#  ('v', 'o'),
#  ('ic', 'e'),
#  ('ye', 'ars'),
#  ('dd', 'en'),
#  ('dden', 'ly'),
#  ('w', 'ond'),
#  ('wond', 'er'),
#  ('wh', 'y'),
#  ('ct', 'ion'),
#  ('re', 'ally'),
#  ('T', 'o'),
#  ('sitter', 's'),
#  ('g', 'g'),
#  ('gg', 'ed'),
#  ('F', 'or'),
#  ('ta', 'ken'),
#  ('s', 'ince'),
#  ('M', 'iss'),
#  ('li', 'ft'),
#  ('l', 'ed'),
#  ('eas', 'el'),
#  ('ha', 'v'),
#  ('hav', 'ing'),
#  ('b', 'al'),
#  ('d', 'ed'),
#  ('b', 'ene'),
#  ('bene', 'ath'),
#  ('co', 'me'),
#  ('f', 'ul'),
#  ('re', 'as'),
#  ('e', 'f'),
#  ('h', 'us'),
#  ('hus', 'b'),
#  ('husb', 'and'),
#  ('t', 'his'),
#  ('c', 'ir'),
#  ('de', 'lic'),
#  ('delic', 'ate'),
#  ('r', 'u'),
#  ('pe', 'o'),
#  ('peo', 'ple'),
#  ('cor', 'n'),
#  ('mo', 'st'),
#  ('ut', 'e'),
#  ('ur', 'y'),
#  ('m', 'ust'),
#  ('re', 'nt'),
#  ('i', 'gh'),
#  ('te', 'en'),
#  ('t', 'able'),
#  ('o', 'ver'),
#  ('s', 'en'),
#  ('ever', 'y'),
#  ('thing', 's'),
#  ('t', 'en'),
#  ('uc', 'k'),
#  ('ti', 'me'),
#  ('se', 'en'),
#  ('b', 'ed'),
#  ('a', 'me'),
#  ('see', 'med'),
#  ('in', 'c'),
#  ('g', 'ar'),
#  ('l', 'and'),
#  ('M', 'y'),
#  ('ch', 'uc'),
#  ('chuc', 'ked'),
#  ('ro', 'se'),
#  ('su', 'n'),
#  ('gl', 'anc'),
#  ('glanc', 'ed'),
#  ('n', 'g'),
#  ('e', 't'),
#  ('l', 'ay'),
#  ('b', 'ar'),
#  ('dra', 'wing'),
#  ('room', 's'),
#  ('g', 'ive'),
#  ('is', 'ed'),
#  ('sim', 'p'),
#  ('v', 'as'),
#  ('cur', 'tain'),
#  ('curtain', 's'),
#  ('te', 'l'),
#  ('fra', 'me'),
#  ('str', 'ain'),
#  ('modest', 'y'),
#  ('a', 'way'),
#  ('a', 'ir'),
#  ('s', 'ity'),
#  ('c', 'ig'),
#  ('s', 'i'),
#  ('lau', 'gh'),
#  ('fo', 'llow'),
#  ('un', 'g'),
#  ('l', 'in'),
#  ('pu', 'she'),
#  ('pushe', 'd'),
#  ('man', 'age'),
#  ('p', 'ie'),
#  ('pie', 'ce'),
#  ('qu', 'al'),
#  ('c', 'le'),
#  ('st', 'ra'),
#  ('ir', 'on'),
#  ('lo', 'se'),
#  ('o', 'ther'),
#  ('sto', 'od'),
#  ('a', 've'),
#  ('smi', 'le'),
#  ('de', 'pre'),
#  ('depre', 'c'),
#  ('deprec', 'ating'),
#  ('the', 'n'),
#  ('k', 'ind'),
#  ('with', 'out'),
#  ('On', 'ly'),
#  ('on', 'ce'),
#  ('pl', 'ain'),
#  ('ig', 'n'),
#  ('che', 'd'),
#  ('J', 'ove'),
#  ('found', 'ations'),
#  ('Y', 'ou'),
#  ('ev', 'en'),
#  ('m', 'u'),
#  ('his', 'tory'),
#  ('T', 'hat'),
#  ('is', 'h'),
#  ('p', 'ing'),
#  ('happen', 'ed'),
#  ('The', 're'),
#  ('w', 'ard'),
#  ('le', 'ft'),
#  ('se', 'cre'),
#  ('secre', 't'),
#  ('stro', 'ke'),
#  ('que', 'st'),
#  ('quest', 'ion'),
#  ('a', 'p'),
#  ('g', 'en'),
#  ('gen', 'i'),
#  ('th', 'ough'),
#  ('fe', 'llow'),
#  ('he', 'ight'),
#  ('glor', 'y'),
#  ('d', 'ro'),
#  ('dro', 'pped'),
#  ('r', 'ich'),
#  ('is', 'hed'),
#  ('o', 'me'),
#  ('a', 'go'),
#  ('ab', 'd'),
#  ('abd', 'ic'),
#  ('abdic', 'ation'),
#  ('v', 'al'),
#  ('wor', 'd'),
#  ('r', 's'),
#  ('re', 'fle'),
#  ('v', 'is'),
#  ('vis', 'ta'),
#  ('or', 's'),
#  ('m', 'our'),
#  ('mour', 'n'),
#  ('ex', 'qu'),
#  ('exqu', 'is'),
#  ('exquis', 'ite'),
#  ('Her', 'mi'),
#  ('Hermi', 'a'),
#  ('ra', 'ft'),
#  ('te', 'ars'),
#  ('s', 'ha'),
#  ('e', 'qu'),
#  ('f', 'it'),
#  ('fe', 'w'),
#  ('t', 's'),
#  ('m', 'ur'),
#  ('je', 'al'),
#  ('jeal', 'ous'),
#  ('jealous', 'y'),
#  ('v', 'ind'),
#  ('vind', 'ic'),
#  ('vindic', 'ated'),
#  ('br', 'ought'),
#  ('ver', 'y'),
#  ('ar', 'y'),
#  ('th', 'o'),
#  ('tho', 'se'),
#  ('c', 'ked'),
#  ('te', 'ch'),
#  ('tech', 'n'),
#  ('re', 'sol'),
#  ('resol', 've'),
#  ('app', 'are'),
#  ('appare', 'nt'),
#  ('ir', 're'),
#  ('vo', 'c'),
#  ('d', 'u'),
#  ('d', 'ied'),
#  ('lat', 'er'),
#  ('we', 'eks'),
#  ('su', 'ddenly'),
#  ('m', 'p'),
#  ('c', 'u'),
#  ('cu', 'se'),
#  ('dra', 'gged'),
#  ('li', 'ked'),
#  ('eas', 'e'),
#  ('con', 't'),
#  ('fail', 'ed'),
#  ('br', 'u'),
#  ('bru', 'sh'),
#  ('app', 'e'),
#  ('a', 'red'),
#  ('dis', 'd'),
#  ('disd', 'ain'),
#  ('s', 'pe'),
#  ('c', 'ul'),
#  ('M', 'on'),
#  ('Mon', 'te'),
#  ('C', 'ar'),
#  ('Car', 'lo'),
#  ('c', 'au'),
#  ('cau', 'ght'),
#  ('p', 'in'),
#  ('b', 'or'),
#  ('nex', 't'),
#  ('p', 'al'),
#  ('c', 'la'),
#  ('cla', 'im'),
#  ('ent', 'ly'),
#  ('ho', 'st'),
#  ('host', 'ess'),
#  ('p', 'ard'),
#  ('pard', 'on'),
#  ('b', 'u'),
#  ('e', 'red'),
#  ('str', 'u'),
#  ('ef', 'fect'),
#  ('med', 'i'),
#  ('tr', 'ac'),
#  ('su', 'b'),
#  ('satis', 'fact'),
#  ('satisfact', 'ion'),
#  ('s', 'corn'),
#  ('one', 'y'),
#  ('an', 's'),
#  ('object', 's'),
#  ('lat', 'ter'),
#  ('re', 'm'),
#  ('e', 'igh'),
#  ('eigh', 'teen'),
#  ('eighteen', 'th'),
#  ('c', 'ent'),
#  ('cent', 'ury'),
#  ('im', 'in'),
#  ('be', 's'),
#  ('re', 's'),
#  ('be', 'a'),
#  ('bea', 'ut'),
#  ('beaut', 'y'),
#  ('x', 'i'),
#  ('ro', 'ss'),
#  ('s', 'il'),
#  ('ad', 'ded'),
#  ('for', 'm'),
#  ('W', 'hat'),
#  ('str', 'uck'),
#  ('sent', 'ed'),
#  ('t', 'one'),
#  ('tr', 'i'),
#  ('tri', 'but'),
#  ('bec', 'ame'),
#  ('f', 'ond'),
#  ('ab', 'sur'),
#  ('absur', 'd'),
#  ('absurd', 'ity'),
#  ('w', 'inc'),
#  ('winc', 'ing'),
#  ('itu', 'de'),
#  ('gar', 'land'),
#  ('st', 'u'),
#  ('V', 'ic'),
#  ('Vic', 'to'),
#  ('Victo', 'r'),
#  ('ll', 'ed'),
#  ('terr', 'ace'),
#  ('m', 'om'),
#  ('mom', 'ent'),
#  ('h', 'our'),
#  ('er', 'ious'),
#  ('D', 'u'),
#  ('Du', 'bar'),
#  ('Dubar', 'ry'),
#  ('dis', 'pl'),
#  ('displ', 'ay'),
#  ('W', 'h'),
#  ('Wh', 'y'),
#  ('as', 'ked'),
#  ('t', 'ly'),
#  ('ey', 'e'),
#  ('h', 'um'),
#  ('hum', 'ou'),
#  ('humou', 'red'),
#  ('do', 'es'),
#  ('qu', 'ite'),
#  ('simp', 'ly'),
#  ('wh', 'ite'),
#  ('pan', 'ell'),
#  ('fa', 'mi'),
#  ('vas', 'es'),
#  ('pa', 'le'),
#  ('s', 'light'),
#  ('r', 'id'),
#  ('rid', 'ic'),
#  ('ridic', 'ul'),
#  ('ridicul', 'ous'),
#  ('say', 's'),
#  ('st', 'air'),
#  ('stair', 's'),
#  ('cur', 'io'),
#  ('curio', 'sity'),
#  ('ow', 'ing'),
#  ('ng', 'ing'),
#  ('tr', 'ied'),
#  ('n', 'er'),
#  ('ner', 'v'),
#  ('nerv', 'ous'),
#  ('follow', 'ed'),
#  ('am', 'ong'),
#  ('d', 'im'),
#  ('me', 'st'),
#  ('h', 'ung'),
#  ('in', 'ev'),
#  ('inev', 'it'),
#  ('me', 're'),
#  ('lin', 'e'),
#  ('pas', 't'),
#  ('d', 're'),
#  ('a', 'z'),
#  ('le', 'as'),
#  ('man', 'tel'),
#  ('st', 'ay'),
#  ('pl', 'ace'),
#  ('tr', 'al'),
#  ('pl', 'ac'),
#  ('plac', 'ed'),
#  ('bet', 'ter'),
#  ('ye', 't'),
#  ('gre', 'w'),
#  ('cha', 'r'),
#  ('g', 'u'),
#  ('tr', 'ick'),
#  ('trick', 's'),
#  ('wh', 'ich'),
#  ('d', 'i'),
#  ('ver', 't'),
#  ('att', 'ent'),
#  ('attent', 'ion'),
#  ('v', 'ance'),
#  ('her', 'self'),
#  ('u', 'su'),
#  ('usu', 'al'),
#  ('de', 'gre'),
#  ('degre', 'e'),
#  ('t', 'u'),
#  ('in', 's'),
#  ('dd', 'ling'),
#  ('c', 'l'),
#  ('a', 'ther'),
#  ('me', 't'),
#  ('wom', 'an'),
#  ('ti', 'red'),
#  ('pr', 'ide'),
#  ('stro', 'y'),
#  ('stroy', 'ed'),
#  ('l', 've'),
#  ('br', 'own'),
#  ('sun', 'burn'),
#  ('che', 'eks'),
#  ('f', 'ur'),
#  ('con', 'f'),
#  ('conf', 'id'),
#  ('confid', 'ent'),
#  ('qual', 'ity'),
#  ('t', 'ha'),
#  ('tha', 'n'),
#  ('want', 'ed'),
#  ('sh', 'ru'),
#  ('min', 'e'),
#  ('ur', 'b'),
#  ('a', 'king'),
#  ('s', 'se'),
#  ('i', 're'),
#  ('sp', 'ite'),
#  ('long', 'ed'),
#  ('c', 'ry'),
#  ('B', 'e'),
#  ('dis', 'satis'),
#  ('dissatis', 'f'),
#  ('dissatisf', 'ied'),
#  ('u', 'nex'),
#  ('unex', 'pected'),
#  ('po', 'sing'),
#  ('a', 'k'),
#  ('D', 'o'),
#  ('d', 'ab'),
#  ('dab', 'ble'),
#  ('N', 'ever'),
#  ('co', 'l'),
#  ('col', 'our'),
#  ('t', 'ou'),
#  ('tou', 'ched'),
#  ('f', 'las'),
#  ('any', 'thing'),
#  ('el', 'se'),
#  ('in', 'st'),
#  ('inst', 'in'),
#  ('instin', 'ct'),
#  ('instinct', 'ively'),
#  ('r', 'as'),
#  ('w', 'all'),
#  ('B', 'y'),
#  ('c', 'lose'),
#  ('ath', 'ing'),
#  ('ever', 'las'),
#  ('everlas', 'ting'),
#  ('an', 'swe'),
#  ('answe', 'red'),
#  ('A', 'h'),
#  ('Stroud', 's'),
#  ('mu', 'ch'),
#  ('ide', 'a'),
#  ('f', 'as'),
#  ('fas', 'h'),
#  ('fash', 'ion'),
#  ('fashion', 'able'),
#  ('pain', 'ter'),
#  ('for', 'c'),
#  ('pu', 'b'),
#  ('pub', 'lic'),
#  ('be', 'li'),
#  ('beli', 'ev'),
#  ('believ', 'ed'),
#  ('be', 'ar'),
#  ('ar', 'n'),
#  ('day', 's'),
#  ('fra', 'g'),
#  ('frag', 'ment'),
#  ('g', 'ro'),
#  ('gro', 'ping'),
#  ('who', 'le'),
#  ('iron', 'y'),
#  ('lau', 'g'),
#  ('laug', 'hed'),
#  ('thre', 'w'),
#  ('c', 'ure'),
#  ('cure', 'd'),
#  ('reas', 'on'),
#  ('under', 'stand'),
#  ('t', 'w'),
#  ('c', 'are'),
#  ('de', 'ep'),
#  ('re', 'me'),
#  ('reme', 'm'),
#  ('remem', 'b'),
#  ('rememb', 'er'),
#  ('st', 're'),
#  ('stre', 'am'),
#  ('fail', 'ure'),
#  ('cur', 'rent'),
#  ('get', 'ting'),
#  ('The', 'n'),
#  ('al', 'one'),
#  ('tra', 'ps'),
#  ('t', 'went'),
#  ('twent', 'y'),
#  ('he', 'art'),
#  ('gl', 'ad'),
#  ('t', 'ic'),
#  ('su', 'bject'),
#  ...]

# %%
learned_merges = [f"{pair[0]} {pair[1]}" for pair in merges]
learned_merges[:10]
# Out:
# ['e </w>', 'h e', 'i n', 't he', 'h a', 'o u', 'r e', 'a n', 'o n', 'i t']

# %%
# Step 1: Build raw word frequency dictionary from text files
vocab = service.build_word_freq(mode="line", lowercase=False)

# Step 2: Initialize trainer
trainer = BPETrainer(num_merges=10000)

# Step 3: Train BPE merge operations
trainer.fit(vocab)

# Step 4: Log useful stats
trainer.log_statistics()
# Out:
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:61] - 📁 Scanning directory: /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/datasets/raw
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:65] - 📄 Processing file: the-verdict.txt
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/components/io/text_loader.py:28] - 📂 Loading file: /Users/kenneth/Public/projects/python/ai/llms/llm-zero-to-trained/datasets/raw/the-verdict.txt (mode: line)
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/services/text_preprocessing_service.py:70] - ✅ Word frequency dictionary built with 1109 unique words.
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:27] - 📦 Initialized BPETrainer with num_merges=10000
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:39] - 🚀 Starting BPE training...
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:42] - 🧱 Initialized vocab with 1109 entries.
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1/10000: ('e', '</w>') → e</w>
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 101/10000: ('o', 'o') → oo
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 201/10000: ('pictur', 'e</w>') → picture</w>
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 301/10000: ('b', 'ack</w>') → back</w>
# [ 2025-07-19 09:48:16 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 401/10000: ('ti', 'll</w>') → till</w>
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 501/10000: ('sati', 's') → satis
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 601/10000: ('won', 'der</w>') → wonder</w>
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 701/10000: ('f', 'ol') → fol
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 801/10000: ('jea', 'l') → jeal
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 901/10000: ('winc', 'ing</w>') → wincing</w>
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1001/10000: ('v', 'es</w>') → ves</w>
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1101/10000: ('som', 'e') → some
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1201/10000: ('mour', 'n</w>') → mourn</w>
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1301/10000: ('l', 'en') → len
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1401/10000: ('disda', 'in</w>') → disdain</w>
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1501/10000: ('N', 'o</w>') → No</w>
# [ 2025-07-19 09:48:17 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1601/10000: ('persu', 'asi') → persuasi
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1701/10000: ('mode', 'st</w>') → modest</w>
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1801/10000: ('lov', 'ely</w>') → lovely</w>
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 1901/10000: ('wh', 'en') → when
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 2001/10000: ('luc', 'k') → luck
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 2101/10000: ('contin', 'u') → continu
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 2201/10000: ('un', 'c') → unc
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:56] - 🔁 Merge 2301/10000: ('totter', 'ing</w>') → tottering</w>
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:48] - 🛑 No more symbol pairs left after 2384 merges.
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:60] - ✅ Training complete. Learned 2384 merge operations.
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:185] - 📊 BPE Merge Statistics:
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:186] - 🔢 Unique symbolized words in final vocab: 1109
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:187] - 🔁 Merge operations learned: 2384
# [ 2025-07-19 09:48:18 ] INFO [../../../src/llmscratch/components/trainers/bpe_trainer.py:188] - 🧱 Avg symbols per word (weighted): 1.00
